# %%
# https://medium.com/@thakermadhav/build-your-own-rag-with-mistral-7b-and-langchain-97d0c92fa146

# %%
import os
import json
from pathlib import Path

# %%
# Configuration

# FAISS
faiss_gpu = False
faiss_embedding_model_name = 'jinaai/jina-embeddings-v2-base-en'
retrieve_topk = 6

# Text splitting settings
chunk_size = 1000
chunk_overlap = 200

# Rag settings
consistency_samples = 5

# Quantization settings
quantization_enabled = True
use_4bit = True
bnb_4bit_compute_dtype = "float16"
bnb_4bit_quant_type = "nf4"
use_nested_quant = True

# Model
# model_name='mistralai/Mistral-7B-Instruct-v0.1'
model_name='teknium/OpenHermes-2.5-Mistral-7B'
load_model_with_transformers = False
# model_name='Intel/neural-chat-7b-v3-1'
# model_name='rishiraj/CatPPT'
# model_name = 'kyujinpy/Sakura-SOLAR-Instruct'

tgi_url = "http://tgi:80"

batch_size = 16

grader_model_name = 'cognitivecomputations/dolphin-2_6-phi-2'

# Data
data_path = Path("./munchkin_rules/")

device = "cuda"

# %%
# nltk is used for PDF processing. Here we ensure anything it downloads goes to
# the cache folder, so it doesn't have to download again
nltk_data_path = Path("~/.cache/nltk_data").expanduser()
nltk_data_path.mkdir(parents=True, exist_ok=True)
os.environ["NLTK_DATA"] = str(nltk_data_path)

# %%
# !pip install chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting chromadb
#   Downloading chromadb-0.4.22-py3-none-any.whl.metadata (7.3 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.5.2)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.104.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0.post1)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.1)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.3.3-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.9.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.22.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.0)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 10.1 MB/s eta 0:00:00
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (23.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2022.12.7)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Downloading google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.6.4)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.26.13)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 87.3 MB/s eta 0:00:00
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.22.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl.metadata (5.9 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.0.2)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.14.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.19.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.2.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 20.3 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Collecting zipp>=0.5 (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 68.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Downloading chromadb-0.4.22-py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.0/509.0 kB 20.2 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 60.2 MB/s eta 0:00:00a 0:00:01
# Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 98.7 MB/s eta 0:00:00
# Downloading build-1.0.3-py3-none-any.whl (18 kB)
# Downloading grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 68.3 MB/s eta 0:00:00a 0:00:01
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 88.5 MB/s eta 0:00:00
# Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 173.0 MB/s eta 0:00:00
# Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 68.6 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_api-1.22.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 153.0 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.22.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 197.9 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl (28 kB)
# Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl (36 kB)
# Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 168.4 MB/s eta 0:00:00
# Downloading posthog-3.3.3-py2.py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 150.8 MB/s eta 0:00:00
# Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 77.3 MB/s eta 0:00:00a 0:00:01
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 179.7 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 198.4 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 103.1 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 93.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 79.1 MB/s eta 0:00:00a 0:00:01
# Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.1 MB/s eta 0:00:00
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 168.1 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 164.9 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=df1c548cb0e9532cf123725a15d712fda7506a8809f66a93e6258feff8bfa4a0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3lwjw59i/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, flatbuffers, zipp, wrapt, uvloop, typer, python-dotenv, pyproject_hooks, pyasn1, pulsar-client, protobuf, opentelemetry-util-http, opentelemetry-semantic-conventions, oauthlib, importlib-resources, humanfriendly, httptools, grpcio, chroma-hnswlib, cachetools, bcrypt, backoff, asgiref, watchfiles, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, importlib-metadata, googleapis-common-protos, deprecated, coloredlogs, build, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, opentelemetry-sdk, opentelemetry-instrumentation, kubernetes, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 build-1.0.3 cachetools-5.3.2 chroma-hnswlib-0.7.3 chromadb-0.4.22 coloredlogs-15.0.1 deprecated-1.2.14 flatbuffers-23.5.26 google-auth-2.27.0 googleapis-common-protos-1.62.0 grpcio-1.60.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-6.11.0 importlib-resources-6.1.1 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.16.3 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-instrumentation-0.43b0 opentelemetry-instrumentation-asgi-0.43b0 opentelemetry-instrumentation-fastapi-0.43b0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 opentelemetry-util-http-0.43b0 posthog-3.3.3 protobuf-4.25.2 pulsar-client-3.4.0 pyasn1-0.5.1 pyasn1-modules-0.3.0 pypika-0.48.9 pyproject_hooks-1.0.0 python-dotenv-1.0.1 requests-oauthlib-1.3.1 rsa-4.9 typer-0.9.0 uvloop-0.19.0 watchfiles-0.21.0 wrapt-1.16.0 zipp-3.17.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# Deps for PDF parsing
# !pip install "unstructured[pdf]"
# !sudo apt-get install -y poppler-utils tesseract-ocr

# I can't even remember why we need this one
# !pip install sentence-transformers

# For phi-2
# !pip install einops

# Flash attention
# !pip install -U flash-attn --no-build-isolation
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unstructured[pdf]
#   Downloading unstructured-0.12.2-py3-none-any.whl.metadata (26 kB)
# Collecting chardet (from unstructured[pdf])
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured[pdf])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured[pdf])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting lxml (from unstructured[pdf])
#   Downloading lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting nltk (from unstructured[pdf])
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 14.7 MB/s eta 0:00:00a 0:00:01
# Collecting tabulate (from unstructured[pdf])
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured[pdf]) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured[pdf]) (4.12.2)
# Collecting emoji (from unstructured[pdf])
#   Downloading emoji-2.10.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured[pdf]) (0.6.3)
# Collecting python-iso639 (from unstructured[pdf])
#   Downloading python_iso639-2024.1.2-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured[pdf])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 86.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unstructured[pdf]) (1.24.1)
# Collecting rapidfuzz (from unstructured[pdf])
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: backoff in /home/jupyter/.local/lib/python3.10/site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured[pdf]) (4.9.0)
# Collecting unstructured-client>=0.15.1 (from unstructured[pdf])
#   Downloading unstructured_client-0.16.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: wrapt in /home/jupyter/.local/lib/python3.10/site-packages (from unstructured[pdf]) (1.16.0)
# Collecting onnx (from unstructured[pdf])
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting pdf2image (from unstructured[pdf])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pdfminer.six (from unstructured[pdf])
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pikepdf (from unstructured[pdf])
#   Downloading pikepdf-8.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.6 kB)
# Collecting pypdf (from unstructured[pdf])
#   Downloading pypdf-4.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting unstructured-inference==0.7.23 (from unstructured[pdf])
#   Downloading unstructured_inference-0.7.23-py3-none-any.whl.metadata (5.8 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[pdf])
#   Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl.metadata (11 kB)
# Collecting layoutparser[layoutmodels,tesseract] (from unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 74.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.23->unstructured[pdf]) (0.0.6)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.23->unstructured[pdf]) (0.19.4)
# Collecting opencv-python!=4.7.0.68 (from unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting onnxruntime<1.16 (from unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.23->unstructured[pdf]) (4.36.0)
# Collecting certifi>=2023.7.22 (from unstructured-client>=0.15.1->unstructured[pdf])
#   Downloading certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer>=3.2.0 (from unstructured-client>=0.15.1->unstructured[pdf])
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: idna>=3.4 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[pdf]) (3.4)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client>=0.15.1->unstructured[pdf])
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: marshmallow>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[pdf]) (3.20.1)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[pdf]) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[pdf]) (2.8.2)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[pdf]) (1.16.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured[pdf]) (0.9.0)
# Collecting urllib3>=1.26.18 (from unstructured-client>=0.15.1->unstructured[pdf])
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (9.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured[pdf]) (2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[pdf]) (8.1.7)
# Collecting joblib (from nltk->unstructured[pdf])
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[pdf]) (2023.10.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[pdf]) (4.66.1)
# Requirement already satisfied: protobuf>=3.20.2 in /home/jupyter/.local/lib/python3.10/site-packages (from onnx->unstructured[pdf]) (4.25.2)
# Collecting cryptography>=36.0.0 (from pdfminer.six->unstructured[pdf])
#   Downloading cryptography-42.0.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting Pillow>=8.0.0 (from unstructured.pytesseract>=0.3.12->unstructured[pdf])
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: Deprecated in /home/jupyter/.local/lib/python3.10/site-packages (from pikepdf->unstructured[pdf]) (1.2.14)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.16.0)
# Requirement already satisfied: coloredlogs in /home/jupyter/.local/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[pdf]) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/jupyter/.local/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[pdf]) (23.5.26)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[pdf]) (1.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[pdf]) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[pdf]) (6.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[pdf]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[pdf]) (0.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.23->unstructured[pdf]) (2023.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (1.11.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (2.1.4)
# Collecting iopath (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting pdfplumber (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading pdfplumber-0.10.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (2.1.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (0.16.1+cu118)
# Collecting effdet (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting pytesseract (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.21)
# Requirement already satisfied: humanfriendly>=9.1 in /home/jupyter/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[pdf]) (10.0)
# Collecting timm>=0.9.2 (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading timm-0.9.12-py3-none-any.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 338.2 MB/s eta 0:00:00
# Collecting pycocotools>=2.0.2 (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting omegaconf>=2.0 (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 217.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (2.1.0)
# Collecting portalocker (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (2023.3)
# Collecting pdfminer.six (from unstructured[pdf])
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 74.8 MB/s eta 0:00:00a 0:00:01
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading pypdfium2-4.26.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 286.1 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[pdf]) (1.3.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 227.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (3.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[pdf]) (3.1.1)
# Downloading unstructured_inference-0.7.23-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 316.8 MB/s eta 0:00:00
# Downloading unstructured_client-0.16.0-py3-none-any.whl (20 kB)
# Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl (14 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 102.2 MB/s eta 0:00:00
# Downloading emoji-2.10.0-py2.py3-none-any.whl (457 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.9/457.9 kB 85.5 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 76.3 MB/s eta 0:00:0000:0100:01
# Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 73.9 MB/s eta 0:00:0000:0100:01
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pikepdf-8.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 84.3 MB/s eta 0:00:00
# Downloading pypdf-4.0.0-py3-none-any.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.9/283.9 kB 119.7 MB/s eta 0:00:00
# Downloading python_iso639-2024.1.2-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 132.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 78.2 MB/s eta 0:00:00a 0:00:01
# Downloading unstructured-0.12.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 81.3 MB/s eta 0:00:00
# Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 160.0 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 342.6 MB/s eta 0:00:00
# Downloading cryptography-42.0.1-cp39-abi3-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 75.6 MB/s eta 0:00:00a 0:00:01
# Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 76.2 MB/s eta 0:00:00a 0:00:01
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 74.4 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 77.4 MB/s eta 0:00:00a 0:00:01
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 183.8 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 136.5 MB/s eta 0:00:00
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 242.0 MB/s eta 0:00:00
# Downloading pdfplumber-0.10.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 203.1 MB/s eta 0:00:00
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 102.0 MB/s eta 0:00:00
# Downloading pypdfium2-4.26.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.3 MB/s eta 0:00:00a 0:00:01
# Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 77.2 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: langdetect, antlr4-python3-runtime
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=1bf97200b08410b67081ca1e770ea60c8d1be30d8c3bcaf0a04ef99f2ae5c7ef
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cgjayir1/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=18708badad508a4d3159344c50ff4a3c7b24ae3210701ae82ab836777528b981
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cgjayir1/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built langdetect antlr4-python3-runtime
# Installing collected packages: filetype, antlr4-python3-runtime, urllib3, tabulate, rapidfuzz, python-magic, python-iso639, pypdfium2, pypdf, portalocker, Pillow, opencv-python, onnx, omegaconf, lxml, langdetect, jsonpath-python, joblib, emoji, charset-normalizer, chardet, certifi, unstructured.pytesseract, pytesseract, pikepdf, pdf2image, onnxruntime, nltk, iopath, cryptography, unstructured-client, pycocotools, pdfminer.six, unstructured, timm, pdfplumber, layoutparser, effdet, unstructured-inference
#   Attempting uninstall: onnxruntime
#     Found existing installation: onnxruntime 1.16.3
#     Uninstalling onnxruntime-1.16.3:
#       Successfully uninstalled onnxruntime-1.16.3
# Successfully installed Pillow-10.2.0 antlr4-python3-runtime-4.9.3 certifi-2023.11.17 chardet-5.2.0 charset-normalizer-3.3.2 cryptography-42.0.1 effdet-0.4.1 emoji-2.10.0 filetype-1.2.0 iopath-0.1.9 joblib-1.3.2 jsonpath-python-1.0.6 langdetect-1.0.9 layoutparser-0.3.4 lxml-5.1.0 nltk-3.8.1 omegaconf-2.3.0 onnx-1.15.0 onnxruntime-1.15.1 opencv-python-4.9.0.80 pdf2image-1.17.0 pdfminer.six-20221105 pdfplumber-0.10.3 pikepdf-8.11.2 portalocker-2.8.2 pycocotools-2.0.7 pypdf-4.0.0 pypdfium2-4.26.0 pytesseract-0.3.10 python-iso639-2024.1.2 python-magic-0.4.27 rapidfuzz-3.6.1 tabulate-0.9.0 timm-0.9.12 unstructured-0.12.2 unstructured-client-0.16.0 unstructured-inference-0.7.23 unstructured.pytesseract-0.3.12 urllib3-2.1.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fontconfig libcairo2 libdatrie1 libdeflate0 libfribidi0 libgif7
#   libgraphite2-3 libharfbuzz0b libjbig0 libjpeg-turbo8 libjpeg8 liblcms2-2
#   liblept5 libnspr4 libnss3 libopenjp2-7 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpixman-1-0 libpoppler118 libtesseract4 libthai-data
#   libthai0 libtiff5 libwebp7 libwebpmux3 libxcb-render0 poppler-data
#   tesseract-ocr-eng tesseract-ocr-osd
# Suggested packages:
#   liblcms2-utils ghostscript fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fontconfig libcairo2 libdatrie1 libdeflate0 libfribidi0 libgif7
#   libgraphite2-3 libharfbuzz0b libjbig0 libjpeg-turbo8 libjpeg8 liblcms2-2
#   liblept5 libnspr4 libnss3 libopenjp2-7 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpixman-1-0 libpoppler118 libtesseract4 libthai-data
#   libthai0 libtiff5 libwebp7 libwebpmux3 libxcb-render0 poppler-data
#   poppler-utils tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 33 newly installed, 0 to remove and 65 not upgraded.
# Need to get 15.1 MB of archives.
# After this operation, 52.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2171 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfribidi0 amd64 1.0.8-2ubuntu3.1 [26.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 fontconfig amd64 2.13.1-4.2ubuntu5 [177 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-0 amd64 0.40.0-1ubuntu0.22.04.1 [264 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render0 amd64 1.14-3ubuntu3 [16.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo2 amd64 1.16.0-5ubuntu2 [628 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdatrie1 amd64 0.2.13-2 [19.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdeflate0 amd64 1.10-2 [70.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgif7 amd64 5.1.9-2build2 [33.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphite2-3 amd64 1.3.14-1build2 [71.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz0b amd64 2.7.4-1ubuntu3.1 [352 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjpeg-turbo8 amd64 2.1.2-0ubuntu1 [134 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjpeg8 amd64 8c-2ubuntu10 [2264 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblcms2-2 amd64 2.12~rc1-2build2 [159 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopenjp2-7 amd64 2.4.0-6 [158 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libjbig0 amd64 2.1-3.1ubuntu0.22.04.1 [29.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebp7 amd64 1.2.2-2ubuntu0.22.04.2 [206 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtiff5 amd64 4.3.0-6ubuntu0.7 [185 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpmux3 amd64 1.2.2-2ubuntu0.22.04.2 [20.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblept5 amd64 1.82.0-3build1 [1107 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnspr4 amd64 2:4.32-3build1 [119 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnss3 amd64 2:3.68.2-0ubuntu1.2 [1280 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libthai-data all 0.1.29-1build1 [162 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libthai0 amd64 0.1.29-1build1 [19.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpango-1.0-0 amd64 1.50.6+ds-2ubuntu1 [230 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoft2-1.0-0 amd64 1.50.6+ds-2ubuntu1 [54.0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangocairo-1.0-0 amd64 1.50.6+ds-2ubuntu1 [39.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpoppler118 amd64 22.02.0-2ubuntu0.3 [1072 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtesseract4 amd64 4.1.1-2.1build1 [1308 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.3 [186 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1591 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2990 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 15.1 MB in 2s (9927 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package poppler-data.
# (Reading database ... 22641 files and directories currently installed.)
# Preparing to unpack .../00-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libfribidi0:amd64.
# Preparing to unpack .../01-libfribidi0_1.0.8-2ubuntu3.1_amd64.deb ...
# Unpacking libfribidi0:amd64 (1.0.8-2ubuntu3.1) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../02-fontconfig_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking fontconfig (2.13.1-4.2ubuntu5) ...
# Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../03-libpixman-1-0_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../04-libxcb-render0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../05-libcairo2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo2:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../06-libdatrie1_0.2.13-2_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.13-2) ...
# Selecting previously unselected package libdeflate0:amd64.
# Preparing to unpack .../07-libdeflate0_1.10-2_amd64.deb ...
# Unpacking libdeflate0:amd64 (1.10-2) ...
# Selecting previously unselected package libgif7:amd64.
# Preparing to unpack .../08-libgif7_5.1.9-2build2_amd64.deb ...
# Unpacking libgif7:amd64 (5.1.9-2build2) ...
# Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../09-libgraphite2-3_1.3.14-1build2_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.14-1build2) ...
# Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../10-libharfbuzz0b_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libjpeg-turbo8:amd64.
# Preparing to unpack .../11-libjpeg-turbo8_2.1.2-0ubuntu1_amd64.deb ...
# Unpacking libjpeg-turbo8:amd64 (2.1.2-0ubuntu1) ...
# Selecting previously unselected package libjpeg8:amd64.
# Preparing to unpack .../12-libjpeg8_8c-2ubuntu10_amd64.deb ...
# Unpacking libjpeg8:amd64 (8c-2ubuntu10) ...
# Selecting previously unselected package liblcms2-2:amd64.
# Preparing to unpack .../13-liblcms2-2_2.12~rc1-2build2_amd64.deb ...
# Unpacking liblcms2-2:amd64 (2.12~rc1-2build2) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../14-libopenjp2-7_2.4.0-6_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.4.0-6) ...
# Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../15-libjbig0_2.1-3.1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1ubuntu0.22.04.1) ...
# Selecting previously unselected package libwebp7:amd64.
# Preparing to unpack .../16-libwebp7_1.2.2-2ubuntu0.22.04.2_amd64.deb ...
# Unpacking libwebp7:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../17-libtiff5_4.3.0-6ubuntu0.7_amd64.deb ...
# Unpacking libtiff5:amd64 (4.3.0-6ubuntu0.7) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../18-libwebpmux3_1.2.2-2ubuntu0.22.04.2_amd64.deb ...
# Unpacking libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Selecting previously unselected package liblept5:amd64.
# Preparing to unpack .../19-liblept5_1.82.0-3build1_amd64.deb ...
# Unpacking liblept5:amd64 (1.82.0-3build1) ...
# Selecting previously unselected package libnspr4:amd64.
# Preparing to unpack .../20-libnspr4_2%3a4.32-3build1_amd64.deb ...
# Unpacking libnspr4:amd64 (2:4.32-3build1) ...
# Selecting previously unselected package libnss3:amd64.
# Preparing to unpack .../21-libnss3_2%3a3.68.2-0ubuntu1.2_amd64.deb ...
# Unpacking libnss3:amd64 (2:3.68.2-0ubuntu1.2) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../22-libthai-data_0.1.29-1build1_all.deb ...
# Unpacking libthai-data (0.1.29-1build1) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../23-libthai0_0.1.29-1build1_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.29-1build1) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../24-libpango-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../25-libpangoft2-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../26-libpangocairo-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpoppler118:amd64.
# Preparing to unpack .../27-libpoppler118_22.02.0-2ubuntu0.3_amd64.deb ...
# Unpacking libpoppler118:amd64 (22.02.0-2ubuntu0.3) ...
# Selecting previously unselected package libtesseract4:amd64.
# Preparing to unpack .../28-libtesseract4_4.1.1-2.1build1_amd64.deb ...
# Unpacking libtesseract4:amd64 (4.1.1-2.1build1) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../29-poppler-utils_22.02.0-2ubuntu0.3_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.3) ...
# Selecting previously unselected package tesseract-ocr-eng.
# Preparing to unpack .../30-tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../31-tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../32-tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up libgraphite2-3:amd64 (1.3.14-1build2) ...
# Setting up liblcms2-2:amd64 (2.12~rc1-2build2) ...
# Setting up libpixman-1-0:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Setting up fontconfig (2.13.1-4.2ubuntu5) ...
# Regenerating fonts cache... done.
# Setting up libdatrie1:amd64 (0.2.13-2) ...
# Setting up libxcb-render0:amd64 (1.14-3ubuntu3) ...
# Setting up libdeflate0:amd64 (1.10-2) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up libjbig0:amd64 (2.1-3.1ubuntu0.22.04.1) ...
# Setting up libcairo2:amd64 (1.16.0-5ubuntu2) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libnspr4:amd64 (2:4.32-3build1) ...
# Setting up libfribidi0:amd64 (1.0.8-2ubuntu3.1) ...
# Setting up libjpeg-turbo8:amd64 (2.1.2-0ubuntu1) ...
# Setting up libwebp7:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libgif7:amd64 (5.1.9-2build2) ...
# Setting up libopenjp2-7:amd64 (2.4.0-6) ...
# Setting up libharfbuzz0b:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libthai-data (0.1.29-1build1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libjpeg8:amd64 (8c-2ubuntu10) ...
# Setting up libnss3:amd64 (2:3.68.2-0ubuntu1.2) ...
# Setting up libthai0:amd64 (0.1.29-1build1) ...
# Setting up libtiff5:amd64 (4.3.0-6ubuntu0.7) ...
# Setting up libpango-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up liblept5:amd64 (1.82.0-3build1) ...
# Setting up libpoppler118:amd64 (22.02.0-2ubuntu0.3) ...
# Setting up libtesseract4:amd64 (4.1.1-2.1build1) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.3) ...
# Setting up libpangoft2-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.36.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.24.1)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /home/jupyter/.local/lib/python3.10/site-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /home/jupyter/.local/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.3.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence-transformers)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/jupyter/.local/lib/python3.10/site-packages (from torchvision->sentence-transformers) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Downloading scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 62.4 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=0f97cf596671c780dbe8a7fd886db09ed972a0bde64d32e5cdc74a7db65697ed
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q47nq2_x/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, threadpoolctl, scikit-learn, sentence-transformers
# Successfully installed scikit-learn-1.4.0 sentence-transformers-2.2.2 sentencepiece-0.1.99 threadpoolctl-3.2.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flash-attn
#   Downloading flash_attn-2.5.0.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 17.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn) (2.1.1+cu118)
# Requirement already satisfied: einops in /home/jupyter/.local/lib/python3.10/site-packages (from flash-attn) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash-attn) (23.2)
# Collecting ninja (from flash-attn)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2023.10.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash-attn) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash-attn) (1.3.0)
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 119.1 MB/s eta 0:00:00
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.5.0-cp310-cp310-linux_x86_64.whl size=121827446 sha256=930b26149f183b41d04ee7100531e7f08b75c6c05ce05af99c59262f3a7448a5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l5q66733/wheels/9e/c3/22/a576eb5627fb2c30dc4679a33d67d34d922d6dbeb24a9119b2
# Successfully built flash-attn
# Installing collected packages: ninja, flash-attn
# Successfully installed flash-attn-2.5.0 ninja-1.11.1.1
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# !pip install text_generation==0.6.1
# !pip install langchain==0.0.354
# !pip install langchain-community==0.0.8
# !pip install langchain-core==0.1.5
# !pip install langsmith==0.0.77
# langchain-community                      0.0.8
# langchain-core                           0.1.5
# langsmith                                0.0.77
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting text_generation==0.6.1
#   Downloading text_generation-0.6.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in /usr/local/lib/python3.10/dist-packages (from text_generation==0.6.1) (3.9.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from text_generation==0.6.1) (0.19.4)
# Requirement already satisfied: pydantic<3,>1.10 in /usr/local/lib/python3.10/dist-packages (from text_generation==0.6.1) (2.5.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.8->text_generation==0.6.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.8->text_generation==0.6.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.8->text_generation==0.6.1) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.8->text_generation==0.6.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.8->text_generation==0.6.1) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.8->text_generation==0.6.1) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (2023.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>1.10->text_generation==0.6.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>1.10->text_generation==0.6.1) (2.14.5)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.8->text_generation==0.6.1) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1.0,>=0.12->text_generation==0.6.1) (2023.11.17)
# Downloading text_generation-0.6.1-py3-none-any.whl (10 kB)
# Installing collected packages: text_generation
# Successfully installed text_generation-0.6.1
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain==0.0.354
#   Downloading langchain-0.0.354-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (1.33)
# Collecting langchain-community<0.1,>=0.0.8 (from langchain==0.0.354)
#   Downloading langchain_community-0.0.16-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<0.2,>=0.1.5 (from langchain==0.0.354)
#   Downloading langchain_core-0.1.16-py3-none-any.whl.metadata (6.0 kB)
# Collecting langsmith<0.1.0,>=0.0.77 (from langchain==0.0.354)
#   Downloading langsmith-0.0.83-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (1.24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.354) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.354) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.354) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain==0.0.354) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.5->langchain==0.0.354) (3.7.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.5->langchain==0.0.354) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.0.354) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.0.354) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.0.354) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.0.354) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.0.354) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.0.354) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.0.354) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.354) (3.0.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.5->langchain==0.0.354) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.5->langchain==0.0.354) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.354) (1.0.0)
# Downloading langchain-0.0.354-py3-none-any.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.3/803.3 kB 8.9 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_community-0.0.16-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.7 MB/s eta 0:00:00
# Downloading langchain_core-0.1.16-py3-none-any.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 kB 144.4 MB/s eta 0:00:00
# Downloading langsmith-0.0.83-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 195.1 MB/s eta 0:00:00
# Installing collected packages: langsmith, langchain-core, langchain-community, langchain
# Successfully installed langchain-0.0.354 langchain-community-0.0.16 langchain-core-0.1.16 langsmith-0.0.83
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-community==0.0.8
#   Downloading langchain_community-0.0.8-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.0.8) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.0.8) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.0.8) (3.9.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.0.8) (0.6.3)
# Requirement already satisfied: langchain-core<0.2,>=0.1.5 in /home/jupyter/.local/lib/python3.10/site-packages (from langchain-community==0.0.8) (0.1.16)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /home/jupyter/.local/lib/python3.10/site-packages (from langchain-community==0.0.8) (0.0.83)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.0.8) (1.24.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.0.8) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.0.8) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.8) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.8) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.8) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.8) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.8) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.8) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.8) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.8) (0.9.0)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (3.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (2.5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain-community==0.0.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community==0.0.8) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain-community==0.0.8) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain-community==0.0.8) (2023.11.17)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.0.8) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.0.8) (3.0.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (1.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.2,>=0.1.5->langchain-community==0.0.8) (2.14.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.8) (1.0.0)
# Downloading langchain_community-0.0.8-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.2 MB/s eta 0:00:00 0:00:01
# Installing collected packages: langchain-community
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.16
#     Uninstalling langchain-community-0.0.16:
#       Successfully uninstalled langchain-community-0.0.16
# Successfully installed langchain-community-0.0.8
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-core==0.1.5
#   Downloading langchain_core-0.1.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.5) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.5) (3.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.5) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /home/jupyter/.local/lib/python3.10/site-packages (from langchain-core==0.1.5) (0.0.83)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.5) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.5) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.5) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.5) (8.2.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core==0.1.5) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core==0.1.5) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core==0.1.5) (1.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.1.5) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core==0.1.5) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core==0.1.5) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core==0.1.5) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain-core==0.1.5) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain-core==0.1.5) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain-core==0.1.5) (2023.11.17)
# WARNING: The candidate selected for download or install is a yanked version: 'langchain-core' candidate (version 0.1.5 at https://files.pythonhosted.org/packages/5e/2f/6c6415ad9108effa62cdea189ac7ad31503ffc965f1a9ee56f2ed866f688/langchain_core-0.1.5-py3-none-any.whl (from https://pypi.org/simple/langchain-core/) (requires-python:>=3.8.1,<4.0))
# Reason for being yanked: breaking changes
# Downloading langchain_core-0.1.5-py3-none-any.whl (205 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.3/205.3 kB 4.0 MB/s eta 0:00:00 0:00:01
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.16
#     Uninstalling langchain-core-0.1.16:
#       Successfully uninstalled langchain-core-0.1.16
# Successfully installed langchain-core-0.1.5
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langsmith==0.0.77
#   Downloading langsmith-0.0.77-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langsmith==0.0.77) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith==0.0.77) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langsmith==0.0.77) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langsmith==0.0.77) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langsmith==0.0.77) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langsmith==0.0.77) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith==0.0.77) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langsmith==0.0.77) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3,>=2->langsmith==0.0.77) (2023.11.17)
# Downloading langsmith-0.0.77-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: langsmith
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.83
#     Uninstalling langsmith-0.0.83:
#       Successfully uninstalled langsmith-0.0.83
# Successfully installed langsmith-0.0.77
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# !pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.14.0)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 2.8 MB/s eta 0:00:00 0:00:01
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 11.5 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 39.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.1 jupyterlab-widgets-3.0.9 widgetsnbextension-4.0.9
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# !pip uninstall faiss faiss-gpu -y
# !pip install faiss-cpu
# Out:
# WARNING: Skipping faiss as it is not installed.
# WARNING: Skipping faiss-gpu as it is not installed.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 62.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.7.4
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
from typing import Optional, Tuple

import torch
import transformers

from langchain.callbacks.tracers import ConsoleCallbackHandler
from langchain.chains import LLMChain
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.llms.huggingface_pipeline import HuggingFacePipeline
from langchain.prompts import PromptTemplate, StringPromptTemplate
from langchain.retrievers import ParentDocumentRetriever
from langchain.schema import AIMessage, SystemMessage, HumanMessage
from langchain.schema.runnable import RunnablePassthrough
from langchain.storage import InMemoryStore
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import VectorStore
from langchain_community.chat_models import ChatHuggingFace
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.llms import HuggingFaceTextGenInference
from langchain_community.vectorstores.chroma import Chroma
from langchain_community.vectorstores.faiss import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
from langchain_core.language_models import BaseChatModel
from langchain_core.runnables import RunnableLambda
from langchain_core.runnables import Runnable
from langchain_core.runnables import RunnableBranch
from transformers import (
    PreTrainedModel, 
    PreTrainedTokenizerBase,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    AutoModel,
)

# %%
# %load_ext autoreload
# %autoreload 2
from util import HuggingFaceChatModel, VectorStoreRetrieverWithTextSplitter, parse_pdf, HuggingFaceChatModelWithBatchSupport

# %%
print(f"{transformers.__version__=}")
print(f"{torch.__version__=}")
print(f"{torch.version.cuda=}")
print(f"{torch.cuda.is_available()=}")
print(f"{torch.cuda.device_count()=}")

if "cuda" in device:
    assert torch.cuda.is_available(), "CUDA is not available"
# Out:
# transformers.__version__='4.36.0'
# torch.__version__='2.1.1+cu118'
# torch.version.cuda='11.8'
# torch.cuda.is_available()=True
# torch.cuda.device_count()=1

# %%
# !nvidia-smi
# Out:
# Sat Jan 27 00:43:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.154.05             Driver Version: 535.154.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off | 00000000:07:00.0 Off |                  N/A |
# |  0%   47C    P8              21W / 420W |  15350MiB / 24576MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
# !curl http://tgi:80/info
# Out:
# {"model_id":"TheBloke/OpenHermes-2.5-Mistral-7B-AWQ","model_sha":"a0e39e3a0ca6767307293819acb7c38e7a18cd31","model_dtype":"torch.float16","model_device_type":"cuda","model_pipeline_tag":"text-generation","max_concurrent_requests":128,"max_best_of":2,"max_stop_sequences":4,"max_input_length":4096,"max_total_tokens":6096,"waiting_served_ratio":1.2,"max_batch_total_tokens":86160,"max_waiting_tokens":20,"validation_workers":2,"version":"1.3.4","sha":"630800eed37b15c4b0c9eb8e6ab47212026720f7","docker_label":"sha-630800e"}

# %% [markdown]
# ## Build Chat Model

# %%
def load_tokenizer(model_name:str) -> PreTrainedTokenizerBase:
    # Load model and tokenizer
    tokenizer = AutoTokenizer.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto"
    )
    if tokenizer.pad_token is None:
        print("Setting pad token")
        # For some reason, this isn't set in the config. For Mistral, it's just
        # the EOS token (which is the default). However, with OpenHermes, the
        # EOS token is a different token, but the padding token appears to still
        # be </s>:
        #
        # https://huggingface.co/teknium/OpenHermes-2.5-Mistral-7B/blob/main/special_tokens_map.json
        #
        # So if it is not set, we just set it explicitly to </s> here.
        tokenizer.pad_token = '</s>'
    
    return tokenizer


def load_transformers_model(model_name:str, bnb_config:Optional[BitsAndBytesConfig]=None, flash_attention=False) -> Tuple[PreTrainedModel, PreTrainedTokenizerBase]:
    # Load model and tokenizer
    tokenizer = load_tokenizer(model_name)

    if bnb_config is not None:
        model_kwargs = {"quantization_config": bnb_config}
    else:
        model_kwargs = {"torch_dtype": torch.float16}
    
    if flash_attention:
        model_kwargs["attn_implementation"] = "flash_attention_2"

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        # OpenHermes has the KV-cache disabled by default (perhaps they setup the
        # defaults for fine-tuning?). Enabling it here because it is way way
        # faster.
        use_cache=True,
        trust_remote_code=True,
        **model_kwargs,
    )

    return (model, tokenizer)

# %%
if not load_model_with_transformers:
    tokenizer = load_tokenizer(model_name)
else:
    compute_dtype = getattr(torch, bnb_4bit_compute_dtype)
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=use_4bit,
        bnb_4bit_quant_type=bnb_4bit_quant_type,
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=use_nested_quant,
    )

    model, tokenizer = load_transformers_model(model_name, bnb_config, flash_attention=True)

    print("BOS token:", tokenizer.bos_token)
    print("EOS token:", tokenizer.eos_token)
    print("PAD token:", tokenizer.pad_token)
    print("UNK token:", tokenizer.unk_token)

    # Example with standard completion
    input_ids = tokenizer.encode("What is the capital of the U.S.?", return_tensors="pt").to(model.device)

    results = model.generate(input_ids, eos_token_id=tokenizer.eos_token_id, pad_token_id=tokenizer.pad_token_id, max_new_tokens=100)
    sequence = results[0]
    sequence = tokenizer.decode(sequence)
    print("Completion:")
    print(sequence)
    print()
    print()

    # Example using chat
    messages = [
        # {
        #     "role": "system",
        #     "content": "You are a helpfule Q&A AI assistant."
        # },
        {
            "role": "user",
            "content": "What is the capital of the U.S.?"
        }
    ]

    input_ids = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to(model.device)

    results = model.generate(input_ids, eos_token_id=tokenizer.eos_token_id, pad_token_id=tokenizer.pad_token_id, max_new_tokens=100)
    sequence = results[0]
    sequence = tokenizer.decode(sequence)
    print("Chat:")
    print(sequence)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Setting pad token

# %%
if load_model_with_transformers:
    messages = [
        # {
        #     "role": "system",
        #     "content": "You are a helpfule Q&A AI assistant."
        # },
        {
            "role": "user",
            "content": "Summarize the history of the U.S. in 200 words or less."
        }
    ]

    input_ids = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to(model.device)

    results = model.generate(input_ids, temperature=0.7, do_sample=True, eos_token_id=tokenizer.eos_token_id, pad_token_id=tokenizer.pad_token_id, max_new_tokens=500, num_return_sequences=2)
    sequence = results[0]
    sequence = tokenizer.decode(sequence)
    print(tokenizer.decode(results[0], skip_special_tokens=True))
    print()
    print()
    print(tokenizer.decode(results[1]))

# %%
if load_model_with_transformers:
    conversations = [
        [
            # {
            #     "role": "system",
            #     "content": "You are a helpfule Q&A AI assistant."
            # },
            {
                "role": "user",
                "content": "Summarize the history of the U.S. in 200 words or less."
            }
        ],
        [
            {
                "role": "user",
                "content": "Captial of U.S.?"
            }
        ]
    ]

    conversations_template_applied = [tokenizer.apply_chat_template(conversation, add_generation_prompt=True, tokenize=False) for conversation in conversations]
    encoded = tokenizer(conversations_template_applied, return_tensors="pt", add_special_tokens=False, padding=True, truncation=True)
    # print(tokenizer.encode(tokenizer.apply_chat_template(
    #     messages,
    #     add_generation_prompt=True,
    #     tokenize=False,
    # ), add_special_tokens=False))

    # print(tokenizer.apply_chat_template(
    #     messages,
    #     add_generation_prompt=True
    # ))
    print(encoded["input_ids"][1])
    results = model.generate(**encoded, temperature=0.7, do_sample=True, eos_token_id=tokenizer.eos_token_id, pad_token_id=tokenizer.pad_token_id, max_new_tokens=500)
    print(results[1])
    tokenizer.decode(results[0], clean_up_tokenization_spaces=True, skip_special_tokens=True)

# %%
if load_model_with_transformers:
    model.config

# %%
# Vanilla mistral:

# MistralConfig {
#   "_name_or_path": "mistralai/Mistral-7B-Instruct-v0.1",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "quantization_config": {
#     "bnb_4bit_compute_dtype": "float16",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 10000.0,
#   "sliding_window": 4096,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.36.2",
#   "use_cache": true,
#   "vocab_size": 32000
# }

# GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": 2
# }

# Hermes:

# MistralConfig {
#   "_name_or_path": "teknium/OpenHermes-2.5-Mistral-7B",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 32000,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "quantization_config": {
#     "bnb_4bit_compute_dtype": "float16",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 10000.0,
#   "sliding_window": 4096,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.36.2",
#   "use_cache": false,
#   "vocab_size": 32002
# }

# GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": 32000,
#   "use_cache": false
# }
if load_model_with_transformers:
    model.generation_config

# %%
from typing import Any


class HuggingFaceChatModelLocal(ChatHuggingFace):
    tokenizer: Any
    
    def _resolve_model_id(self):
        pass

# %%
# chat_model = HuggingFaceChatModel(
#     model=model,
#     tokenizer=tokenizer,
#     generate_kwargs={},
#     max_tokens=500
# )
if load_model_with_transformers:
    chat_model = HuggingFaceChatModelWithBatchSupport.from_model_tokenizer(
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=512,
        batch_size=batch_size,
    )
else:
    llm_model = HuggingFaceTextGenInference(
        inference_server_url=tgi_url,
        max_new_tokens=512,
        timeout=900,
    )
    chat_model = HuggingFaceChatModelLocal(
        tokenizer=tokenizer,
        llm=llm_model
    )

chat_model.invoke(
    [
        SystemMessage(content="You are a helpful Q&A AI assistant."),
        HumanMessage(content="What is the capital of the U.S.?")
    ],
)
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_fields.py:149: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# AIMessage(content='The capital of the United States is Washington, D.C.')

# %% [markdown]
# ## Build Grader Chat Model
#
# To create a level playing field when comparing model performance, we always use
# the same language model for grading. We load this model now before we start
# hogging all the vram.

# %%
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

grader_model, grader_tokenizer = load_transformers_model(grader_model_name, bnb_config)

# grader_chat_model = HuggingFaceChatModel(
#     model=grader_model,
#     tokenizer=grader_tokenizer,
#     generate_kwargs={},
#     max_tokens=500
# )

grader_chat_model = HuggingFaceChatModelWithBatchSupport.from_model_tokenizer(
    model=grader_model,
    tokenizer=grader_tokenizer,
    max_tokens=512,
    batch_size=batch_size,
)

grader_chat_model.invoke(
    [
        SystemMessage(content="You are a helpful Q&A AI assistant."),
        HumanMessage(content="What is the capital of the U.S.?")
    ],
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some weights of the model checkpoint at cognitivecomputations/dolphin-2_6-phi-2 were not used when initializing PhiForCausalLM: ['lm_head.linear.lora_B.default.weight', 'lm_head.linear.lora_A.default.weight']
# - This IS expected if you are initializing PhiForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing PhiForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# AIMessage(content="The capital of the United States is Washington, D.C. It is a federal district and the seat of the federal government of the United States. It is located on the east bank of the Potomac River across from the District of Columbia's western border with Maryland. The city is divided into two parts: the Federal City, which is the area around the White House and the U.S. Capitol, and the Georgetown neighborhood, which is the area around the U.S. Naval Observatory and the U.S. Army's Fort Lesley J. McNair. Washington, D.C. is the fourth-smallest capital city in the world by area.")

# %% [markdown]
# ## Build Retriever

# %%
def load_docs():
    rule_docs = []
    for filename in data_path.glob("*.pdf"):
        print(f"Processing {filename}")
        rule_docs.extend(parse_pdf(filename))
    return rule_docs

# %%
rule_docs = load_docs()
# Out:
# Processing munchkin_rules/munchkin_rules-1.pdf
# Processing munchkin_rules/puppies-rules.pdf
# Processing munchkin_rules/princesses_rules.pdf
# Processing munchkin_rules/munch_4_rules_20thp.pdf

# %%
total_rule_tokens = sum(len(tokenizer.tokenize(doc.page_content)) for doc in rule_docs)
print(f"Total doc tokens: {total_rule_tokens:,}")
# Out:
# Total doc tokens: 11,641

# %%
def load_embedding_model(model_name:str) -> HuggingFaceEmbeddings:
    # We first load the embedding model using AutoModel so that we can pass
    # trust_remote_code=True to install it, which we cannot do with 
    # HuggingFaceEmbeddings (https://github.com/langchain-ai/langchain/issues/6080)
    _ = AutoModel.from_pretrained(model_name, trust_remote_code=True)

    embedding_model = HuggingFaceEmbeddings(model_name=model_name, model_kwargs={'device': 'cpu'})

    # There should be a better way to do this... but I don't know what it is.
    # We put the model in eval mode (since we aren't doing any finetuning) and
    # disable gradients for all parameters, since we don't need the gradients.
    embedding_model.client.eval()
    for parameter in embedding_model.client.parameters():
        parameter.requires_grad = False

    return embedding_model

# %%
def build_vectorstore_faiss(embedding_model:HuggingFaceEmbeddings) -> VectorStore:
    import faiss
    embeddings = embedding_model.embed_documents(["test"])
    embedding_size = len(embeddings[0])
    distance_strategy = DistanceStrategy.EUCLIDEAN_DISTANCE
    index = faiss.IndexFlatL2(embedding_size)
    vectorstore = FAISS(
        embedding_model,
        index,
        InMemoryDocstore(),
        {},
        normalize_L2=False,
        distance_strategy=distance_strategy,
    )
    return vectorstore

def build_vectorstore_chroma(embedding_model:HuggingFaceEmbeddings) -> VectorStore:
    db = Chroma(embedding_function=embedding_model)
    return db

build_vectorstore = build_vectorstore_faiss

# %%
# Retriever config dataclass
from dataclasses import dataclass
import math

# @dataclass
# class RetrieverConfig:
#     max_context_size:int = 4096
#     percent_context_use:float = 0.5
#     parent_percent:float = 0.25
#     parent_overlap_percent:float = 0.1
#     child_percent:float = 0.25
#     child_overlap_percent:float = 0.1
#     retrieve_extra_results_percent:float = 0.0

@dataclass
class RetrieverConfig:
    parent_chunk_size:int = 500
    parent_chunk_overlap:int = 50
    child_chunk_size:int = 125
    child_chunk_overlap:int = 12
    k:int = 10



def build_retriever(
    tokenizer:PreTrainedTokenizerBase,
    vectorstore:VectorStore,
    config:RetrieverConfig,
):
    parent_chunk_size = config.parent_chunk_size
    parent_chunk_overlap = config.parent_chunk_overlap
    parent_splitter = RecursiveCharacterTextSplitter.from_huggingface_tokenizer(
        tokenizer,
        chunk_size=parent_chunk_size,
        chunk_overlap=parent_chunk_overlap
    )

    k = config.k

    search_kwargs={"k": k}

    child_chunk_size = config.child_chunk_size

    if child_chunk_size > 0:
        child_chunk_overlap = config.child_chunk_overlap
        child_splitter = RecursiveCharacterTextSplitter.from_huggingface_tokenizer(
            tokenizer,
            chunk_size=child_chunk_size,
            chunk_overlap=child_chunk_overlap
        )
        store = InMemoryStore()
        retriever = ParentDocumentRetriever(
            vectorstore=vectorstore,
            docstore=store,
            child_splitter=child_splitter,
            parent_splitter=parent_splitter,
            search_kwargs=search_kwargs,
        )
    else:
        retriever = VectorStoreRetrieverWithTextSplitter(
            vectorstore=vectorstore,
            text_splitter=parent_splitter,
            search_kwargs=search_kwargs,
        )

    return retriever

db = build_vectorstore(load_embedding_model(faiss_embedding_model_name))
retriever = build_retriever(tokenizer, db, RetrieverConfig())
retriever.add_documents(rule_docs)

# %%
query = "Can I play a Go Up a Level card during combat?"
result = db.similarity_search(query)
print(f"Query: {query}")
print()
print(f"From vectorstore:")
print(f"Result count: {len(result)}")
print(f"Doc length: {len(result[0].page_content)}")
print(f"Content: {result[0].page_content[:100]}")
print()

result = retriever.invoke("Can I play a Go Up a Level card during combat?")
print(f"From retriever:")
print(f"Result count: {len(result)}")
print(f"Doc length: {len(result[0].page_content)}")
print(f"Content: {result[0].page_content[:100]}")

# print(f"{str(len(result)):<5.5} {len(result[0].page_content):<5.5} {result[0].page_content[:100]}")
# Out:
# Query: Can I play a Go Up a Level card during combat?
#
# From vectorstore:
# Result count: 4
# Doc length: 423
# Content: OTHER TREASURES
# Other Treasure cards (like Go Up a Level cards) are not Items. Most of these cards s
#
# From retriever:
# Result count: 9
# Doc length: 1017
# Content: "ONE-SHOT” TREASURES
# A Treasure card that says “Usable once only” is often called a “one-shot” Treas

# %% [markdown]
# ## Sampling LLM Chain
#
# For self consistency, we need a way to sample multiple results from the LLM.

# %%
import copy
from langchain.schema import AIMessage
from langchain_core.outputs import LLMResult

@dataclass
class SamplingConfig:
    temperature:float = 0.7
    top_k:Optional[int] = 0
    top_p:Optional[float] = None
    samples:int = 1


def llmresult_to_aimessages(llmresult: LLMResult):
    return [
        AIMessage(content=gen.text) 
        for generations in llmresult.generations 
        for gen in generations
    ]


def build_sampling_llm_chain(chat_model:BaseChatModel, config:SamplingConfig) -> Runnable:
    temperature = config.temperature
    top_k = config.top_k
    top_p = config.top_p
    n = config.samples
    # kwargs = dict(temperature=temperature, top_k=top_k, top_p=top_p, do_sample=True, num_return_sequences=n)
    kwargs = dict(temperature=temperature, top_k=top_k, top_p=top_p, do_sample=True)
    kwargs = {k: v for k, v in kwargs.items() if v is not None}
    if kwargs.get("top_k") == 0:
        kwargs.pop("top_k")
    sampling_model = chat_model.bind(**kwargs)
    return (
        RunnableLambda(
            # lambda x: chat_model.batch([x]*n, temperature=temperature, top_k=top_k, top_p=top_p)
            lambda x:  [copy.deepcopy(x) for _ in range(n)],
            # lambda x: llmresult_to_aimessages(chat_model.generate_prompt([chat_model._convert_input(x)], **kwargs)),
        )
        | sampling_model.map()
    ).with_config({"run_name": "chat-sampling"})

sampling_chain = build_sampling_llm_chain(chat_model, SamplingConfig(samples=3))
sampling_chain.invoke("What is the capital of the U.S.?")
# Out:
# [AIMessage(content='The capital of the U.S. is Washington, D.C.'),
#  AIMessage(content='The capital of the U.S. is Washington, D.C.'),
#  AIMessage(content='The capital of the United States is Washington, D.C. (District of Columbia).')]

# %% [markdown]
# ## Basic RAG

# %%
from operator import itemgetter
from langchain_core.prompts import ChatPromptTemplate, BasePromptTemplate, format_document
from langchain.schema import Document
from functools import partial

document_prompt_template = """---
NAME: {source}
PAGE: {page_number}
PASSAGE:
{page_content}
---"""

DEFAULT_DOCUMENT_PROMPT = PromptTemplate.from_template(document_prompt_template)

rag_prompt_template = """\
Answer the question based only on the following context of the board game \
rules. Do not use any other information.

----
{context}
----

Question: {question}
Let's think step by step.
"""

DEFAULT_RAG_PROMPT = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert at board games. Board game players ask you questions about board games, and you provide succinct answers in your own words."),
        ("human", rag_prompt_template),
    ]
)

follow_up_prompt_template = """\
Now revise your answer. Be concise and remove any unrelated information to the question.
"""

follow_up_prompt = ChatPromptTemplate.from_messages(
    [
        ("assistant", "{answer}"),
        ("human", follow_up_prompt_template)
    ]
)

def _combine_documents(
    docs, document_prompt=DEFAULT_DOCUMENT_PROMPT, document_separator="\n"
):
    doc_strings = [format_document(doc, document_prompt) for doc in docs]
    return document_separator.join(doc_strings)

def build_basic_rag_chain(retriever_chain, chat_model, sampling_chain=None, prompt=DEFAULT_RAG_PROMPT, document_prompt=DEFAULT_DOCUMENT_PROMPT):
    if sampling_chain is None:
        sampling_chain = chat_model

    followup_chain = prompt+follow_up_prompt | chat_model

    def is_multiple_answers(x):
        return isinstance(x["answer"], list)
    
    def duplicate_dict_for_each_answer(x):
        return [{**x, "answer": answer} for answer in x["answer"]]

    followup_branch = RunnableBranch(
        (
            is_multiple_answers, 
            RunnableLambda(duplicate_dict_for_each_answer) | followup_chain.map()
        ),
        followup_chain,
    )

    # context_chain = itemgetter("question") | retriever | _combine_documents
    return (
        RunnablePassthrough.assign(
            documents=itemgetter("question") | retriever_chain
        )
        | RunnablePassthrough.assign(
            context=RunnableLambda(itemgetter("documents")) | partial(_combine_documents, document_prompt=document_prompt)
        )
        | RunnablePassthrough.assign(
            answer=RunnablePassthrough() | prompt | sampling_chain
        )
        | RunnablePassthrough.assign(
            answer=followup_branch
        )
    ).with_config({"run_name": "basic-rag-chain"})

# %%
retriever_chain = (
    retriever
    | RunnableLambda(lambda documents: documents[:5])
)
basic_rag_chain = build_basic_rag_chain(retriever_chain, chat_model.with_config({"callbacks": [ConsoleCallbackHandler()]}))
result = basic_rag_chain.invoke({"question": "Can I play a Go Up a Level card during combat?"})
print("Question:")
print(result["question"])
print()
print()
print("Context:")
print(result["context"])
print()
print()
print("Answer:")
print(result["answer"])
# Out:
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an expert at board games. Board game players ask you questions about board games, and you provide succinct answers in your own words.\nHuman: Answer the question based only on the following context of the board game rules. Do not use any other information.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get a monster card any other way, it goes into your hand and may be played during your own turn to Look For Trouble, or playe ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [1.40s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "First, let's look at the general rules for when you can play cards. On page 2, it says that you may perform these actions at any time:\n- Play a Go Up a Level or Hireling.\n\nThis means that you can indeed play a Go Up a Level card during combat, as it is listed as an action that can be performed at any time.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "First, let's look at the general rules for when you can play cards. On page 2, it says that you may perform these actions at any time:\n- Play a Go Up a Level or Hireling.\n\nThis means that you can indeed play a Go Up a Level card during combat, as it is listed as an action that can be performed at any time."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an expert at board games. Board game players ask you questions about board games, and you provide succinct answers in your own words.\nHuman: Answer the question based only on the following context of the board game rules. Do not use any other information.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get a monster card any other way, it goes into your hand and may be played during your own turn to Look For Trouble, or playe ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Yes, you can play a Go Up a Level card during combat, as it is an action that can be performed at any time.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Yes, you can play a Go Up a Level card during combat, as it is an action that can be performed at any time."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# Question:
# Can I play a Go Up a Level card during combat?
#
#
# Context:
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 3
# PASSAGE:
# "ONE-SHOT” TREASURES
# A Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.
# One-shot Items with a Gold Piece value may be sold for levels, just like other Items.
#
# OTHER TREASURES
# Other Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!
# Hireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 1
# PASSAGE:
# Conflicts Between Cards and Rules
# This rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!
# iL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.
# 2. You go up a level after combat only if you Ail a monster.
# 3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.
# 4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.
# Any other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.
#
# STEVE JACKSON GAMES
# Your Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).
# Cards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 2
# PASSAGE:
# When You May Take Actions
# You may perform these actions at any time: & Discard a Class or Race.
# & Play a Go Up a Level or Hireling. Play a Curse.
# You may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).
# y Change which Items you have equipped.
# Play a card that you have just received (some cards may be played even during combat; see above).
# You may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).
# we Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 4
# PASSAGE:
# MONSTERS
# If drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.
# If you get a monster card any other way, it goes into your hand and may be played during your own turn to Look For Trouble, or played to join another player's fight with the Wandering Monster card. (See Fighting Multiple Monsters, below.)
# Each monster card is a single monster, even if the name on the card is plural. had ) , ‘y
#
# MONSTER ENHANCERS
# Certain cards, called monster enhancers, raise or lower the combat strength of individual monsters. (Penalties to monsters are still considered enhancers.) They also affect the number of Treasures the monsters are worth. monster enhancers may be played by any player during any combat.
# All enhancers on a single monster add together. If there are multiple monsters in a combat, the person who plays each enhancer must choose which monster it applies to.
# Exception: Anything that enhances a monster also enhances its Mate . . . if Ancient, Enraged, and Mate are played ona single monster, in any order, you are facing an Ancient Enraged monster and its Ancient Enraged Mate.
#
# Good luck .. .
#
# FIGHTING MULTIPLE MONSTERS
# Some cards (such as Wandering Monster) allow your rivals to send other monsters to join the fight. You must defeat their combined combat strengths. Any special abilities, such as forcing you to fight with your Level only, apply to the entire fight. If you have the right cards, you can eliminate one monster from the combat and fight the other(s) normally, but you cannot choose to fight one and Run Away from the other(s). If you eliminate one monster, but then run from the other(s), you don’t get any levels or Treasure!
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 3
# PASSAGE:
# COMBAT
# To fight a monster, compare its combat strength to yours. Combat strength is the total of Level plus all modifiers - positive or negative - given by Items and other cards. If the monster's combat strength is equal to yours, or greater, you lose the combat and must Run Away (see p. 5). If your combat strength totals more than the monster's — note that monsters win ties! — you kill it and goupa level (two levels for some big monsters). You'll also get the number of Treasures shown on its card.
# Sometimes a card will let you get rid of the monster without killing it. This is still “winning,” but you don't get a level. Unless the ability says otherwise, you don’t get the Treasures, either. If the last monster is removed from a combat, it ends instantly.
# Some monster cards have special powers that affect combat — a bonus against a Race or Class, for instance. Be sure to check these!
# You and the other players may play one-shot Treasures or use Class or Race abilities to help or harm you in your combat. Some Door cards may also be played into a combat, such as monster enhancers (see below).
# If you kill a monster (or monsters!), discard the monster(s) and any other cards played, and claim your rewards. But note: someone may play a hostile card on you, or use a special power, just as you think you have won. When you kill a monster, you must wait a reasonable time, defined as about 2.6 seconds, for anyone else to speak up. After that, you have really killed the monster, and you really get the level(s) and Treasures, though they can still whine and argue.
# ---
#
#
# Answer:
# content='Yes, you can play a Go Up a Level card during combat, as it is an action that can be performed at any time.'

# %% [markdown]
# ## Universal Self-Consistency
# https://arxiv.org/abs/2311.17311

# %%
from typing import List
from langchain.output_parsers import RegexParser

response_prompt_template = """{page_content}"""

consensus_prompt_template = """\
I have generated the following responses to the question: {question}

{context}

Evaluate these responses.
Select the most consistent response based on majority consensus.
Start your answer with "The most consistent response is Response X" (without \
quotes)
"""

DEFAULT_CONSENSUS_DOCUMENT_PROMPT = PromptTemplate.from_template(
    response_prompt_template
)

DEFAULT_CONSENSUS_PROMPT = ChatPromptTemplate.from_template(
    consensus_prompt_template
)

response_selection_parser = RegexParser(
    regex=r"(?i)response\s+(\d+)",
    output_keys=["response_selected_index"],
)

def convert_to_document(message: AIMessage) -> Document:
    return Document(
        page_content=message.content,
    )

def format_responses(responses:List[Document], document_prompt=DEFAULT_CONSENSUS_DOCUMENT_PROMPT, document_separator="\n\n") -> str:
    formatted = [f"Response {i}\n{format_document(doc, document_prompt)}" for i, doc in enumerate(responses)]
    return document_separator.join(formatted)

def build_universal_consistency_chain(chat_model:BaseChatModel, prompt=DEFAULT_CONSENSUS_PROMPT) -> Runnable:
    chat_model_consistency = chat_model.bind(temperature=0.01, do_sample=False, max_new_tokens=1000)

    # chain that takes a list of responses and returns a formatted string combining them
    format_responses_chain = RunnableLambda(convert_to_document).map() | format_responses

    # chain that takes a question and a context and returns the index of the consensus response
    select_response_index_chain = prompt | chat_model_consistency | response_selection_parser | itemgetter(response_selection_parser.output_keys[0]) | int

    # chain that takes responses and a response_selected_index and returns the response at that index
    select_response_from_index_chain = RunnableLambda(lambda x: x["responses"][x["response_selected_index"]])

    # chain that takes a question and candiatate responses and returns the consensus response
    consistency_chain = (
        {"question": itemgetter("question"), "responses": itemgetter("responses"), "context": itemgetter("responses") | format_responses_chain}
        | RunnablePassthrough.assign(response_selected_index=select_response_index_chain)
        | select_response_from_index_chain
    )

    # chain that picks the first response if the consistency chain fails to
    # parse a response index
    fallback_chain = RunnableLambda(lambda x: x["responses"][0])

    return consistency_chain.with_fallbacks([fallback_chain], exceptions_to_handle=(ValueError, IndexError)).with_config({"run_name": "universal-consistency"})

# %%
basic_rag_chain = build_basic_rag_chain(retriever, chat_model, sampling_chain)
consistency_chain = build_universal_consistency_chain(chat_model)

result = basic_rag_chain.invoke({"question": "Can I play a Go Up a Level card during combat?"})
consistency_result = consistency_chain.invoke({
    "question": result["question"],
    "responses": result["answer"],
})

print("Question:")
print(result["question"])
print()
print()
print("Answers:")
print('\n\n'.join(answer.content for answer in result["answer"]))
print()
print()
print("Consensus answer:")
print(consistency_result.content)
# Out:
# Question:
# Can I play a Go Up a Level card during combat?
#
#
# Answers:
# Yes, you can play a Go Up a Level card during combat.
#
# Yes, you can play a Go Up a Level card during combat.
#
# Yes, you can play a Go Up a Level card during combat.
#
#
# Consensus answer:
# Yes, you can play a Go Up a Level card during combat.

# %% [markdown]
# ## RAG with Thread-of-Thought
#
# https://arxiv.org/abs/2311.08734

# %%
from langchain_core.runnables import RunnableBranch

# https://arxiv.org/abs/2311.08734


# You are an AI assistant to help boardgame players find answers to their rules \
# questions.
# Answer the question based only on the following board game rule excerpts. Do \
# not use any other information. Never use the word "excerpts" in your answer. \
# Simply refer to the context as the rules.

# As a content reviewer, I provide multiple retrieved passages about this \
# question; you need to answer the question.

# If you don't know the answer, just say that you don't know, don't try to make \
# up an answer.

thread_of_thought_template = """\
You are an AI assistant to help board game players find answers to their rule \
questions.

Answer the question based only on the following board game rule \
excerpts. Do not use any other information. Never use the word "excerpts" in \
your answer. Simply refer to the context as the rules.

----
{context}
----

Q: {question}
Walk me through this context in manageable parts step by step, summarizing and \
analyzing as we go.
"""

DEFAULT_THREAD_OF_THOUGHT_PROMPT = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an AI assistant to help board game players find answers to their rule questions."),
        ("human", thread_of_thought_template),
    ]
)

DEFAULT_THEREFORE_PROMPT = ChatPromptTemplate.from_messages(
    [
        ("assistant", "{answer}"),
        ("human", "Now revise your answer. Be concise and remove any unrelated information to the question.")
    ]
)


def thread_of_thought_combine_documents(
    docs, 
    document_prompt=DEFAULT_DOCUMENT_PROMPT, 
    document_separator="\n"
):
    formatted = [
        f"{format_document(doc, document_prompt)}" 
        for i, doc in enumerate(docs)
    ]
    return document_separator.join(formatted)


def build_thread_of_thought_rag_chain(
    retriever_chain:Runnable, 
    chat_model:BaseChatModel, 
    sampling_chain=None, 
    prompt=DEFAULT_THREAD_OF_THOUGHT_PROMPT, 
    therefore_prompt=DEFAULT_THEREFORE_PROMPT
) -> Runnable:
    chat_model = chat_model.bind(do_sample=False, max_new_tokens=1000)

    if sampling_chain is None:
        sampling_chain = chat_model
    
    # context_chain = retriever | thread_of_thought_combine_documents

    followup_chain = prompt+therefore_prompt | chat_model

    def is_multiple_answers(x):
        return isinstance(x["answer"], list)
    
    def duplicate_dict_for_each_answer(x):
        return [{**x, "answer": answer} for answer in x["answer"]]

    followup_branch = RunnableBranch(
        (
            is_multiple_answers,
            RunnableLambda(duplicate_dict_for_each_answer) | RunnableLambda(lambda x: followup_chain.batch(x))
        ),
        followup_chain,
    )

    return (
        RunnablePassthrough.assign(
            documents=itemgetter("question") | retriever_chain
        )
        | RunnablePassthrough.assign(
            context=(
                RunnableLambda(itemgetter("documents"))
                | thread_of_thought_combine_documents
            )
        )
        | RunnablePassthrough.assign(
            answer=(
                RunnablePassthrough()
                | prompt
                | sampling_chain
            )
        )
        | RunnablePassthrough.assign(
            answer=followup_branch
        )

    ).with_config({"run_name": "thread-of-thought"})

# %%
retriever_chain = (
    retriever
    | RunnableLambda(lambda documents: documents[:5])
)

thread_of_thought_rag = build_thread_of_thought_rag_chain(
    retriever_chain,
    chat_model.with_config({'callbacks': [ConsoleCallbackHandler()]})
)
result = thread_of_thought_rag.invoke(
    {"question": "Can I play a Go Up a Level card during combat?"}
)
print("Question:")
print(result["question"])
print()
print()
print("Context:")
print(result["context"])
print()
print()
print("Answer:")
print(result["answer"])
# Out:
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "First, let's identify the relevant information from the provided rules excerpts. The question is asking if a player can play a Go Up a Level card during combat. We need to find the information about when Go Up a Level cards can be played.\n\n1. In the first excerpt on page 3, it discusses One-shot Treasures, but it does not specifically mention Go Up a Level cards. So, we cannot find the answer here.\n2. In the second excerpt on page 1, it talks about conflicts between cards and rules. It states that \"in most cases when the rulesheet disagrees with a card, follow the card.\" However, this passage doesn't provide specific information about Go Up a Level cards.\n3. In the third excerpt on page 2, it lists actions a player may perform at any time, during their own turn, and on any turn. Go Up a Level cards are not mentioned in this list.\n4. In the fourth excerpt on page 4, it discusses fighting multiple monsters and monster enhancers, but neither of these sections mention Go Up a Level cards.\n5. Finally, in the fifth excerpt on page 3, it discusses combat. It states that \"some Door cards may also be played into a combat, such as monster enhancers.\" However, it does not specifically mention Go Up a Level cards in this context.\n\nBased on the information provided, we cannot determine if a player can play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "First, let's identify the relevant information from the provided rules excerpts. The question is asking if a player can play a Go Up a Level card during combat. We need to find the information about when Go Up a Level cards can be played.\n\n1. In the first excerpt on page 3, it discusses One-shot Treasures, but it does not specifically mention Go Up a Level cards. So, we cannot find the answer here.\n2. In the second excerpt on page 1, it talks about conflicts between cards and rules. It states that \"in most cases when the rulesheet disagrees with a card, follow the card.\" However, this passage doesn't provide specific information about Go Up a Level cards.\n3. In the third excerpt on page 2, it lists actions a player may perform at any time, during their own turn, and on any turn. Go Up a Level cards are not mentioned in this list.\n4. In the fourth excerpt on page 4, it discusses fighting multiple monsters and monster enhancers, but neither of these sections mention Go Up a Level cards.\n5. Finally, in the fifth excerpt on page 3, it discusses combat. It states that \"some Door cards may also be played into a combat, such as monster enhancers.\" However, it does not specifically mention Go Up a Level cards in this context.\n\nBased on the information provided, we cannot determine if a player can play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [1.02s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Based on the provided excerpts, we cannot determine if a player can play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Based on the provided excerpts, we cannot determine if a player can play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# Question:
# Can I play a Go Up a Level card during combat?
#
#
# Context:
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 3
# PASSAGE:
# "ONE-SHOT” TREASURES
# A Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.
# One-shot Items with a Gold Piece value may be sold for levels, just like other Items.
#
# OTHER TREASURES
# Other Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!
# Hireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 1
# PASSAGE:
# Conflicts Between Cards and Rules
# This rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!
# iL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.
# 2. You go up a level after combat only if you Ail a monster.
# 3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.
# 4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.
# Any other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.
#
# STEVE JACKSON GAMES
# Your Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).
# Cards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 2
# PASSAGE:
# When You May Take Actions
# You may perform these actions at any time: & Discard a Class or Race.
# & Play a Go Up a Level or Hireling. Play a Curse.
# You may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).
# y Change which Items you have equipped.
# Play a card that you have just received (some cards may be played even during combat; see above).
# You may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).
# we Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 4
# PASSAGE:
# MONSTERS
# If drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.
# If you get a monster card any other way, it goes into your hand and may be played during your own turn to Look For Trouble, or played to join another player's fight with the Wandering Monster card. (See Fighting Multiple Monsters, below.)
# Each monster card is a single monster, even if the name on the card is plural. had ) , ‘y
#
# MONSTER ENHANCERS
# Certain cards, called monster enhancers, raise or lower the combat strength of individual monsters. (Penalties to monsters are still considered enhancers.) They also affect the number of Treasures the monsters are worth. monster enhancers may be played by any player during any combat.
# All enhancers on a single monster add together. If there are multiple monsters in a combat, the person who plays each enhancer must choose which monster it applies to.
# Exception: Anything that enhances a monster also enhances its Mate . . . if Ancient, Enraged, and Mate are played ona single monster, in any order, you are facing an Ancient Enraged monster and its Ancient Enraged Mate.
#
# Good luck .. .
#
# FIGHTING MULTIPLE MONSTERS
# Some cards (such as Wandering Monster) allow your rivals to send other monsters to join the fight. You must defeat their combined combat strengths. Any special abilities, such as forcing you to fight with your Level only, apply to the entire fight. If you have the right cards, you can eliminate one monster from the combat and fight the other(s) normally, but you cannot choose to fight one and Run Away from the other(s). If you eliminate one monster, but then run from the other(s), you don’t get any levels or Treasure!
# ---
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 3
# PASSAGE:
# COMBAT
# To fight a monster, compare its combat strength to yours. Combat strength is the total of Level plus all modifiers - positive or negative - given by Items and other cards. If the monster's combat strength is equal to yours, or greater, you lose the combat and must Run Away (see p. 5). If your combat strength totals more than the monster's — note that monsters win ties! — you kill it and goupa level (two levels for some big monsters). You'll also get the number of Treasures shown on its card.
# Sometimes a card will let you get rid of the monster without killing it. This is still “winning,” but you don't get a level. Unless the ability says otherwise, you don’t get the Treasures, either. If the last monster is removed from a combat, it ends instantly.
# Some monster cards have special powers that affect combat — a bonus against a Race or Class, for instance. Be sure to check these!
# You and the other players may play one-shot Treasures or use Class or Race abilities to help or harm you in your combat. Some Door cards may also be played into a combat, such as monster enhancers (see below).
# If you kill a monster (or monsters!), discard the monster(s) and any other cards played, and claim your rewards. But note: someone may play a hostile card on you, or use a special power, just as you think you have won. When you kill a monster, you must wait a reasonable time, defined as about 2.6 seconds, for anyone else to speak up. After that, you have really killed the monster, and you really get the level(s) and Treasures, though they can still whine and argue.
# ---
#
#
# Answer:
# content='Based on the provided excerpts, we cannot determine if a player can play a Go Up a Level card during combat.'

# %% [markdown]
# ## Glue Code

# %%
from typing import Union

RetrieverWithAddDocuments = Union[ParentDocumentRetriever, VectorStoreRetrieverWithTextSplitter]

# %%
@dataclass
class RagChainConfig:
    rag_prompt:PromptTemplate = DEFAULT_RAG_PROMPT
    thread_of_thought_enabled:bool = True
    thread_of_thought_prompt:PromptTemplate = DEFAULT_THREAD_OF_THOUGHT_PROMPT
    thread_of_thought_therefore_prompt:PromptTemplate = DEFAULT_THEREFORE_PROMPT
    consensus_prompt:PromptTemplate = DEFAULT_CONSENSUS_PROMPT
    number_of_documents:int = 5
    use_self_consistency:bool = True


def build_rag_chain(
    chat_model:BaseChatModel,
    sampling_chain:Runnable,
    retriever:RetrieverWithAddDocuments,
    config:RagChainConfig,
) -> Runnable:
    if not config.use_self_consistency:
        sampling_chain = None

    retriever_chain = (
        retriever
        | RunnableLambda(lambda documents: documents[:config.number_of_documents])
    )

    if config.thread_of_thought_enabled:
        rag_chain = build_thread_of_thought_rag_chain(
            retriever_chain=retriever_chain,
            chat_model=chat_model,
            sampling_chain=sampling_chain,
            prompt=config.thread_of_thought_prompt,
            therefore_prompt=config.thread_of_thought_therefore_prompt,
        )
    else:
        rag_chain = build_basic_rag_chain(
            retriever_chain=retriever_chain,
            chat_chain=sampling_chain if sampling_chain else chat_model,
            prompt=config.rag_prompt,
        )
    
    if config.use_self_consistency:
        consistency_chain = build_universal_consistency_chain(chat_model, prompt=config.consensus_prompt)

        consistency_chain = (
            {"question": itemgetter("question"), "responses": itemgetter("answer")}
            | consistency_chain
        )

        rag_chain = (
            rag_chain
            | RunnablePassthrough.assign(
                answer=consistency_chain
            )
        )

    return rag_chain

# %%
def build_complete_chain(
        chat_model, 
        tokenizer, 
        vectorstore,
        retriever_config:RetrieverConfig, 
        sampling_config:SamplingConfig, 
        rag_config:RagChainConfig
) -> Tuple[RetrieverWithAddDocuments, Runnable]:
    retriever = build_retriever(tokenizer, vectorstore, retriever_config)
    sampling_chain = build_sampling_llm_chain(chat_model, sampling_config)
    rag_chain = build_rag_chain(chat_model, sampling_chain, retriever, rag_config)
    full_chain = {"question": RunnablePassthrough()} | rag_chain

    return retriever, full_chain

# %%
chat_model.callbacks = [ConsoleCallbackHandler()]

# Reset the vectorstore so we can add the documents again with the appropriate
# chunk sizes. Unfortunately, we can't just instantiate a new instance of Chroma
# as that seems to just create a new instance of the same vectorstore. Also, we
# cannot just delete the collection and then resuse the same instance, as then
# we will get an error about the collection not existing >:( so we have to both
# delete the collection and create a new instance. How annoying.
if isinstance(db, Chroma):
    try:
        db.delete_collection()
    except ValueError:
        # we might have already delete it. Good for us!
        pass

db = build_vectorstore(load_embedding_model(faiss_embedding_model_name))



retriever, complete_chain = build_complete_chain(
    chat_model=chat_model,
    tokenizer=tokenizer,
    vectorstore=db,
    retriever_config=RetrieverConfig(),
    sampling_config=SamplingConfig(
        temperature=0.7,
        samples=5,
    ),
    rag_config=RagChainConfig(
        thread_of_thought_enabled=True
    ),
)

retriever.add_documents(rule_docs)

query = "Can I play a Go Up a Level card during combat?"
result = complete_chain.invoke(query)

print("Question:")
print(result["question"])
print()
print()
print("Answer:")
print(result["answer"].content)
# Out:
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [5.75s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "First, let's look at the part of the rules related to when you may play a Go Up a Level card:\n\n\"When You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race. & Play a Go Up a Level or Hireling. Play a Curse. You may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either). & Change which Items you have equipped. Play a card that you have just received (some cards may be played even during combat; see above).\"\n\nFrom the passage above, we can see that playing a Go Up a Level card is an action that can be performed at any time, including during combat.\n\nSo, based on the rules, you can play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "First, let's look at the part of the rules related to when you may play a Go Up a Level card:\n\n\"When You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race. & Play a Go Up a Level or Hireling. Play a Curse. You may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either). & Change which Items you have equipped. Play a card that you have just received (some cards may be played even during combat; see above).\"\n\nFrom the passage above, we can see that playing a Go Up a Level card is an action that can be performed at any time, including during combat.\n\nSo, based on the rules, you can play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [6.29s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "First, let's find the relevant information in the context. The question asks if it's possible to play a Go Up a Level card during combat. The part of the context that might answer this question is on page 1 (under \"When You May Take Actions\") and page 2 (under \"Actions at any time\").\n\nFrom page 1:\n\"You may perform these actions at any time: [...] Play a card that you have just received (some cards may be played even during combat; see above).\"\n\nFrom page 2:\n\"You may perform these actions on your own turn: 3 Play a new Class or Race [...]\n4 Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\"\n\nNow, let's analyze this information:\n\n1. Go Up a Level cards are mentioned as one of the cards that can be played during combat.\n2. Go Up a Level cards are not specifically mentioned as something that cannot be played during combat.\n\nBased on this analysis, we can conclude that, according to the provided rules, it is possible to play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "First, let's find the relevant information in the context. The question asks if it's possible to play a Go Up a Level card during combat. The part of the context that might answer this question is on page 1 (under \"When You May Take Actions\") and page 2 (under \"Actions at any time\").\n\nFrom page 1:\n\"You may perform these actions at any time: [...] Play a card that you have just received (some cards may be played even during combat; see above).\"\n\nFrom page 2:\n\"You may perform these actions on your own turn: 3 Play a new Class or Race [...]\n4 Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\"\n\nNow, let's analyze this information:\n\n1. Go Up a Level cards are mentioned as one of the cards that can be played during combat.\n2. Go Up a Level cards are not specifically mentioned as something that cannot be played during combat.\n\nBased on this analysis, we can conclude that, according to the provided rules, it is possible to play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [6.41s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The question is: \"Can I play a Go Up a Level card during combat?\"\n\nTo answer this question, we need to find the relevant information in the provided context.\n\n1. First, let's find the relevant passage about Go Up a Level cards. In the passage on page 1, it states: \"Go Up a Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played.\"\n\n2. Now, we need to determine if this information is applicable during combat. In the passage on page 2, under \"Actions you may perform on your own turn,\" it states: \"Play a card that you have just received (some cards may be played even during combat; see above).\"\n\n3. In the passage on page 3 about \"one-shot” treasures, it states: \"A Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table.\"\n\n4. Based on the information found in the context, we can conclude that Go Up a Level cards can be played during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The question is: \"Can I play a Go Up a Level card during combat?\"\n\nTo answer this question, we need to find the relevant information in the provided context.\n\n1. First, let's find the relevant passage about Go Up a Level cards. In the passage on page 1, it states: \"Go Up a Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played.\"\n\n2. Now, we need to determine if this information is applicable during combat. In the passage on page 2, under \"Actions you may perform on your own turn,\" it states: \"Play a card that you have just received (some cards may be played even during combat; see above).\"\n\n3. In the passage on page 3 about \"one-shot” treasures, it states: \"A Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table.\"\n\n4. Based on the information found in the context, we can conclude that Go Up a Level cards can be played during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [6.75s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Q: Can I play a Go Up a Level card during combat?\n\nA: No, you cannot play a Go Up a Level card during combat.\n\nWalk me through this context in manageable parts step by step, summarizing and analyzing as we go.\n\nStep 1: Identify the question\nThe question is asking whether it is allowed to play a Go Up a Level card during combat in the game Munchkin.\n\nStep 2: Locate the relevant information in the provided context\nThe context contains three pages of rules for the game Munchkin, and we need to find the specific rule regarding playing Go Up a Level cards during combat.\n\nStep 3: Analyze the relevant rule\nThe relevant rule is found on Page 1 of the context: \"You may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either). & Play a card that you have just received (some cards may be played even during combat; see above).\"\n\nStep 4: Summarize the answer\nBased on the rule provided, Go Up a Level cards can be played when you are not in combat. Since combat is mentioned as a restriction, it means that you cannot play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Q: Can I play a Go Up a Level card during combat?\n\nA: No, you cannot play a Go Up a Level card during combat.\n\nWalk me through this context in manageable parts step by step, summarizing and analyzing as we go.\n\nStep 1: Identify the question\nThe question is asking whether it is allowed to play a Go Up a Level card during combat in the game Munchkin.\n\nStep 2: Locate the relevant information in the provided context\nThe context contains three pages of rules for the game Munchkin, and we need to find the specific rule regarding playing Go Up a Level cards during combat.\n\nStep 3: Analyze the relevant rule\nThe relevant rule is found on Page 1 of the context: \"You may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either). & Play a card that you have just received (some cards may be played even during combat; see above).\"\n\nStep 4: Summarize the answer\nBased on the rule provided, Go Up a Level cards can be played when you are not in combat. Since combat is mentioned as a restriction, it means that you cannot play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [6.92s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Step 1: Identify the rule question\nThe question is asking if you can play a Go Up a Level card during combat.\n\nStep 2: Locate the relevant rule excerpts\nWe need to find the rules related to playing Go Up a Level cards and during combat.\n\nPassage: \"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\n\nPassage: WHEN YOU MAY TAKE ACTIONS\nYou may perform these actions at any time: & Play a Go Up a Level or Hireling.\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\n\nStep 3: Analyze the relevant rule excerpts\nThe first passage states that one-shot Treasures, including Go Up a Level cards, can be played during combat. The second passage states that you can play a Go Up a Level card at any time, which includes during your own turn in combat.\n\nStep 4: Answer the rule question\nBased on the given rules, you can play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Step 1: Identify the rule question\nThe question is asking if you can play a Go Up a Level card during combat.\n\nStep 2: Locate the relevant rule excerpts\nWe need to find the rules related to playing Go Up a Level cards and during combat.\n\nPassage: \"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\n\nPassage: WHEN YOU MAY TAKE ACTIONS\nYou may perform these actions at any time: & Play a Go Up a Level or Hireling.\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\n\nStep 3: Analyze the relevant rule excerpts\nThe first passage states that one-shot Treasures, including Go Up a Level cards, can be played during combat. The second passage states that you can play a Go Up a Level card at any time, which includes during your own turn in combat.\n\nStep 4: Answer the rule question\nBased on the given rules, you can play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nMONSTERS\nIf drawn face-up, during the Kick Open The Door phase, monsters immediately attack the person who drew them.\nIf you get ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [1.70s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Yes, you can play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Yes, you can play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [2.59s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "You can play a Go Up a Level card during combat as it is a one-shot Treasure and can be played at any time.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "You can play a Go Up a Level card during combat as it is a one-shot Treasure and can be played at any time."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [3.52s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "A: No, you cannot play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "A: No, you cannot play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [4.28s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Yes, you can play a Go Up a Level card during combat, as it is mentioned among the cards that can be played during combat in the provided rules.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Yes, you can play a Go Up a Level card during combat, as it is mentioned among the cards that can be played during combat in the provided rules."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [4.39s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Yes, you can play a Go Up a Level card during combat.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Yes, you can play a Go Up a Level card during combat."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: I have generated the following responses to the question: Can I play a Go Up a Level card during combat?\n\nResponse 0\nYes, you can play a Go Up a Level card during combat.\n\nResponse 1\nYes, you can play a Go Up a Level card during combat, as it is mentioned among the cards that can be played during combat in the provided rules.\n\nResponse 2\nA: No, you cannot play a Go Up a Level card during combat.\n\nResponse 3\nYou can play a Go Up a Level card during combat as it is a one-shot Treasure and can be played at any time.\n\nResponse 4\nYes, you can play a Go Up a Level card during combat.\n\nEvaluate these responses.\nSelect the most consistent response based on majority consensus.\nStart your answer with \"The most consistent response is Response X\" (without quotes)"
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The most consistent response is Response 1.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The most consistent response is Response 1."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# Question:
# Can I play a Go Up a Level card during combat?
#
#
# Answer:
# Yes, you can play a Go Up a Level card during combat, as it is mentioned among the cards that can be played during combat in the provided rules.

# %%
db.similarity_search("Can I play a Super Munchkin card without a class card?")
# Out:
# [Document(page_content='SUPER MUNCHKIN AND HALF-BREED\nThese cards may be played whenever it is legal to play a Class or Race, as long as you have an appropriate card (Class for Super Munchkin, Race for Half-Breed) to attach it to. You cannot have more than one of the same Class or Race card in play at once.', metadata={'page_number': 2, 'source': 'munchkin_rules/munchkin_rules-1.pdf', 'doc_id': '25cd2061-e21f-4b77-8858-9f734a723ae7'}),
#  Document(page_content='If you play Super Munchkin while you have two Classes, you have all the normal advantages and disadvantages of both Classes. (All of the above is also true for', metadata={'page_number': 2, 'source': 'munchkin_rules/munchkin_rules-1.pdf', 'doc_id': '25cd2061-e21f-4b77-8858-9f734a723ae7'}),
#  Document(page_content="You can discard a Class card at any time, even in combat: “I don't wanna be a wizard anymore.” When you discard a Class card, you become classless until you play another Class card.\nYou may not belong to more than one class at once unless you play the Super Munchkin card.\nRace: Characters may be Humans, Elves, Dwarves, or Halflings. If you have no Race card in front of you, you are human.", metadata={'page_number': 2, 'source': 'munchkin_rules/munchkin_rules-1.pdf', 'doc_id': '30eae818-782a-4dba-88ed-061ccd423458'}),
#  Document(page_content='If you play Super Munchkin with one Class, you get all the advantages of being that Class (the ability to equip Class-only Items, monsters with penalties against that', metadata={'page_number': 2, 'source': 'munchkin_rules/munchkin_rules-1.pdf', 'doc_id': '25cd2061-e21f-4b77-8858-9f734a723ae7'})]

# %% [markdown]
# ## Evaluating

# %%
test_cases = [
    {
        "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
        "answer": "No, you cannot loot the room."
    },
    {
        "query": "Can I sell items from my hand to go up a level, assuming I can sell 1,000 gold pieces worth?",
        "answer": "Yes. You can sell items from your hand to go up a level."
    },
    {
        "query": "If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?",
        "answer": "No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play."
    },
    {
        "query": "Can I have multiple steeds equipped at the same time?",
        "answer": "No. You can only have one steed equipped at a time."
    },
    {
        "query": "Can I play a Go Up a Level card during combat on my turn?",
        "answer": "Yes. You can play a Go Up a Level card at any time."
    },
    {
        "query": "How many players can join me in a combat?",
        "answer": "Only one player can join you in combat."
    },
    {
        "query": "Does a player retain their princess card in play if they die?",
        "answer": "Yes. A player retains their princess card in play if they die."
    },
    {
        "query": "Can I carry multiple big items so long as only one is equipped?",
        "answer": "No. You can only carry one big item at a time."
    },
    {
        "query": "What is an item in play but not equipped called?",
        "answer": "An item in play but not equipped is called a carried item."
    },
    {
        "query": "If after breaking down the door I draw a steed face up, what are my options?",
        "answer": "You can put the steed into your hand, equip it, or treat as a monster and fight it."
    },
    {
        "query": "When can I play a Super Munchkin card?",
        "answer": "You can play a Super Munchkin card whenever it is legal to play a Class card."
    },
    {
        "query": "Can I play a Super Munchkin card without a class card?",
        "answer": "No, you must have a class card to attach it to."
    },
    {
        "query": "What cards can I trade with other players?",
        "answer": "You can trade any item cards in play (on the table) with other players."
    },
    {
        "query": "When can I player a Hireling?",
        "answer": "At any time."
    },
    {
        "query": "Can I play a Hireling card if I already have a Hireling in play?",
        "answer": "No. You can only have one Hireling in play at a time."
    },
    {
        "query": "When I loot the room, is the door card drawn face up or face down?",
        "answer": "The door card is drawn face down."
    },
    {
        "query": "Can I use a card to compel another player to help me in combat if winning that combat would give me the winning level?",
        "answer": "No. You cannot compel another player to get the winning level."
    },
    {
        "query": "Can I play a Go Up a Level card on another player?",
        "answer": "Yes."
    },
    {
        "query": "Can I play a Curse while in combat?",
        "answer": "Yes. A curse may be played at any time."
    },
    {
        "query": "How can I get rid of my Class card?",
        "answer": "You can discard your Class card at any time."
    },
    {
        "query": "When can I discard a Race card?",
        "answer": "You can discard your Race card at any time."
    }
]

# %%
from langchain.evaluation.qa.eval_chain import QAEvalChain, CotQAEvalChain
from langchain_core.output_parsers.string import StrOutputParser
import copy

eval_template = """You are a teacher grading a quiz.
You are given a question, the student's answer, and the true answer, and are \
asked to score the student answer as either CORRECT or INCORRECT.
Write out in a step by step manner your reasoning to be sure that your \
conclusion is correct. Avoid simply stating the correct answer at the outset.
The student answer may contain additional information, it may also provide \
clarifications and exceptions to the true answer, so long as it does not \
contradict the true asnwer. If the student answer fails to provide an answer \
claiming that the rules are unclear or do not provide sufficient informatn, \
then the student answer receives a grade of incorrect.
There is no partial credit. Answers are either CORRECT or INCORRECT.
At the end, always output "GRADE: CORRECT" or "GRADE: INCORRECT" (without the \
quotes) to indicate your final conclusion on a line all by itself.

Example Format:
QUESTION: question here
STUDENT ANSWER: student's answer here
TRUE ANSWER: true answer here
EXPLANATION: step by step reasoning here
GRADE: CORRECT or INCORRECT here

Grade the student answers based ONLY on their factual accuracy with respect to \
the true answer. Ignore differences in punctuation and phrasing between the \
student answer and true answer. Begin! 

QUESTION: Can I carry multiple big items so long as only one is equipped?
STUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.
TRUE ANSWER: No. You can only carry one big item at a time.
EXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.
GRADE: INCORRECT

QUESTION: How many players can join me in a combat?
STUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.
TRUE ANSWER: Only one player can join you in combat.
EXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.
GRADE: INCORRECT

QUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?
STUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.
TRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.
EXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.
GRADE: CORRECT

QUESTION: When can I discard a Race card?
STUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.
TRUE ANSWER: You can discard your Race card at any time.
EXPLANATION: The true answer states that you can discard your race at any time. The student answer suggests scenarios in which a race card might be discarded, but fails to mention the race card may be discarded at any time. Therefore, the student answer is incorrect.
GRADE: INCORRECT

QUESTION: What is an item in play but not equipped called?
STUDENT ANSWER: In Munchkin, an item that is in play but not equipped is referred to as an item turned sideways. These items are not being used during gameplay.
TRUE ANSWER: An item in play but not equipped is called a carried item.
EXPLANATION: The true answer states that an item in play but not equipped is called a carried item. The student answer makes no mention of a "carried item". Therefore, the student answer is incorrect.
GRADE: INCORRECT

QUESTION: {query}
STUDENT ANSWER: {result}
TRUE ANSWER: {answer}
EXPLANATION:"""
eval_prompt = PromptTemplate(
    input_variables=["query", "result", "answer"], template=eval_template
)

def predict_answer(test_cases, chain):
    test_cases = copy.deepcopy(test_cases)
    results = chain.batch([test_case["query"] for test_case in test_cases])
    for result, test_case in zip(results, test_cases):
        # query = test_case["query"]
        # result = chain.invoke(query)
        context = None
        if isinstance(result, dict):
            context = result.get("context")
            result = result.get("answer")
        result = result.content
        test_case["result"] = result
        if context is not None:
            test_case["context"] = context
    return test_cases


def grade(test_cases, llm):
    test_cases = copy.deepcopy(test_cases)
    eval_chain = QAEvalChain.from_llm(llm, prompt=eval_prompt)
    results = eval_chain.evaluate(examples=test_cases, predictions=test_cases)
    # It looks like, once upon a time, the eval chain did this bit for us... but
    # now it doesn't? Maybe a bug? Unclear as there seem to have been other 
    # intentional changes in behavior. Anyway, we do it ourselves now.
    results = [eval_chain._prepare_output(result) for result in results]

    # Merge the test cases and results
    for test_case, result in zip(test_cases, results):
        test_case.update(result)

    return test_cases


def print_graded(graded):
    for test_case in graded:
        print("query:", test_case["query"])
        print("answer:", test_case["result"])
        print("reference:", test_case["answer"])
        print("reasoning:", test_case["reasoning"])
        print("score:", test_case["score"])
        if "expected_score" in test_case:
            print("expected_score:", test_case["expected_score"])
        print()


def get_overall_score(scores):
    return sum([score["score"] or 0 for score in scores]) / len(scores)

# %%
example_test_cases = test_cases[:1]
example_test_cases = predict_answer(example_test_cases, complete_chain)
example_test_cases = grade(example_test_cases, grader_chat_model.with_config({"callbacks": [ConsoleCallbackHandler()]}))
print_graded(example_test_cases)
# Out:
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [6.73s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "A: In the given context, we have rules from a board game called Munchkin. Let's break down the relevant information to answer the question:\n\n1. The question is about the situation where a monster does not pursue the player because their level is too low.\n2. The player wants to know if they can still \"loot the room.\"\n\nNow let's analyze the rules to find the answer:\n\n1. In the \"Turn Phases\" section (page 2), we find the \"Look For Trouble/Loot The Room\" phase (phase 2). This phase is triggered when the player did NOT draw a monster when they first opened the door. In this case, the player has two choices: either Look For Trouble or Loot The Room.\n2. There are no specific rules about the level of the player or the monster preventing the player from looting the room.\n\nBased on the rules provided, if the player did not draw a monster when they first opened the door, they can choose to Loot The Room, regardless of their level or the level of the monster.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "A: In the given context, we have rules from a board game called Munchkin. Let's break down the relevant information to answer the question:\n\n1. The question is about the situation where a monster does not pursue the player because their level is too low.\n2. The player wants to know if they can still \"loot the room.\"\n\nNow let's analyze the rules to find the answer:\n\n1. In the \"Turn Phases\" section (page 2), we find the \"Look For Trouble/Loot The Room\" phase (phase 2). This phase is triggered when the player did NOT draw a monster when they first opened the door. In this case, the player has two choices: either Look For Trouble or Loot The Room.\n2. There are no specific rules about the level of the player or the monster preventing the player from looting the room.\n\nBased on the rules provided, if the player did not draw a monster when they first opened the door, they can choose to Loot The Room, regardless of their level or the level of the monster."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [6.79s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Based on the given rules excerpts, the answer to the question is as follows:\n\n1. First, let's understand the \"Charity\" phase from the turn phases (page 2): If a player has more than five cards in their hand, they must play enough cards to get their hand count to five or below. If they cannot reduce their hand to five cards or do not want to, they must give the excess cards to the player with the lowest Level.\n\n2. Now, let's look at the \"Running Away\" section (page 5): If you fail to Run Away from a monster, it does Bad Stuff to you as described on the monster's card. This may include losing an Item, losing one or more levels, or Death.\n\n3. From the \"Combat\" section (page 3), we learn that if a player cannot defeat a monster, they must Run Away.\n\nBased on these rules, if a monster does not pursue you because your level is too low, you cannot loot the room. This is because you must first defeat the monster or Run Away from it.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Based on the given rules excerpts, the answer to the question is as follows:\n\n1. First, let's understand the \"Charity\" phase from the turn phases (page 2): If a player has more than five cards in their hand, they must play enough cards to get their hand count to five or below. If they cannot reduce their hand to five cards or do not want to, they must give the excess cards to the player with the lowest Level.\n\n2. Now, let's look at the \"Running Away\" section (page 5): If you fail to Run Away from a monster, it does Bad Stuff to you as described on the monster's card. This may include losing an Item, losing one or more levels, or Death.\n\n3. From the \"Combat\" section (page 3), we learn that if a player cannot defeat a monster, they must Run Away.\n\nBased on these rules, if a monster does not pursue you because your level is too low, you cannot loot the room. This is because you must first defeat the monster or Run Away from it."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [8.00s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "First, let's break down the context into manageable parts:\n\n1. Turn phases: The player's turn consists of phases, such as \"Kick Open The Door,\" \"Look For Trouble/Loot The Room,\" and \"Charity.\"\n2. Combat: When a player encounters a monster, they must engage in combat to either defeat or run away from the monster.\n3. Rewards: If a player defeats a monster, they gain levels and Treasure cards.\n4. Running away: If a player cannot defeat a monster or their fellow players cannot help them win, they must run away and may suffer consequences depending on the monster.\n\nNow, let's analyze the question:\n\nQ: If a monster does not pursue me because my level is too low, can I still loot the room?\n\nThe context does not explicitly state the consequences of not pursuing a monster due to a player's level being too low. However, we can infer the answer based on the information provided:\n\nSince the \"Look For Trouble/Loot The Room\" phase occurs after the \"Kick Open The Door\" phase, and the player has the option to either look for trouble or loot the room, we can conclude that the player can choose to loot the room even if the monster does not pursue them due to their level being too low.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "First, let's break down the context into manageable parts:\n\n1. Turn phases: The player's turn consists of phases, such as \"Kick Open The Door,\" \"Look For Trouble/Loot The Room,\" and \"Charity.\"\n2. Combat: When a player encounters a monster, they must engage in combat to either defeat or run away from the monster.\n3. Rewards: If a player defeats a monster, they gain levels and Treasure cards.\n4. Running away: If a player cannot defeat a monster or their fellow players cannot help them win, they must run away and may suffer consequences depending on the monster.\n\nNow, let's analyze the question:\n\nQ: If a monster does not pursue me because my level is too low, can I still loot the room?\n\nThe context does not explicitly state the consequences of not pursuing a monster due to a player's level being too low. However, we can infer the answer based on the information provided:\n\nSince the \"Look For Trouble/Loot The Room\" phase occurs after the \"Kick Open The Door\" phase, and the player has the option to either look for trouble or loot the room, we can conclude that the player can choose to loot the room even if the monster does not pursue them due to their level being too low."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [8.31s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "In the given context, the rules for Munchkin are provided in a PDF file. The rules are divided into sections, each discussing different aspects of the game. To answer the question, we need to refer to the relevant sections of the rules.\n\nThe question is: If a monster does not pursue me because my level is too low, can I still loot the room?\n\n1. First, let's look at the section discussing the turn phases. According to the rules on page 2, the turn phases are as follows:\n\n- Phase iL (1) Kick Open The Door\n- Phase 2: Look For Trouble/Loot The Room\n- Phase 3: Charity\n\n2. Now, let's analyze the specific rule related to the question: \"If you drew any other card, you may either put it in your hand or play it immediately.\"\n\n3. The question refers to a situation where the monster does not pursue the player because their level is too low. This situation is not explicitly mentioned in the rules. However, we can infer from the rules that the player would have the option to put the drawn card in their hand or play it immediately.\n\n4. The rule for looting the room does not have any restrictions based on the player's level or the monster's pursuit. Therefore, the player can loot the room even if the monster does not pursue them due to their level being too low.\n\nIn conclusion, based on the given context and the rules provided, the player can still loot the room even if the monster does not pursue them because their level is too low.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "In the given context, the rules for Munchkin are provided in a PDF file. The rules are divided into sections, each discussing different aspects of the game. To answer the question, we need to refer to the relevant sections of the rules.\n\nThe question is: If a monster does not pursue me because my level is too low, can I still loot the room?\n\n1. First, let's look at the section discussing the turn phases. According to the rules on page 2, the turn phases are as follows:\n\n- Phase iL (1) Kick Open The Door\n- Phase 2: Look For Trouble/Loot The Room\n- Phase 3: Charity\n\n2. Now, let's analyze the specific rule related to the question: \"If you drew any other card, you may either put it in your hand or play it immediately.\"\n\n3. The question refers to a situation where the monster does not pursue the player because their level is too low. This situation is not explicitly mentioned in the rules. However, we can infer from the rules that the player would have the option to put the drawn card in their hand or play it immediately.\n\n4. The rule for looting the room does not have any restrictions based on the player's level or the monster's pursuit. Therefore, the player can loot the room even if the monster does not pursue them due to their level being too low.\n\nIn conclusion, based on the given context and the rules provided, the player can still loot the room even if the monster does not pursue them because their level is too low."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [9.72s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The passage provided is from a board game called Munchkin, and the rules are outlined in a PDF document. The game involves players going through various stages, fighting monsters, and gaining rewards. Here is a step-by-step analysis of the provided passage to answer the question:\n\n1. The first passage (page 2) explains the turn phases. In the first phase, the player draws a card from the Door deck. If it's a monster, they must fight it. If it's not a monster, they can either put the card in their hand or play it immediately.\n\n2. The second passage (page 2) talks about the Look For Trouble or Loot The Room phase. If the player did not draw a monster when they first opened the door, they have two choices: either Look For Trouble (fight a monster from their hand) or Loot The Room (draw a second card from the Door deck and place it in their hand).\n\n3. The third passage (page 2) discusses the Charity phase. If a player has more than five cards in their hand, they must play enough cards to get to five or below, either by playing curses, selling items, or playing items on the table. If they cannot reduce their hand to five cards or do not want to, they must give excess cards to the player with the lowest level. If the player is the lowest or tied for the lowest, they can discard the excess cards.\n\n4. The first passage (page 1) discusses conflicts between cards and rules. The general rule is that no card can reduce a player below level 1. However, if there is a conflict between a card and the rules, the card usually takes precedence unless it explicitly says it supersedes the rule.\n\n5. The passage on page 4 discusses interfering with combat. Players can use one-shot cards, monster enhancers, add a monster from their hand, backstab, or curse to interfere with another player's combat.\n\n6. The passage on page 5 talks about rewards. When a player defeats a monster, they gain one level per monster, and they get all the Treasure cards associated with the monster. If the monster is defeated by non-lethal means, the player does not gain a level, but they might still receive the Treasure.\n\n7. The passage on",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The passage provided is from a board game called Munchkin, and the rules are outlined in a PDF document. The game involves players going through various stages, fighting monsters, and gaining rewards. Here is a step-by-step analysis of the provided passage to answer the question:\n\n1. The first passage (page 2) explains the turn phases. In the first phase, the player draws a card from the Door deck. If it's a monster, they must fight it. If it's not a monster, they can either put the card in their hand or play it immediately.\n\n2. The second passage (page 2) talks about the Look For Trouble or Loot The Room phase. If the player did not draw a monster when they first opened the door, they have two choices: either Look For Trouble (fight a monster from their hand) or Loot The Room (draw a second card from the Door deck and place it in their hand).\n\n3. The third passage (page 2) discusses the Charity phase. If a player has more than five cards in their hand, they must play enough cards to get to five or below, either by playing curses, selling items, or playing items on the table. If they cannot reduce their hand to five cards or do not want to, they must give excess cards to the player with the lowest level. If the player is the lowest or tied for the lowest, they can discard the excess cards.\n\n4. The first passage (page 1) discusses conflicts between cards and rules. The general rule is that no card can reduce a player below level 1. However, if there is a conflict between a card and the rules, the card usually takes precedence unless it explicitly says it supersedes the rule.\n\n5. The passage on page 4 discusses interfering with combat. Players can use one-shot cards, monster enhancers, add a monster from their hand, backstab, or curse to interfere with another player's combat.\n\n6. The passage on page 5 talks about rewards. When a player defeats a monster, they gain one level per monster, and they get all the Treasure cards associated with the monster. If the monster is defeated by non-lethal means, the player does not gain a level, but they might still receive the Treasure.\n\n7. The passage on"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
# ...
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [5.25s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "If a monster does not pursue a player because their level is too low, they can still choose to loot the room during their turn.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "If a monster does not pursue a player because their level is too low, they can still choose to loot the room during their turn."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [5.46s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "A: If a monster does not pursue the player because their level is too low, they can still choose to \"loot the room\" in the \"Look For Trouble/Loot The Room\" phase if they did not draw a monster when they first opened the door.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "A: If a monster does not pursue the player because their level is too low, they can still choose to \"loot the room\" in the \"Look For Trouble/Loot The Room\" phase if they did not draw a monster when they first opened the door."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [5.46s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Based on the given rules excerpts, if a monster does not pursue you because your level is too low, you cannot loot the room.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Based on the given rules excerpts, if a monster does not pursue you because your level is too low, you cannot loot the room."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: I have generated the following responses to the question: If a monster does not pursue me because my level is too low, can I still loot the room?\n\nResponse 0\nA: If a monster does not pursue the player because their level is too low, they can still choose to \"loot the room\" in the \"Look For Trouble/Loot The Room\" phase if they did not draw a monster when they first opened the door.\n\nResponse 1\nIf a monster does not pursue you because your level is too low, you cannot loot the room.\n\nResponse 2\nBased on the provided rules, if a monster does not pursue you because your level is too low, you can still loot the room.\n\nResponse 3\nBased on the given rules excerpts, if a monster does not pursue you because your level is too low, you cannot loot the room.\n\nResponse 4\nIf a monster does not pursue a player because their level is too low, they can still choose to loot the room during their turn.\n\nEvaluate these responses.\nSelect the most consistent response based on majority consensus.\nStart your answer with \"The most consistent response is Response X\" (without quotes)"
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The most consistent response is Response 2.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The most consistent response is Response 2."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/start] [1:llm:HuggingFaceChatModelWithBatchSupport] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/end] [1:llm:HuggingFaceChatModelWithBatchSupport] [19.21s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The true answer states that if a monster does not pursue you because your level is too low, you cannot loot the room. The student answer claims that you can still loot the room in this situation, which contradicts the true answer. Therefore, the student answer is incorrect.\n\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer states that only one other player can join someone in combat. The student answer claims that there is no maximum to the number of players who can join combat. Therefore, the student answer is incorrect.\n\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\n\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that if a monster does not pursue you because your level is too low, you cannot loot the room. The student answer claims that you can still loot the room in this situation, which contradicts the true answer. Therefore, the student answer is incorrect.\n\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer states that only one other player can join someone in combat. The student answer claims that there is no maximum to the number of players who can join combat. Therefore, the student answer is incorrect.\n\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\n\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# query: If a monster does not pursue me because my level is too low, can I still loot the room?
# answer: Based on the provided rules, if a monster does not pursue you because your level is too low, you can still loot the room.
# reference: No, you cannot loot the room.
# reasoning: The true answer states that if a monster does not pursue you because your level is too low, you cannot loot the room. The student answer claims that you can still loot the room in this situation, which contradicts the true answer. Therefore, the student answer is incorrect.
#
# GRADE: INCORRECT
#
# QUESTION: How many players can join me in a combat?
# STUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.
# TRUE ANSWER: Only one player can join you in combat.
# EXPLANATION: The true answer states that only one other player can join someone in combat. The student answer claims that there is no maximum to the number of players who can join combat. Therefore, the student answer is incorrect.
#
# GRADE: INCORRECT
#
# QUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?
# STUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.
# TRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.
# EXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.
#
# GRADE: CORRECT
#
# QUESTION: When can I discard a Race card?
# STUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or
# score: 0

# %% [markdown]
# ### Grade the Grader
#
# We have a set of QA pairs that have been evaluated by a human grader for
# correctness. We use these examples to compare the performance of our llm grader
# to the human grader.

# %%
if False:
    with open("grader_test_cases.json", "r") as f:
        grader_test_cases = json.loads(f.read())
    graded = grade(grader_test_cases, chat_model.bind(do_sample=False, max_new_tokens=1000))
    grader_got_wrong = [grade for grade in graded if grade["score"] != grade["expected_score"]]
    print_graded(grader_got_wrong)
    sum(1 if grade["score"] == grade["expected_score"] else 0 for grade in graded) / len(graded)
# Out:
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\nWrite out in a step by step manner your reasoning to be sure that your conclusion is correct. Avoid simply stating the correct answer at the outset.\nThe student answer may contain additional information, it may also provide clarifications and exceptions to the true answer, so long as it does not contradict the true asnwer. If the student answer fails to provide an answer claiming that the rules are unclear or do not provide sufficient informatn, then the student answer receives a grade of incorrect.\nThere is no partial credit. Answers are either CORRECT or INCORRECT.\nAt the end, always output \"GRADE: CORRECT\" or \"GRADE: INCORRECT\" (without the quotes) to indicate your final conclusion on a line all by itself.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nEXPLANATION: step by step reasoning here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy with respect to the true answer. Ignore differences in punctuation and phrasing between the student answer and true answer. Begin! \n\nQUESTION: Can I carry multiple big items so long as only one is equipped?\nSTUDENT ANSWER: A player can carry multiple big items, including Steeds, but only one can be equipped. If a player loses the ability to have more than one big item, they must correct the issue or discard all but one big item.\nTRUE ANSWER: No. You can only carry one big item at a time.\nEXPLANATION: The true answer states that you cannot carry more than one big item at a time. The student answer states a player can carray multiple big items. This contradicts the true answer. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: How many players can join me in a combat?\nSTUDENT ANSWER: In Munchkin, during combat against a monster, other players can help by adding their combat strength. Multiple players can contribute monsters to a fight using the Wandering Monster card. The player fighting the monster must defeat the combined combat strength of all the joined monsters. However, the rules do not explicitly state a maximum number of players who can contribute monsters to join a combat.\nTRUE ANSWER: Only one player can join you in combat.\nEXPLANATION: The true answer says that only one other player can join someone in combat. The student answer claims there is no maxiumum to the number of players who can join combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT\n\nQUESTION: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?\nSTUDENT ANSWER: If a Hireling is removed from play due to Bad Stuff or any other circumstances, the items the Hireling was carrying are lost, not retained by the player.\nTRUE ANSWER: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.\nEXPLANATION: The student answer explains that if a Hireling is removed from play for any reason, the items the Hireling was carrying are lost and not retained by the player. The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. Both the student answer and the true answer convey the same core information: that the player does not retain the items when the hireling is removed from play.\nGRADE: CORRECT\n\nQUESTION: When can I discard a Race card?\nSTUDENT ANSWER: To discard a Race card in Munchkin, you can do so to sell for a level, trade with another player, give to a player who wants it, power a Class or Race ability, or comply with a Curse or monster's Bad Stuff effect.\nTRUE ANSWER: You can discard your Race card at any time.\nEXPLANATION: The true answer stat ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
# ...
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that the door card is drawn face down. The student answer does not explicitly state whether the second card drawn when looting the room should be drawn face up or face down, but it does suggest that players may need to discard cards face down in certain situations. However, this does not contradict the true answer. Therefore, the student answer is correct.\nGRADE: CORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [11.86s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The true answer states that you can trade any item cards in play (on the table) with other players. The student answer correctly explains that players can trade items at any time except during combat or running away, and the best time to trade is when it is not your turn. The student answer does not contradict the true answer and provides additional information, so the student answer is correct.\n\nGRADE: CORRECT",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that you can trade any item cards in play (on the table) with other players. The student answer correctly explains that players can trade items at any time except during combat or running away, and the best time to trade is when it is not your turn. The student answer does not contradict the true answer and provides additional information, so the student answer is correct.\n\nGRADE: CORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [5.17s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The true answer states that you cannot compel another player to help you win the game. The student answer discusses how players can help each other in combat, but does not address the specific case of using a card to compel another player to help in order to gain the winning level. Therefore, the student answer is incorrect.\nGRADE: INCORRECT",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that you cannot compel another player to help you win the game. The student answer discusses how players can help each other in combat, but does not address the specific case of using a card to compel another player to help in order to gain the winning level. Therefore, the student answer is incorrect.\nGRADE: INCORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [12.05s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The true answer states that you can play a Super Munchkin card whenever it is legal to play a Class card. The student answer explains the same information, mentioning that you can have only one of the same Class or Race card in play at once, and that when you play Super Munchkin, you get the benefits of the Class you are playing, and none of the disadvantages. Both the student answer and the true answer convey the same core information: that you can play a Super Munchkin card whenever it is legal to play a Class card.\nGRADE: CORRECT",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that you can play a Super Munchkin card whenever it is legal to play a Class card. The student answer explains the same information, mentioning that you can have only one of the same Class or Race card in play at once, and that when you play Super Munchkin, you get the benefits of the Class you are playing, and none of the disadvantages. Both the student answer and the true answer convey the same core information: that you can play a Super Munchkin card whenever it is legal to play a Class card.\nGRADE: CORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [3.93s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The true answer states that you can discard your Class card at any time. The student answer explains that you can discard a Class card at any time, even in combat, and the character becomes classless until another Class card is played. Both the student answer and the true answer convey the same core information: that you can discard your Class card at any time. Therefore, the student answer is correct.\nGRADE: CORRECT",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that you can discard your Class card at any time. The student answer explains that you can discard a Class card at any time, even in combat, and the character becomes classless until another Class card is played. Both the student answer and the true answer convey the same core information: that you can discard your Class card at any time. Therefore, the student answer is correct.\nGRADE: CORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [5.49s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The true answer states that a Curse card can be played at any time. The student answer provides a lengthy explanation about the rules and effects of Curse cards, but does not directly answer the question of whether a Curse can be played during combat. The student answer does mention that Curse cards may be played on any player at any time, but this statement is not directly linked to the context of combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that a Curse card can be played at any time. The student answer provides a lengthy explanation about the rules and effects of Curse cards, but does not directly answer the question of whether a Curse can be played during combat. The student answer does mention that Curse cards may be played on any player at any time, but this statement is not directly linked to the context of combat. Therefore, the student answer is incorrect.\nGRADE: INCORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [llm/end] [1:llm:HuggingFaceChatModelLocal] [4.03s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The true answer states that a player can discard their Race card at any time. The student answer provides additional context and clarifications, such as the conditions under which a Race card may or may not be discarded, and the impact of other cards on the decision to discard a Race card. While the student answer does not contradict the true answer, it does not directly address the question. Therefore, the student answer is incorrect.\nGRADE: INCORRECT",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that a player can discard their Race card at any time. The student answer provides additional context and clarifications, such as the conditions under which a Race card may or may not be discarded, and the impact of other cards on the decision to discard a Race card. While the student answer does not contradict the true answer, it does not directly address the question. Therefore, the student answer is incorrect.\nGRADE: INCORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# query: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?
# answer: The player can play a Hireling at any time, even during combat, as long as they only have one Hireling in play at a time. If a Hireling is removed from play due to Bad Stuff, the player does not retain any items that the Hireling was carrying. Instead, the items go with the Hireling.
# reference: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.
# reasoning: The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. The student answer claims that the player does not retain any items that the Hireling was carrying, but instead, the items go with the Hireling. This contradicts the true answer, as it implies that the player retains the items, which is not the case. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
# expected_score: 1
#
# query: Can I carry multiple big items so long as only one is equipped?
# answer: In Munchkin, players can carry multiple items, including big items, but they can only equip one at a time. Big items are limited to one per player, and players must sell, trade, or lose them if they want to equip another big item. Some items have restrictions, such as the Mace of Sharpness, which can only be wielded by a Cleric. Items can be sold for levels, traded with other players, or given away to another player. The game also includes various classes and races that allow players to carry more than one big item.
# reference: No. You can only carry one big item at a time.
# reasoning: The true answer states that you can only carry one big item at a time. The student answer states that players can carry multiple items, including big items, but can only equip one at a time. Although the student answer is mostly accurate, it contradicts the true answer by suggesting that players can carry multiple big items, even if only one can be equipped. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
# expected_score: 1
#
# query: When I loot the room, is the door card drawn face up or face down?
# answer: It is not specified whether the second card drawn when looting the room should be drawn face up or face down. However, players must play enough cards to reduce their hand to five or below during the "Charity" phase, which suggests that players may need to discard cards face down. Additionally, players must give excess cards to the player with the lowest Level during this phase, so it is possible that players may need to discard cards face down to fulfill this requirement.
# reference: The door card is drawn face down.
# reasoning: The true answer states that the door card is drawn face down. The student answer does not explicitly state whether the second card drawn when looting the room should be drawn face up or face down, but it does suggest that players may need to discard cards face down in certain situations. However, this does not contradict the true answer. Therefore, the student answer is correct.
# GRADE: CORRECT
# score: 1
# expected_score: 0
#
# query: Can I play a Curse while in combat?
# answer: The passage describes the rules and effects of Curse cards in the game "The Adventure Game." If a player draws a Curse card during the Kick Open The Door phase, it applies to the person who drew it. If acquired some other way, such as by Looting The Room, Curse cards go into the player's hand and may be played on any player at any time. Curse cards can have a variety of effects, such as reducing someone's abilities, cursing an Item, or causing a player to lose Treasure. If a Curse applies to multiple Items, the player who draws the Curse gets to choose which Item is affected by the Curse. If a Curse cannot affect an Item, it will not have any effect on that Item. It's important to read the effects of each Curse carefully before playing it, as some Curses have alternate effects that may be useful in certain situations. If a Curse that applies to an Item you don't have, you don't need to worry about it. The Curse will simply be discarded and won't have any effect on you. Sometimes using a Curse or Monster card on yourself can be beneficial, especially if it will help you gain an advantage or protect yourself from an incoming threat. Similarly, helping another player in a way that costs them Treasure can also be useful, especially if you are working together as a team.
# reference: Yes. A curse may be played at any time.
# reasoning: The true answer states that a Curse card can be played at any time. The student answer provides a lengthy explanation about the rules and effects of Curse cards, but does not directly answer the question of whether a Curse can be played during combat. The student answer does mention that Curse cards may be played on any player at any time, but this statement is not directly linked to the context of combat. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
# expected_score: 1
#
# query: When can I discard a Race card?
# answer: I apologize for the confusion. To clarify, in the game of Munchkin, Race cards can be discarded at any time during the game, regardless of the current phase or state of the game. However, there are certain rules and abilities that may affect when a Race card can be discarded.
#
# For example, some cards may have abilities that allow them to be discarded and then immediately returned to the player's hand, while others may require a specific condition to be met before they can be discarded. Additionally, certain cards may have effects that prevent certain types of cards from being discarded, such as Item cards or Character cards.
#
# In general, the decision to discard a Race card is up to the player and depends on their strategy and game plan. However, it is important to be aware of any rules or abilities that may affect when a Race card can be discarded in order to make the most effective decisions during the game.
# reference: You can discard your Race card at any time.
# reasoning: The true answer states that a player can discard their Race card at any time. The student answer provides additional context and clarifications, such as the conditions under which a Race card may or may not be discarded, and the impact of other cards on the decision to discard a Race card. While the student answer does not contradict the true answer, it does not directly address the question. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
# expected_score: 1
# 0.7619047619047619

# %% [markdown]
# ### Evaluate chain

# %%
# 22m 16.4s
# 19m 50.8s
# 18m 7.9s
# 19m 50.9s
# 18m 18.1s
# 0.7619047619047619
# 2m 54s
# 6m 20s - 0.71
if False:
    predictions = predict_answer(test_cases, complete_chain)
    with open("test_cases.json", "w") as f:
        f.write(json.dumps(predictions))
    # graded = grade(predictions, chat_model)
    # print_graded(graded)
    # get_overall_score(graded)

if False:
    with open("test_cases.json", "r") as f:
        predictions = json.loads(f.read())

    graded = grade(predictions, chat_model.bind(do_sample=False, max_new_tokens=1000))
    print_graded(graded)
    get_overall_score(graded)
# Out:
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n1,000 Gold Pieces of Items to sell). Otherwise, you must give them to the lowest-Level player(s) who can carry them! If any Big items are still left over, discard them. Trading: You may trade Items (but no other cards) with other players. You may only trade Items from the table - not from your hand. You may trade at any time except when you or your trading partner are in combat — in fact, the best time to trade is when it’s not your turn, Any Ttem you receive in a trade must remain in play. You may also give Items away without a trade, to bribe other players - “Tl give you my Flaming Armor if you won't help Bob fight that dragon!” You may show your hand to others. Like we could stop you. Selling Items for Levels: At any point during your turn except during combat or Running Away, you may discard Items worth a total of at least 1,000 Gold Pieces and immediately go up one level. (“No Value” cards are the same as zero Gold Pieces.) If you discard (for instance) 1,100 Gold Pieces worth, you don't get change. But if you can manage 2,000 worth, you can go up two levels at once, and so on. You may sell Items from your hand as well as those you are carrying. You may not sell Items to go to Level 10.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\nITEMS\nMost Treasures are Items. Items have a Gold Piece value. “No Value” is equivalent to zero Gold Pieces, and a “No Value” card is considered an Item.\nAll Items you have in play are considered “carried.” Items that are actually giving you a bonus are “equipped.” You should indicate Items that are not equipped by turning the cards sideways. You may not alter the status of your Items during a combat or while running away.\nAnyone can carry any Item (except for extra Big items; see below), but you may equip only one Headgear, one suit of Armor, one pair of Footgear, and two “I Hand” Items (or one “2 Hands” Item) . . . unless you have a card that lets you ignore these limits, such as Hireling or Cheat!, or unless one of the cards says otherwise. If you are carrying two Headgear cards, for instance, you can equip only one of them at a time.\nLikewise, some Items have restrictions: for instance, the Mace of Sharpness can only be wielded by a Cleric. Its bonus only counts for someone who is, at the moment, a Cleric.\nYou cannot discard Item cards “just because.” You may sell Items for a level, trade Items with other players, o ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n1,000 Gold Pieces of Items to sell). Otherwise, you must give them to the lowest-Level player(s) who can carry them! If any Big items are still left over, discard them. Trading: You may trade Items (but no other cards) with other players. You may only trade Items from the table - not from your hand. You may trade at any time except when you or your trading partner are in combat — in fact, the best time to trade is when it’s not your turn, Any Ttem you receive in a trade must remain in play. You may also give Items away without a trade, to bribe other players - “Tl give you my Flaming Armor if you won't help Bob fight that dragon!” You may show your hand to others. Like we could stop you. Selling Items for Levels: At any point during your turn except during combat or Running Away, you may discard Items worth a total of at least 1,000 Gold Pieces and immediately go up one level. (“No Value” cards are the same as zero Gold Pieces.) If you discard (for instance) 1,100 Gold Pieces worth, you don't get change. But if you can manage 2,000 worth, you can go up two levels at once, and so on. You may sell Items from your hand as well as those you are carrying. You may not sell Items to go to Level 10.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\nITEMS\nMost Treasures are Items. Items have a Gold Piece value. “No Value” is equivalent to zero Gold Pieces, and a “No Value” card is considered an Item.\nAll Items you have in play are considered “carried.” Items that are actually giving you a bonus are “equipped.” You should indicate Items that are not equipped by turning the cards sideways. You may not alter the status of your Items during a combat or while running away.\nAnyone can carry any Item (except for extra Big items; see below), but you may equip only one Headgear, one suit of Armor, one pair of Footgear, and two “I Hand” Items (or one “2 Hands” Item) . . . unless you have a card that lets you ignore these limits, such as Hireling or Cheat!, or unless one of the cards says otherwise. If you are carrying two Headgear cards, for instance, you can equip only one of them at a time.\nLikewise, some Items have restrictions: for instance, the Mace of Sharpness can only be wielded by a Cleric. Its bonus only counts for someone who is, at the moment, a Cleric.\nYou cannot discard Item cards “just because.” You may sell Items for a level, trade Items with other players, o ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 1\nPASSAGE:\nHIRELINGS\nHirelings, Sidekicks, Monks, Minions, Comrades, and Allies are all the same for the purposes of these rules.\nHirelings are found in Door decks in some sets, Treasures in others. (In this set, they're Doors.) You can play a Hireling at any time, even in combat, as long as you have only one Hireling in play at a time. If you draw a face-up Hireling, you may put it in your hand if you cannot (or don’t want to) put it in play. You may discard a Hireling at any time.\nA Hireling is not an Item unless it has a price on it. You may only trade Hirelings that have a Gold Piece value.\nA Hireling can sacrifice himself for you. If you lose a fight, then instead of rolling to run away, you may discard one Hireling and anything he is carrying. You automatically escape from all monsters in the fight, even if a monster card says escape is impossible. If someone was helping you in the fight, YOU decide whether that person automatically escapes as well, or must roll to escape.\nSome Hirelings give you extra Hands, or let you carry an extra Big or Complex item. In this case, the Hireling does not actually have any Items . . . he merely increases your own abilities. If something happens to the Hireling, your Items are not affected.\nOther Hirelings, like the Elf Hireling from this set, can specifically carry and use an Item themselves; in some cases, a Hireling can use an Item you cannot use for yourself. The Items a Hireling carries count for you and are affected by Traps, Curses, and Bad Stuff as though you were carrying them yourself.\ne If your Hireling sacrifices himself to save you, any Items he was carrying are lost.\ne If your Hireling is killed, you loot the body yourself and keep the Items.\n---\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 1\nPASSAGE:\ne If your Hireling sacrifices himself to save you, any Items he was carrying are lost.\ne If your Hireling is killed, you loot the body yourself and keep the Items.\ne If your Hireling is taken away by a Trap/Curse, by Bad Stuff, or by a change in loyalty, the Items go with him! Hirelings and Monster Bonuses If (for instance) you have the Dwarf Hireling and you face a monster that gets a bonus against Dwarves, it gets the bonus against you unless you discard the Hireling. A monster that has a penalty\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\nITEMS\nMost Treasures are Items. Items have a ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n1,000 Gold Pieces of Items to sell). Otherwise, you must give them to the lowest-Level player(s) who can carry them! If any Big items are still left over, discard them. Trading: You may trade Items (but no other cards) with other players. You may only trade Items from the table - not from your hand. You may trade at any time except when you or your trading partner are in combat — in fact, the best time to trade is when it’s not your turn, Any Ttem you receive in a trade must remain in play. You may also give Items away without a trade, to bribe other players - “Tl give you my Flaming Armor if you won't help Bob fight that dragon!” You may show your hand to others. Like we could stop you. Selling Items for Levels: At any point during your turn except during combat or Running Away, you may discard Items worth a total of at least 1,000 Gold Pieces and immediately go up one level. (“No Value” cards are the same as zero Gold Pieces.) If you discard (for instance) 1,100 Gold Pieces worth, you don't get change. But if you can manage 2,000 worth, you can go up two levels at once, and so on. You may sell Items from your hand as well as those you are carrying. You may not sell Items to go to Level 10.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\nITEMS\nMost Treasures are Items. Items have a Gold Piece value. “No Value” is equivalent to zero Gold Pieces, and a “No Value” card is considered an Item.\nAll Items you have in play are considered “carried.” Items that are actually giving you a bonus are “equipped.” You should indicate Items that are not equipped by turning the cards sideways. You may not alter the status of your Items during a combat or while running away.\nAnyone can carry any Item (except for extra Big items; see below), but you may equip only one Headgear, one suit of Armor, one pair of Footgear, and two “I Hand” Items (or one “2 Hands” Item) . . . unless you have a card that lets you ignore these limits, such as Hireling or Cheat!, or unless one of the cards says otherwise. If you are carrying two Headgear cards, for instance, you can equip only one of them at a time.\nLikewise, some Items have restrictions: for instance, the Mace of Sharpness can only be wielded by a Cleric. Its bonus only counts for someone who is, at the moment, a Cleric.\nYou cannot discard Item cards “just because.” You may sell Items for a level, trade Items with other players, o ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 1\nPASSAGE:\nHIRELINGS\nHirelings, Sidekicks, Monks, Minions, Comrades, and Allies are all the same for the purposes of these rules.\nHirelings are found in Door decks in some sets, Treasures in others. (In this set, they're Doors.) You can play a Hireling at any time, even in combat, as long as you have only one Hireling in play at a time. If you draw a face-up Hireling, you may put it in your hand if you cannot (or don’t want to) put it in play. You may discard a Hireling at any time.\nA Hireling is not an Item unless it has a price on it. You may only trade Hirelings that have a Gold Piece value.\nA Hireling can sacrifice himself for you. If you lose a fight, then instead of rolling to run away, you may discard one Hireling and anything he is carrying. You automatically escape from all monsters in the fight, even if a monster card says escape is impossible. If someone was helping you in the fight, YOU decide whether that person automatically escapes as well, or must roll to escape.\nSome Hirelings give you extra Hands, or let you carry an extra Big or Complex item. In this case, the Hireling does not actually have any Items . . . he merely increases your own abilities. If something happens to the Hireling, your Items are not affected.\nOther Hirelings, like the Elf Hireling from this set, can specifically carry and use an Item themselves; in some cases, a Hireling can use an Item you cannot use for yourself. The Items a Hireling carries count for you and are affected by Traps, Curses, and Bad Stuff as though you were carrying them yourself.\ne If your Hireling sacrifices himself to save you, any Items he was carrying are lost.\ne If your Hireling is killed, you loot the body yourself and keep the Items.\n---\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 1\nPASSAGE:\ne If your Hireling sacrifices himself to save you, any Items he was carrying are lost.\ne If your Hireling is killed, you loot the body yourself and keep the Items.\ne If your Hireling is taken away by a Trap/Curse, by Bad Stuff, or by a change in loyalty, the Items go with him! Hirelings and Monster Bonuses If (for instance) you have the Dwarf Hireling and you face a monster that gets a bonus against Dwarves, it gets the bonus against you unless you discard the Hireling. A monster that has a penalty\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\nITEMS\nMost Treasures are Items. Items have a ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 2\nPASSAGE:\nSTEEDS\nDear to a munchkin’s heart (as of now) is his mighty Steed. Because, of course, it gives bonuses. Steeds are found in the Door deck.\nNo player can have more than one Steed except by using a Cheat! card.\nSteeds are Items, and follow normal Item rules. Anything that affects an Item can affect a Steed.\nSteeds carry themselves. A Steed is “Big,” but it does not count against the number of Big items you can carry (in fact, some let you carry more Big things). The “Big” designation on Steeds is to control what Traps and Curses affect them, and to keep Thieves from pocketing them and walking off.\nThere are a few Items that specifically enhance Steeds. Steeds cannot use Items unless the Item card specifically says so, and Item Enhancers don’t affect Steed-enhancing Items.\nIf a Steed has a bonus or penalty to Run Away, that replaces the bonus of the rider. An Elf normally has a bonus to Run Away, but he has a penalty if he is riding the Turtle Steed! If your Steed gives you a penalty to Run Away, you may discard the Steed before you roll to flee. You don’t suffer the penalty, but the card goes to the discard pile.\n\nTreating Steeds as Monsters\nA player who draws a face-up Steed may choose to treat it as a monster instead. In that case, its Level is equal to twice the combat bonus at the top of the card, and defeating it is good for one Treasure and one level. Monster Enhancers may be played on Steeds being fought as monsters, and have their normal effects. The Bad Stuff for any Steed attacked as a monster is “Lose a level.”\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\nITEMS\nMost Treasures are Items. Items have a Gold Piece value. “No Value” is equivalent to zero Gold Pieces, and a “No Value” card is considered an Item.\nAll Items you have in play are considered “carried.” Items that are actually giving you a bonus are “equipped.” You should indicate Items that are not equipped by turning the cards sideways. You may not alter the status of your Items during a combat or while running away.\nAnyone can carry any Item (except for extra Big items; see below), but you may equip only one Headgear, one suit of Armor, one pair of Footgear, and two “I Hand” Items (or one “2 Hands” Item) . . . unless you have a card that lets you ignore these limits, such as Hireling or Cheat!, or unless one of the cards says otherwise. If you are carrying two Headgear cards, for instance, you can equip only one of them at a time.\nLikewise, some Items have restrictions: for instance, the Mace of Sharpness can only be wielded by a Cleric. Its bonus only counts for someone who is, at the moment, a Cleric.\nYou cannot discard Item cards “just because.” You may sell Items for a level, trade Items with other players, or give an Item to another player who wants it (see below). You may discard Items to power certain Class and Race abilities. And a Curse or a monster's Bad Stuff (see p. 5) may force you to get rid of something!\nBig Items: You may carry any number of Small items, but only one Big one. (Any item not marked Big is considered Small.) You may not discard one Big item to play another; you must sell the first Item, trade it, lose it to a Curse or Bad Stuff, or discard it to power a Class or Race ability.\n---\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 1\nPASSAGE:\nMUNCHKIN2 THE NEED FOR STEED\nThis set emphasizes two special types of cards: © Hirelings (you've seen a few, but this has more) © Steeds (a new card type!)\nIt is intend ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n(3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.\nAs soon as you are finished with Charity, the next player's turn begins.\n\nAg\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you c ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an AI assistant to help board game players find answers to their rule questions.\nHuman: You are an AI assistant to help board game players find answers to their rule questions.\n\nAnswer the question based only on the following board game rule excerpts. Do not use any other information. Never use the word \"excerpts\" in your answer. Simply refer to the context as the rules.\n\n----\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 1\nPASSAGE:\nHIRELINGS\nHirelings, Sidekicks, Monks, Minions, Comrades, and Allies are all the same for the purposes of these rules.\nHirelings are found in Door decks in some sets, Treasures in others. (In this set, they're Doors.) You can play a Hireling at any time, even in combat, as long as you have only one Hireling in play at a time. If you draw a face-up Hireling, you may put it in your hand if you cannot (or don’t want to) put it in play. You may discard a Hireling at any time.\nA Hireling is not an Item unless it has a price on it. You may only trade Hirelings that have a Gold Piece value.\nA Hireling can sacrifice himself for you. If you lose a fight, then instead of rolling to run away, you may discard one Hireling and anything he is carrying. You automatically escape from all monsters in the fight, even if a monster card says escape is impossible. If someone was helping you in the fight, YOU decide whether that person automatically escapes as well, or must roll to escape.\nSome Hirelings give you extra Hands, or let you carry an extra Big or Complex item. In this case, the Hireling does not actually have any Items . . . he merely increases your own abilities. If something happens to the Hireling, your Items are not affected.\nOther Hirelings, like the Elf Hireling from this set, can specifically carry and use an Item themselves; in some cases, a Hireling can use an Item you cannot use for yourself. The Items a Hireling carries count for you and are affected by Traps, Curses, and Bad Stuff as though you were carrying them yourself.\ne If your Hireling sacrifices himself to save you, any Items he was carrying are lost.\ne If your Hireling is killed, you loot the body yourself and keep the Items.\n---\n---\nNAME: munchkin_rules/munch_4_rules_20thp.pdf\nPAGE: 1\nPASSAGE:\ne If your Hireling sacrifices himself to save you, any Items he was carrying are lost.\ne If your Hireling is killed, you loot the body yourself and keep the Items.\ne If your Hireling is taken away by a Trap/Curse, by Bad Stuff, or by a change in loyalty, the Items go with him! Hirelings and Monster Bonuses If (for instance) you have the Dwarf Hireling and you face a monster that gets a bonus against Dwarves, it gets the bonus against you unless you discard the Hireling. A monster that has a penalty\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\nITEMS\nMost Treasures are Items. Items have a ...
#   ]
# }
# [llm/start] [1:llm:HuggingFaceChatModelLocal] Entering LLM run with input:
# {
#   "prompts": [
# ...
#       {
#         "text": "The true answer states that you cannot compel another player to help you in combat if winning that combat would give you the winning level. The student answer provides a more nuanced response, stating that the ability to compel another player depends on the specific card and its wording. While the student answer does not explicitly contradict the true answer, it does not directly address the question, as it suggests the answer depends on the card. Therefore, the student answer is incorrect.\nGRADE: INCORRECT",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The true answer states that you cannot compel another player to help you in combat if winning that combat would give you the winning level. The student answer provides a more nuanced response, stating that the ability to compel another player depends on the specific card and its wording. While the student answer does not explicitly contradict the true answer, it does not directly address the question, as it suggests the answer depends on the card. Therefore, the student answer is incorrect.\nGRADE: INCORRECT"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# query: If a monster does not pursue me because my level is too low, can I still loot the room?
# answer: If a monster does not pursue you because your level is too low, you can still choose to Loot The Room, as it is a separate action from facing the monster in combat.
# reference: No, you cannot loot the room.
# reasoning: The true answer states that if a monster does not pursue you because your level is too low, you cannot loot the room. The student answer claims that you can still choose to loot the room. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: Can I sell items from my hand to go up a level, assuming I can sell 1,000 gold pieces worth?
# answer: Yes, you can sell items from your hand to go up a level if the total value is at least 1,000 gold pieces.
# reference: Yes. You can sell items from your hand to go up a level.
# reasoning: The true answer states that you can sell items from your hand to go up a level. The student answer confirms that you can indeed sell items from your hand to go up a level, as long as the total value is at least 1,000 gold pieces. Both the student answer and the true answer are correct.
# GRADE: CORRECT
# score: 1
#
# query: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?
# answer: A: If a hireling is removed from play due to Bad Stuff, the player retains the items the hireling was carrying.
# reference: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.
# reasoning: The true answer states that when a hireling is removed from play due to bad stuff, the items carried by the hireling are also removed from play. The student answer claims that the player retains the items when the hireling is removed from play. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: Can I have multiple steeds equipped at the same time?
# answer: A player can have only one Steed equipped at a time, unless using a Cheat! card that allows them to ignore this rule.
# reference: No. You can only have one steed equipped at a time.
# reasoning: The true answer states that you can only have one steed equipped at a time. The student answer states that a player can have only one steed equipped at a time, unless using a Cheat! card that allows them to ignore this rule. While the student answer is mostly correct, it adds an exception that does not contradict the true answer. Therefore, the student answer is correct.
# score: 1
#
# query: Can I play a Go Up a Level card during combat on my turn?
# answer: Yes, you can play a Go Up a Level card during combat on your turn.
# reference: Yes. You can play a Go Up a Level card at any time.
# reasoning: The true answer states that a Go Up a Level card can be played at any time. The student answer also correctly states that it can be played during combat on your turn. Both the student answer and the true answer convey the same core information: that a Go Up a Level card can be played at any time.
# GRADE: CORRECT
# score: 1
#
# query: How many players can join me in a combat?
# answer: In the provided context, there is no specific limit mentioned on the number of players who can join another player in a combat. However, the text does mention that a player can ask other players for help in a combat and other players can interfere in a combat by using cards to strengthen or weaken a player's side.
# reference: Only one player can join you in combat.
# reasoning: The true answer says that only one other player can join someone in combat. The student answer claims there is no maximum number of players who can join combat. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: Does a player retain their princess card in play if they die?
# answer: To answer the question of whether a player retains their Princess card in play if they die, we need to examine the relevant rule excerpts:
#
# 1. Munchkin Princesses rules (page 1) - Princesses rules
# - If you have a Princess card, are not already a Princess, and want to become a Princess, just play it in front of you.
# - You may discard Princess at any time.
#
# 2. Death rules (page 5) - Death rules
# - If you die, you lose all your stuff.
# - You may discard Princess at any time.
#
# Since neither the Princesses rules nor the Death rules explicitly state that a player retains their Princess card in play if they die, we cannot definitively answer the question based on the given context.
# reference: Yes. A player retains their princess card in play if they die.
# reasoning: The true answer states that a player retains their princess card in play if they die. The student answer does not explicitly provide an answer to the question, stating instead that the rules do not clearly address the situation. Since the student answer does not contradict the true answer, but also does not provide a definitive answer, it is considered incorrect.
#
# GRADE: INCORRECT
# score: 0
#
# query: Can I carry multiple big items so long as only one is equipped?
# answer: Yes, you can carry multiple big items, but only one can be equipped at a time.
# reference: No. You can only carry one big item at a time.
# reasoning: The true answer states that you can only carry one big item at a time. The student answer states that you can carry multiple big items, but only one can be equipped at a time. This is a contradiction to the true answer. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: What is an item in play but not equipped called?
# answer: An item in play but not equipped is called "carried."
# reference: An item in play but not equipped is called a carried item.
# reasoning: The true answer states that an item in play but not equipped is called a carried item. The student answer correctly identifies this as "carried," though the phrasing is slightly different. Both the student answer and the true answer convey the same core information: that an item in play but not equipped is called a carried item.
# GRADE: CORRECT
# score: 1
#
# query: If after breaking down the door I draw a steed face up, what are my options?
# answer: If a player draws a Steed face up during the Kick Open The Door phase, they have two options: treat it as a monster or treat it as an Item. If treated as a monster, the Steed's Level is equal to twice the combat bonus at the top of the card, and defeating it is good for one Treasure and one level. If treated as an Item, the player adds it to their hand. Steeds are Items and follow normal Item rules. A player cannot have more than one Steed, except by using a Cheat! card. Steeds carry themselves and are subject to Traps and Curses as per the "Big" designation.
# reference: You can put the steed into your hand, equip it, or treat as a monster and fight it.
# reasoning: The true answer states that upon drawing a steed face up during the Kick Open The Door phase, the player has three options: put the steed into their hand, equip it, or treat it as a monster and fight it. The student answer provides more detailed information about the options, but does not contradict the true answer. Therefore, the student answer is correct.
# score: 1
#
# query: When can I play a Super Munchkin card?
# answer: You can play a Super Munchkin card when you have a Class card in your hand and want to take advantage of the abilities associated with that Class. Remember, you cannot have more than one of the same Class or Race card in play at once.
# reference: You can play a Super Munchkin card whenever it is legal to play a Class card.
# reasoning: The true answer states that a Super Munchkin card can be played whenever it is legal to play a Class card. The student answer provides additional information about the need to have a Class card in hand and not having more than one of the same Class or Race card in play at once. However, this information does not contradict the true answer. Therefore, the student answer is correct.
# GRADE: CORRECT
# score: 1
#
# query: Can I play a Super Munchkin card without a class card?
# answer: Yes, you can play a Super Munchkin card without a class card. If you play the Super Munchkin card without a specific class card, you will still enjoy the benefits and drawbacks associated with having a class.
# reference: No, you must have a class card to attach it to.
# reasoning: The true answer states that a Super Munchkin card cannot be played without a class card. The student answer claims that a player can play a Super Munchkin card without a specific class card and still enjoy the benefits and drawbacks associated with having a class. This contradicts the true answer. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: What cards can I trade with other players?
# answer: You can trade Item cards with other players, as long as they are on the table and not in your hand. Trading is not allowed during your or your trading partner's combat.
# reference: You can trade any item cards in play (on the table) with other players.
# reasoning: The true answer states that any item cards in play can be traded with other players. The student answer restricts the trade to only item cards on the table and not in the player's hand, which does not contradict the true answer. Therefore, the student answer is correct.
# score: 1
#
# query: When can I player a Hireling?
# answer: A player can play a Hireling at any time, even in combat, as long as they have only one Hireling in play at a time. This rule is found in the first excerpt from the "munchkin_rules/munch_4_rules_20thp.pdf" file on page 1.
# reference: At any time.
# reasoning: The true answer states that a player can play a Hireling at any time. The student answer also states that a player can play a Hireling at any time, including in combat, as long as they have only one Hireling in play at a time. Both the student answer and the true answer convey the same core information: that a player can play a Hireling at any time.
# GRADE: CORRECT
# score: 1
#
# query: Can I play a Hireling card if I already have a Hireling in play?
# answer: Yes, you can play a Hireling card if you already have a Hireling in play, as long as you only have one Hireling in play at a time.
# reference: No. You can only have one Hireling in play at a time.
# reasoning: The true answer states that only one Hireling can be in play at a time. The student answer claims that you can play a Hireling card even if you already have one in play, as long as you only have one Hireling in play at a time. This contradicts the true answer. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: When I loot the room, is the door card drawn face up or face down?
# answer: When a player loots the room, the door card drawn is face down.
# reference: The door card is drawn face down.
# reasoning: The true answer states that the door card is drawn face down. The student answer also states that the door card is drawn face down, which matches the true answer. Therefore, the student answer is correct.
# GRADE: CORRECT
# score: 1
#
# query: Can I use a card to compel another player to help me in combat if winning that combat would give me the winning level?
# answer: Based on the given context, it is unclear whether you can use a card to compel another player to help you in combat if winning that combat would give you the winning level. The answer depends on the specific card and its wording. If the card explicitly states that it supersedes the rule mentioned above, then it would be allowed; otherwise, it would not be allowed.
# reference: No. You cannot compel another player to get the winning level.
# reasoning: The true answer states that you cannot compel another player to help you in combat if winning that combat would give you the winning level. The student answer provides a more nuanced response, stating that the ability to compel another player depends on the specific card and its wording. While the student answer does not explicitly contradict the true answer, it does not directly address the question, as it suggests the answer depends on the card. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: Can I play a Go Up a Level card on another player?
# answer: Yes, you can play a Go Up a Level card on another player, but not if it would give them the winning level.
# reference: Yes.
# reasoning: The true answer simply states "yes," indicating that a player can play a Go Up a Level card on another player. The student answer provides additional context, stating that you cannot play it if it would give them the winning level, but this does not contradict the true answer. Both the student answer and the true answer convey the same core information, which is that a player can play a Go Up a Level card on another player.
# GRADE: CORRECT
# score: 1
#
# query: Can I play a Curse while in combat?
# answer: Based on the provided context, you cannot play a Curse during combat, but you can interfere with others' combats using a Curse.
# reference: Yes. A curse may be played at any time.
# reasoning: The true answer states that a curse may be played at any time, while the student answer implies that a curse cannot be played during combat. The student answer does not directly contradict the true answer, but it fails to provide a clear and accurate explanation. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: How can I get rid of my Class card?
# answer: A: To discard a Class card, a player must play it in front of them, and when discarded, they lose their class abilities and become classless until they play another Class card.
# reference: You can discard your Class card at any time.
# reasoning: The true answer states that you can discard your class card at any time. The student answer explains the process of discarding a class card, but fails to mention that it can be done at any time. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
#
# query: When can I discard a Race card?
# answer: You can discard a Race card whenever it is legal to play a Race card. This occurs when you have an appropriate Race card to attach to and you cannot have more than one of the same Race card in play at once.
# reference: You can discard your Race card at any time.
# reasoning: The true answer states that you can discard your race at any time. The student answer suggests scenarios in which a race card might be discarded, but fails to mention the race card may be discarded at any time. Therefore, the student answer is incorrect.
# GRADE: INCORRECT
# score: 0
# 0.47619047619047616

# %%
for doc in retriever.invoke("Can I carry multiple big items so long as only one is equipped?"):
    print(doc.page_content)
    print()
    print()
# Out:
# ITEMS
# Most Treasures are Items. Items have a Gold Piece value. “No Value” is equivalent to zero Gold Pieces, and a “No Value” card is considered an Item.
# All Items you have in play are considered “carried.” Items that are actually giving you a bonus are “equipped.” You should indicate Items that are not equipped by turning the cards sideways. You may not alter the status of your Items during a combat or while running away.
# Anyone can carry any Item (except for extra Big items; see below), but you may equip only one Headgear, one suit of Armor, one pair of Footgear, and two “I Hand” Items (or one “2 Hands” Item) . . . unless you have a card that lets you ignore these limits, such as Hireling or Cheat!, or unless one of the cards says otherwise. If you are carrying two Headgear cards, for instance, you can equip only one of them at a time.
# Likewise, some Items have restrictions: for instance, the Mace of Sharpness can only be wielded by a Cleric. Its bonus only counts for someone who is, at the moment, a Cleric.
# You cannot discard Item cards “just because.” You may sell Items for a level, trade Items with other players, or give an Item to another player who wants it (see below). You may discard Items to power certain Class and Race abilities. And a Curse or a monster's Bad Stuff (see p. 5) may force you to get rid of something!
# Big Items: You may carry any number of Small items, but only one Big one. (Any item not marked Big is considered Small.) You may not discard one Big item to play another; you must sell the first Item, trade it, lose it to a Curse or Bad Stuff, or discard it to power a Class or Race ability.
#
#
# STEEDS
# Dear to a munchkin’s heart (as of now) is his mighty Steed. Because, of course, it gives bonuses. Steeds are found in the Door deck.
# No player can have more than one Steed except by using a Cheat! card.
# Steeds are Items, and follow normal Item rules. Anything that affects an Item can affect a Steed.
# Steeds carry themselves. A Steed is “Big,” but it does not count against the number of Big items you can carry (in fact, some let you carry more Big things). The “Big” designation on Steeds is to control what Traps and Curses affect them, and to keep Thieves from pocketing them and walking off.
# There are a few Items that specifically enhance Steeds. Steeds cannot use Items unless the Item card specifically says so, and Item Enhancers don’t affect Steed-enhancing Items.
# If a Steed has a bonus or penalty to Run Away, that replaces the bonus of the rider. An Elf normally has a bonus to Run Away, but he has a penalty if he is riding the Turtle Steed! If your Steed gives you a penalty to Run Away, you may discard the Steed before you roll to flee. You don’t suffer the penalty, but the card goes to the discard pile.
#
# Treating Steeds as Monsters
# A player who draws a face-up Steed may choose to treat it as a monster instead. In that case, its Level is equal to twice the combat bonus at the top of the card, and defeating it is good for one Treasure and one level. Monster Enhancers may be played on Steeds being fought as monsters, and have their normal effects. The Bad Stuff for any Steed attacked as a monster is “Lose a level.”
#
#
# lf something lets you have more than one Big item (for instance, the Dwarf race) and you lose that ability, you must either correct the problem immediately or get rid of all but one Big item. If it's your turn and you're not in combat, you can sell the excess Big items (as long as you have at least Level Counters: It’s Not Cheating, It’s Using the Rules!
# If you have an iOS or Android device, you'll like our Level Counter app. Just search for “Munchkin level counter” or click the link at levelcounter.sjgames.com. Even better, it gives you personal in- game advantages to make your friends jealous . . . which is what being a munchkin is all about!
#
#
# 1,000 Gold Pieces of Items to sell). Otherwise, you must give them to the lowest-Level player(s) who can carry them! If any Big items are still left over, discard them. Trading: You may trade Items (but no other cards) with other players. You may only trade Items from the table - not from your hand. You may trade at any time except when you or your trading partner are in combat — in fact, the best time to trade is when it’s not your turn, Any Ttem you receive in a trade must remain in play. You may also give Items away without a trade, to bribe other players - “Tl give you my Flaming Armor if you won't help Bob fight that dragon!” You may show your hand to others. Like we could stop you. Selling Items for Levels: At any point during your turn except during combat or Running Away, you may discard Items worth a total of at least 1,000 Gold Pieces and immediately go up one level. (“No Value” cards are the same as zero Gold Pieces.) If you discard (for instance) 1,100 Gold Pieces worth, you don't get change. But if you can manage 2,000 worth, you can go up two levels at once, and so on. You may sell Items from your hand as well as those you are carrying. You may not sell Items to go to Level 10.
#
#
# TURN PHASES
# Your turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.
# If it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).
# If you draw any other card, you may either put it in your hand or play it immediately.
# (2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.
# Look For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!
# Loot The Room: Draw a second card from the Door deck, face down, and place it in your hand.
# (3) Charity: If you have more than five cards in your hand, you must play enough cards to get you to five or below — for instance, you can play Curses, sell Items from your hand, or play Items to the table. If you cannot reduce your hand to five cards, or do not want to, you must give the excess cards to the player with the lowest Level. If players are tied for lowest, divide the cards as evenly as possible, but it's up to you who gets the bigger set(s) of leftovers. If YOU are the lowest or tied for lowest, just discard the excess.
# As soon as you are finished with Charity, the next player's turn begins.
#
# Ag
#
#
# HIRELINGS
# Hirelings, Sidekicks, Monks, Minions, Comrades, and Allies are all the same for the purposes of these rules.
# Hirelings are found in Door decks in some sets, Treasures in others. (In this set, they're Doors.) You can play a Hireling at any time, even in combat, as long as you have only one Hireling in play at a time. If you draw a face-up Hireling, you may put it in your hand if you cannot (or don’t want to) put it in play. You may discard a Hireling at any time.
# A Hireling is not an Item unless it has a price on it. You may only trade Hirelings that have a Gold Piece value.
# A Hireling can sacrifice himself for you. If you lose a fight, then instead of rolling to run away, you may discard one Hireling and anything he is carrying. You automatically escape from all monsters in the fight, even if a monster card says escape is impossible. If someone was helping you in the fight, YOU decide whether that person automatically escapes as well, or must roll to escape.
# Some Hirelings give you extra Hands, or let you carry an extra Big or Complex item. In this case, the Hireling does not actually have any Items . . . he merely increases your own abilities. If something happens to the Hireling, your Items are not affected.
# Other Hirelings, like the Elf Hireling from this set, can specifically carry and use an Item themselves; in some cases, a Hireling can use an Item you cannot use for yourself. The Items a Hireling carries count for you and are affected by Traps, Curses, and Bad Stuff as though you were carrying them yourself.
# e If your Hireling sacrifices himself to save you, any Items he was carrying are lost.
# e If your Hireling is killed, you loot the body yourself and keep the Items.

# %% [markdown]
# ## Optimize Parameters

# %% [markdown]
# ### Context length

# %%
from sklearn.model_selection import ParameterGrid
param_grid = {
    "context_percent": [0.25, 0.5, 0.75, 1],
    "parent_docs_percent": [1, 1/3, 1/6, 1/8],
    "child_docs_percent": [1/3, 1/6, 1/8],
    "chunk_overlap_percent": [0.0, 0.1, 0.2],
    "use_child_docs": [True, False]
}

all_combinations = list(ParameterGrid(param_grid))
all_combinations

def to_retriever_params(combination, context_size, min_context_use, min_doc_size):
    context_use = context_size * combination["context_percent"]
    if context_use < min_context_use:
        return False
    
    parent_docs_size = context_use * combination["parent_docs_percent"]
    if parent_docs_size < min_doc_size:
        return False
    
    number_of_docs = int(context_use / parent_docs_size)
    
    use_child_docs = combination["use_child_docs"]
    child_docs_size = parent_docs_size * combination["child_docs_percent"]
    if use_child_docs and child_docs_size < min_doc_size:
        return False
    
    return {
        "parent_chunk_size": int(parent_docs_size),
        "parent_chunk_overlap": int(parent_docs_size * combination["chunk_overlap_percent"]),
        "child_chunk_size": int(child_docs_size) if use_child_docs else 0,
        "child_chunk_overlap": int(child_docs_size * combination["chunk_overlap_percent"]) if use_child_docs else 0,
        "number_of_docs": number_of_docs,
    }

valid_retriever_params = list(
    filter(
        None, 
        (
            to_retriever_params(combination, 4096-1000-200, 1024, 125)
            for combination in all_combinations
        )
    )
)

print(f"number of valid retriever params: {len(valid_retriever_params)}")
valid_retriever_params[:2]
# Out:
# number of valid retriever params: 150
# [{'parent_chunk_size': 1448,
#   'parent_chunk_overlap': 0,
#   'child_chunk_size': 482,
#   'child_chunk_overlap': 0,
#   'number_of_docs': 1},
#  {'parent_chunk_size': 1448,
#   'parent_chunk_overlap': 0,
#   'child_chunk_size': 0,
#   'child_chunk_overlap': 0,
#   'number_of_docs': 1}]

# %%
type(db.index)
# Out:
# faiss.swigfaiss_avx2.IndexFlatL2

# %%
def get_new_vectorstore():
    global db
    if db and isinstance(db, Chroma):
        try:
            db.delete_collection()
        except ValueError:
            # we might have already deleted it. Good for us!
            pass

    db = build_vectorstore(load_embedding_model(faiss_embedding_model_name))
    return db

def retriever_test_objective(
        parent_chunk_size, 
        parent_chunk_overlap, 
        child_chunk_size, 
        child_chunk_overlap, 
        number_of_docs,
        self_consistency=0
):
    db = get_new_vectorstore()

    chat_model.callbacks = []

    retriever_config = RetrieverConfig(
        parent_chunk_size=parent_chunk_size,
        parent_chunk_overlap=parent_chunk_overlap,
        child_chunk_size=child_chunk_size,
        child_chunk_overlap=child_chunk_overlap,
        k=int(number_of_docs*2.5),
    )
    retriever, complete_chain = build_complete_chain(
        chat_model=chat_model,
        tokenizer=tokenizer,
        vectorstore=db,
        retriever_config=retriever_config,
        sampling_config=SamplingConfig(
            temperature=0.7,
            samples=5,
        ),
        rag_config=RagChainConfig(
            thread_of_thought_enabled=True,
            use_self_consistency=False,
            number_of_documents=number_of_docs,
        ),
    )
    retriever.add_documents(rule_docs)
    predictions = predict_answer(test_cases, complete_chain)
    graded = grade(predictions, chat_model.bind(do_sample=False, max_new_tokens=1000))
    return get_overall_score(graded)

# %%
def test_creation():
    params = {"child_chunk_overlap": 0, "child_chunk_size": 599, "number_of_docs": 1, "parent_chunk_overlap": 0, "parent_chunk_size": 1798}
    retriever_test_objective(**params)

# %%
import time
from tqdm import tqdm

# for _ in tqdm(list(range(1800))):
#     # embedding_model.embed_documents([doc.page_content for doc in rule_docs])
#     # time.sleep(60)
#     db = get_new_vectorstore()
#     db.add_documents(rule_docs)
#     # retriever = build_retriever(tokenizer, db, RetrieverConfig())
#     # retriever.add_documents(rule_docs)

# %%
from tqdm import tqdm

def evaluate_all_params(params, logfile=None):
    results = []
    # Iterate over params and show progress bar
    for param in tqdm(params):
        score = retriever_test_objective(**param)
        result = [score, param]
        results.append(result)
        if logfile is not None:
            logfile.write(json.dumps(result))
            logfile.write("\n")
            logfile.flush()
    results.sort(key=itemgetter(0), reverse=True)
    return results

# %%
if False:
    with open("retriever_params_search.log", "w") as f:
        results = evaluate_all_params(valid_retriever_params, logfile=f)

with open("retriever_params_search.log", "r") as f:
    results = [json.loads(line) for line in f.readlines()]

results[:10]
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# 100%|██████████| 150/150 [2:43:38<00:00, 65.46s/it]
# [[0.8571428571428571,
#   {'parent_chunk_size': 362,
#    'parent_chunk_overlap': 0,
#    'child_chunk_size': 0,
#    'child_chunk_overlap': 0,
#    'number_of_docs': 8}],
#  [0.8095238095238095,
#   {'parent_chunk_size': 362,
#    'parent_chunk_overlap': 36,
#    'child_chunk_size': 0,
#    'child_chunk_overlap': 0,
#    'number_of_docs': 8}],
#  [0.8095238095238095,
#   {'parent_chunk_size': 1448,
#    'parent_chunk_overlap': 289,
#    'child_chunk_size': 241,
#    'child_chunk_overlap': 48,
#    'number_of_docs': 1}],
#  [0.8095238095238095,
#   {'parent_chunk_size': 482,
#    'parent_chunk_overlap': 96,
#    'child_chunk_size': 0,
#    'child_chunk_overlap': 0,
#    'number_of_docs': 3}],
#  [0.8095238095238095,
#   {'parent_chunk_size': 2896,
#    'parent_chunk_overlap': 0,
#    'child_chunk_size': 362,
#    'child_chunk_overlap': 0,
#    'number_of_docs': 1}],
#  [0.8095238095238095,
#   {'parent_chunk_size': 482,
#    'parent_chunk_overlap': 0,
#    'child_chunk_size': 0,
#    'child_chunk_overlap': 0,
#    'number_of_docs': 6}],
#  [0.8095238095238095,
#   {'parent_chunk_size': 2896,
#    'parent_chunk_overlap': 579,
#    'child_chunk_size': 362,
#    'child_chunk_overlap': 72,
#    'number_of_docs': 1}],
#  [0.7619047619047619,
#   {'parent_chunk_size': 482,
#    'parent_chunk_overlap': 0,
#    'child_chunk_size': 0,
#    'child_chunk_overlap': 0,
#    'number_of_docs': 6}],
#  [0.7619047619047619,
#   {'parent_chunk_size': 482,
#    'parent_chunk_overlap': 48,
#    'child_chunk_size': 0,
#    'child_chunk_overlap': 0,
#    'number_of_docs': 3}],
#  [0.7619047619047619,
#   {'parent_chunk_size': 724,
#    'parent_chunk_overlap': 72,
#    'child_chunk_size': 241,
#    'child_chunk_overlap': 24,
#    'number_of_docs': 3}]]

# %%
from functools import reduce

new_param_grid = {
    "self_consistency": [0, 3, 5, 7],
    "self_consistency_temperature": [0.4, 0.7, 1.0, 1.3]
}

for result in results:
    for k, v in result[1].items():
        values = new_param_grid.setdefault(k, [])
        if v not in values:
            values.append(v)
 
all_combinations = list(ParameterGrid(new_param_grid))
all_combinations

# %%
# new_params = [{**result[1], "self_consistency": True} for result in results[:10]]
# with open("self_consistency_params_search.log", "w") as f:
#     results2 = evaluate_all_params(new_params, logfile=f)

# with open("self_consistency_params_search.log", "r") as f:
#     results2 = [json.loads(line) for line in f.readlines()]

# results2[:10]

# %%
retriever_config = RetrieverConfig(
    max_context_size=4096,
    percent_context_use=0.75,
    parent_percent=0.15,
    parent_overlap_percent=0.1,
    child_percent=0.25,
    child_overlap_percent=0.1,
)

sampling_config = SamplingConfig(
    temperature=0.7,
    # top_k=0,
    # top_p=None,
    samples=5,
)

rag_config = RagChainConfig(
    thread_of_thought_enabled=True,
)

retriever, rag_chain_with_context = build_complete_chain(
    chat_model=chat_model,
    tokenizer=tokenizer,
    vectorstore=db,
    retriever_config=retriever_config,
    sampling_config=sampling_config,
    rag_config=rag_config,
)
# print(rag_chain_with_context)
rag_chain = rag_chain_with_context | itemgetter("answer")

# %%
retriever.add_documents(rule_docs)

# %%
from langchain.callbacks.tracers import ConsoleCallbackHandler

# rag_chain = build_basic_rag_chain(
#     retriever=retriever,
#     chat_chain=chat_model,
#     prompt=rag_config.rag_prompt,
# )

rag_chain_trace = rag_chain.with_config({'callbacks': [ConsoleCallbackHandler()]})

rag_chain_trace.invoke("Can I play a Go Up a Level card during combat?")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": "Can I play a Go Up a Level card during combat?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel] Entering Chain run with input:
# {
#   "input": "Can I play a Go Up a Level card during combat?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:RunnablePassthrough] Entering Chain run with input:
# {
#   "input": "Can I play a Go Up a Level card during combat?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:RunnablePassthrough] s] Exiting Chain run with output:
# {
#   "output": "Can I play a Go Up a Level card during combat?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "question": "Can I play a Go Up a Level card during combat?"
# }
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought] Entering Chain run with input:
# {
#   "question": "Can I play a Go Up a Level card during combat?"
# }
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign] Entering Chain run with input:
# {
#   "question": "Can I play a Go Up a Level card during combat?"
# }
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign > 6:chain:RunnableParallel] Entering Chain run with input:
# {
#   "question": "Can I play a Go Up a Level card during combat?"
# }
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign > 6:chain:RunnableParallel > 7:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "Can I play a Go Up a Level card during combat?"
# }
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign > 6:chain:RunnableParallel > 7:chain:RunnableSequence > 8:chain:RunnableLambda] Entering Chain run with input:
# {
#   "question": "Can I play a Go Up a Level card during combat?"
# }
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign > 6:chain:RunnableParallel > 7:chain:RunnableSequence > 8:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "Can I play a Go Up a Level card during combat?"
# }
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign > 6:chain:RunnableParallel > 7:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign > 6:chain:RunnableParallel] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 5:chain:RunnableAssign] s] Exiting Chain run with output:
# {
#   "question": "Can I play a Go Up a Level card during combat?",
#   "documents": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "When You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Conflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.",
#         "metadata": {
#           "page_number": 1,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.",
#         "metadata": {
#           "page_number": 3,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "CHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You can also sell Items to buy levels (see Items). You lose a level when a card says you do. Your Level can never go below 1. However, your combat strength can be negative, if you get hit by a Curse or suffer some other kind of penalty.\nClass: Characters may be Warriors, Wizards, Thieves, or Clerics. If you have no Class card in front of you, you have no class. Yeah, I know, we did that one already.\nEach Class has special abilities, shown on the cards. You gain the abilities of a Class the moment you play its card in front of you, and lose them as soon as you discard that card. Some Class abilities are powered by discards. You may discard any card, in play or in your hand, to power a special ability.\nSee the Class cards for when abilities can be used. Note that a Thief cannot steal while he or the target is fighting - and as soon as a monster is revealed, the fight is on!\nYou can discard a Class card at any time, even in combat: “I don't wanna be a wizard anymore.” When you discard a Class card, you become classless until you play another Class card.\nYou may not belong to more than one class at once unless you play the Super Munchkin card.",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Interfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may not get the Treasure, depending on the method.\nTreasure cards can be played as soon as you get them, even if you are the helper.",
#         "metadata": {
#           "page_number": 4,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "STEEDS\nDear to a munchkin’s heart (as of now) is his mighty Steed. Because, of course, it gives bonuses. Steeds are found in the Door deck.\nNo player can have more than one Steed except by using a Cheat! card.\nSteeds are Items, and follow normal Item rules. Anything that affects an Item can affect a Steed.\nSteeds carry themselves. A Steed is “Big,” but it does not count against the number of Big items you can carry (in fact, some let you carry more Big things). The “Big” designation on Steeds is to control what Traps and Curses affect them, and to keep Thieves from pocketing them and walking off.\nThere are a few Items that specifically enhance Steeds. Steeds cannot use Items unless the Item card specifically says so, and Item Enhancers don’t affect Steed-enhancing Items.\nIf a Steed has a bonus or penalty to Run Away, that replaces the bonus of the rider. An Elf normally has a bonus to Run Away, but he has a penalty if he is riding the Turtle Steed! If your Steed gives you a penalty to Run Away, you may discard the Steed before you roll to flee. You don’t suffer the penalty, but the card goes to the discard pile.\n\nTreating Steeds as Monsters\nA player who draws a face-up Steed may choose to treat it as a monster instead. In that case, its Level is equal to twice the combat bonus at the top of the card, and defeating it is good for one Treasure and one level. Monster Enhancers may be played on Steeds being fought as monsters, and have their normal effects. The Bad Stuff for any Steed attacked as a monster is “Lose a level.”",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munch_4_rules_20thp.pdf"
#         }
#       }
#     }
#   ]
# }
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel > 12:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel > 12:chain:RunnableSequence > 13:chain:RunnableLambda] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel > 12:chain:RunnableSequence > 13:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "When You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Conflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.",
#         "metadata": {
#           "page_number": 1,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.",
#         "metadata": {
#           "page_number": 3,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "CHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You can also sell Items to buy levels (see Items). You lose a level when a card says you do. Your Level can never go below 1. However, your combat strength can be negative, if you get hit by a Curse or suffer some other kind of penalty.\nClass: Characters may be Warriors, Wizards, Thieves, or Clerics. If you have no Class card in front of you, you have no class. Yeah, I know, we did that one already.\nEach Class has special abilities, shown on the cards. You gain the abilities of a Class the moment you play its card in front of you, and lose them as soon as you discard that card. Some Class abilities are powered by discards. You may discard any card, in play or in your hand, to power a special ability.\nSee the Class cards for when abilities can be used. Note that a Thief cannot steal while he or the target is fighting - and as soon as a monster is revealed, the fight is on!\nYou can discard a Class card at any time, even in combat: “I don't wanna be a wizard anymore.” When you discard a Class card, you become classless until you play another Class card.\nYou may not belong to more than one class at once unless you play the Super Munchkin card.",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Interfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may not get the Treasure, depending on the method.\nTreasure cards can be played as soon as you get them, even if you are the helper.",
#         "metadata": {
#           "page_number": 4,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "STEEDS\nDear to a munchkin’s heart (as of now) is his mighty Steed. Because, of course, it gives bonuses. Steeds are found in the Door deck.\nNo player can have more than one Steed except by using a Cheat! card.\nSteeds are Items, and follow normal Item rules. Anything that affects an Item can affect a Steed.\nSteeds carry themselves. A Steed is “Big,” but it does not count against the number of Big items you can carry (in fact, some let you carry more Big things). The “Big” designation on Steeds is to control what Traps and Curses affect them, and to keep Thieves from pocketing them and walking off.\nThere are a few Items that specifically enhance Steeds. Steeds cannot use Items unless the Item card specifically says so, and Item Enhancers don’t affect Steed-enhancing Items.\nIf a Steed has a bonus or penalty to Run Away, that replaces the bonus of the rider. An Elf normally has a bonus to Run Away, but he has a penalty if he is riding the Turtle Steed! If your Steed gives you a penalty to Run Away, you may discard the Steed before you roll to flee. You don’t suffer the penalty, but the card goes to the discard pile.\n\nTreating Steeds as Monsters\nA player who draws a face-up Steed may choose to treat it as a monster instead. In that case, its Level is equal to twice the combat bonus at the top of the card, and defeating it is good for one Treasure and one level. Monster Enhancers may be played on Steeds being fought as monsters, and have their normal effects. The Bad Stuff for any Steed attacked as a monster is “Lose a level.”",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munch_4_rules_20thp.pdf"
#         }
#       }
#     }
#   ]
# }
# [chain/start] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel > 12:chain:RunnableSequence > 14:chain:thread_of_thought_combine_documents] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel > 12:chain:RunnableSequence > 14:chain:thread_of_thought_combine_documents] s] Exiting Chain run with output:
# {
#   "output": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nCHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You  ...
# }
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel > 12:chain:RunnableSequence] s] Exiting Chain run with output:
# {
#   "output": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nCHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You  ...
# }
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign > 11:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "context": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nCHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You ...
# }
# [chain/end] [1:chain:RunnableSequence > 4:chain:thread-of-thought > 10:chain:RunnableAssign] s] Exiting Chain run with output:
# {
#   "question": "Can I play a Go Up a Level card during combat?",
#   "documents": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "When You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Conflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.",
#         "metadata": {
#           "page_number": 1,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.",
#         "metadata": {
#           "page_number": 3,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "CHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You can also sell Items to buy levels (see Items). You lose a level when a card says you do. Your Level can never go below 1. However, your combat strength can be negative, if you get hit by a Curse or suffer some other kind of penalty.\nClass: Characters may be Warriors, Wizards, Thieves, or Clerics. If you have no Class card in front of you, you have no class. Yeah, I know, we did that one already.\nEach Class has special abilities, shown on the cards. You gain the abilities of a Class the moment you play its card in front of you, and lose them as soon as you discard that card. Some Class abilities are powered by discards. You may discard any card, in play or in your hand, to power a special ability.\nSee the Class cards for when abilities can be used. Note that a Thief cannot steal while he or the target is fighting - and as soon as a monster is revealed, the fight is on!\nYou can discard a Class card at any time, even in combat: “I don't wanna be a wizard anymore.” When you discard a Class card, you become classless until you play another Class card.\nYou may not belong to more than one class at once unless you play the Super Munchkin card.",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Interfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may not get the Treasure, depending on the method.\nTreasure cards can be played as soon as you get them, even if you are the helper.",
#         "metadata": {
#           "page_number": 4,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "STEEDS\nDear to a munchkin’s heart (as of now) is his mighty Steed. Because, of course, it gives bonuses. Steeds are found in the Door deck.\nNo player can have more than one Steed except by using a Cheat! card.\nSteeds are Items, and follow normal Item rules. Anything that affects an Item can affect a Steed.\nSteeds carry themselves. A Steed is “Big,” but it does not count against the number of Big items you can carry (in fact, some let you carry more Big things). The “Big” designation on Steeds is to control what Traps and Curses affect them, and to keep Thieves from pocketing them and walking off.\nThere are a few Items that specifically enhance Steeds. Steeds cannot use Items unless the Item card specifically says so, and Item Enhancers don’t affect Steed-enhancing Items.\nIf a Steed has a bonus or penalty to Run Away, that replaces the bonus of the rider. An Elf normally has a bonus to Run Away, but he has a penalty if he is riding the Turtle Steed! If your Steed gives you a penalty to Run Away, you may discard the Steed before you roll to flee. You don’t suffer the penalty, but the card goes to the discard pile.\n\nTreating Steeds as Monsters\nA player who draws a face-up Steed may choose to treat it as a monster instead. In that case, its Level is equal to twice the combat bonus at the top of the card, and defeating it is good for one Treasure and one level. Monster Enhancers may be played on Steeds being fought as monsters, and have their normal effects. The Bad Stuff for any Steed attacked as a monster is “Lose a level.”",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munch_4_rules_20thp.pdf"
#         }
#       }
#     }
#   ],
# ...
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 31:chain:RunnableAssign > 32:chain:RunnableParallel > 33:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 31:chain:RunnableAssign > 32:chain:RunnableParallel] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 31:chain:RunnableAssign] s] Exiting Chain run with output:
# {
#   "question": "Can I play a Go Up a Level card during combat?",
#   "documents": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "When You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Conflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.",
#         "metadata": {
#           "page_number": 1,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.",
#         "metadata": {
#           "page_number": 3,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "CHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You can also sell Items to buy levels (see Items). You lose a level when a card says you do. Your Level can never go below 1. However, your combat strength can be negative, if you get hit by a Curse or suffer some other kind of penalty.\nClass: Characters may be Warriors, Wizards, Thieves, or Clerics. If you have no Class card in front of you, you have no class. Yeah, I know, we did that one already.\nEach Class has special abilities, shown on the cards. You gain the abilities of a Class the moment you play its card in front of you, and lose them as soon as you discard that card. Some Class abilities are powered by discards. You may discard any card, in play or in your hand, to power a special ability.\nSee the Class cards for when abilities can be used. Note that a Thief cannot steal while he or the target is fighting - and as soon as a monster is revealed, the fight is on!\nYou can discard a Class card at any time, even in combat: “I don't wanna be a wizard anymore.” When you discard a Class card, you become classless until you play another Class card.\nYou may not belong to more than one class at once unless you play the Super Munchkin card.",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Interfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may not get the Treasure, depending on the method.\nTreasure cards can be played as soon as you get them, even if you are the helper.",
#         "metadata": {
#           "page_number": 4,
#           "source": "munchkin_rules/munchkin_rules-1.pdf"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "STEEDS\nDear to a munchkin’s heart (as of now) is his mighty Steed. Because, of course, it gives bonuses. Steeds are found in the Door deck.\nNo player can have more than one Steed except by using a Cheat! card.\nSteeds are Items, and follow normal Item rules. Anything that affects an Item can affect a Steed.\nSteeds carry themselves. A Steed is “Big,” but it does not count against the number of Big items you can carry (in fact, some let you carry more Big things). The “Big” designation on Steeds is to control what Traps and Curses affect them, and to keep Thieves from pocketing them and walking off.\nThere are a few Items that specifically enhance Steeds. Steeds cannot use Items unless the Item card specifically says so, and Item Enhancers don’t affect Steed-enhancing Items.\nIf a Steed has a bonus or penalty to Run Away, that replaces the bonus of the rider. An Elf normally has a bonus to Run Away, but he has a penalty if he is riding the Turtle Steed! If your Steed gives you a penalty to Run Away, you may discard the Steed before you roll to flee. You don’t suffer the penalty, but the card goes to the discard pile.\n\nTreating Steeds as Monsters\nA player who draws a face-up Steed may choose to treat it as a monster instead. In that case, its Level is equal to twice the combat bonus at the top of the card, and defeating it is good for one Treasure and one level. Monster Enhancers may be played on Steeds being fought as monsters, and have their normal effects. The Bad Stuff for any Steed attacked as a monster is “Lose a level.”",
#         "metadata": {
#           "page_number": 2,
#           "source": "munchkin_rules/munch_4_rules_20thp.pdf"
#         }
#       }
#     }
#   ],
#   "context": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 3\nPASSAGE:\n\"ONE-SHOT” TREASURES\nA Treasure card that says “Usable once only” is often called a “one-shot” Treasure. Most of these are used during combat to strengthen the munchkins or the monsters, and may be played from your hand or from the table. Some have other effects, however, so read the card carefully! Discard these cards as soon as the combat is over or their effect is resolved.\nOne-shot Items with a Gold Piece value may be sold for levels, just like other Items.\n\nOTHER TREASURES\nOther Treasure cards (like Go Up a Level cards) are not Items. Most of these cards say when they can be played, and whether they stay in play or are discarded. A couple of specific examples: Go Upa Level cards may be played on yourself or any other player at any time, even during combat. Discard them once they are played. Exception: You cannot play a Go Up a Level card to give a player the winning level!\nHireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nCHARACTER STATS\nEach character is basically a collection of weapons, armor, and magic items, with three stats: Level, Race, and Class. For instance, you might describe your character as a “Level 8 Elf Wizard with Boots of Butt-Kicking, a Staff of Napalm, and the Kneepads of Allure.” Level: This is a measure of how generally buff and studly you are. When the rules or cards refer to your Level, capitalized, they mean this number. You gain a level when you kill a monster, or when a card says that you do. You ...
#   "answer": {
#     "lc": 1,
#     "type": "constructor",
#     "id": [
#       "langchain",
#       "schema",
#       "messages",
#       "AIMessage"
#     ],
#     "kwargs": {
#       "content": "No, a \"Go Up a Level\" card cannot be played during combat in the game Munchkin. According to the rules, a player can only go up a level after defeating a monster, and this must be done on their own turn. Additionally, the rules state that nothing can reduce a player below Level 1, so a player cannot use a \"Go Up a Level\" card to increase their level during combat."
#     }
#   }
# }
# [chain/start] [1:chain:RunnableSequence > 60:chain:RunnableLambda] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 60:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "messages",
#     "AIMessage"
#   ],
#   "kwargs": {
#     "content": "No, a \"Go Up a Level\" card cannot be played during combat in the game Munchkin. According to the rules, a player can only go up a level after defeating a monster, and this must be done on their own turn. Additionally, the rules state that nothing can reduce a player below Level 1, so a player cannot use a \"Go Up a Level\" card to increase their level during combat."
#   }
# }
# [chain/end] [1:chain:RunnableSequence] [48.98s] Exiting Chain run with output:
# [outputs]
# AIMessage(content='No, a "Go Up a Level" card cannot be played during combat in the game Munchkin. According to the rules, a player can only go up a level after defeating a monster, and this must be done on their own turn. Additionally, the rules state that nothing can reduce a player below Level 1, so a player cannot use a "Go Up a Level" card to increase their level during combat.')

# %%
chain = (
    RunnablePassthrough.assign(result=itemgetter("query") | rag_chain | StrOutputParser())
    | QAEvalChain.from_llm(chat_model)
) 

chain.with_config({"callbacks": [ConsoleCallbackHandler()]}).invoke(
    {
        "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
        "result": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
        "answer": "No, you cannot loot the room.",
    }
)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room."
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign] Entering Chain run with input:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room."
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel] Entering Chain run with input:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room."
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence] Entering Chain run with input:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room."
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 5:chain:RunnableLambda] Entering Chain run with input:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room."
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 5:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 6:chain:RunnableParallel] Entering Chain run with input:
# {
#   "input": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 6:chain:RunnableParallel > 7:chain:RunnablePassthrough] Entering Chain run with input:
# {
#   "input": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 6:chain:RunnableParallel > 7:chain:RunnablePassthrough] s] Exiting Chain run with output:
# {
#   "output": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 6:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel] Entering Chain run with input:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 9:chain:RunnableLambda] Entering Chain run with input:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 9:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought] Entering Chain run with input:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel] Entering Chain run with input:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 12:chain:RunnableLambda] Entering Chain run with input:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 12:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 13:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 13:chain:RunnableSequence > 14:chain:RunnableLambda] Entering Chain run with input:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 13:chain:RunnableSequence > 14:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 13:chain:RunnableSequence > 16:chain:thread_of_thought_combine_documents] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 13:chain:RunnableSequence > 16:chain:thread_of_thought_combine_documents] s] Exiting Chain run with output:
# {
#   "output": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may  ...
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel > 13:chain:RunnableSequence] s] Exiting Chain run with output:
# {
#   "output": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may  ...
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 11:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "context": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may ...
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 17:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "context": "\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the monster alone. Draw face-up, so the whole party can see what you got, if someone helped you, even if they aren't taking any Treasures. (Sucker.)\nIf you defeat a monster by nonlethal means, you do not get a level and you may or may ...
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 17:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "As a content reviewer, I provide multiple retrieved passages about this question; you need to answer the question.\n\nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n\n----\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nTURN PHASES\nYour turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.\nIf it’s a monster, you must fight it. See Combat, p- 3. If the card is a curse - see Curses, p- Sait applies to you immediately (if it can) and is discarded (unless it has a persistent effect or you keep the card as a reminder of an upcoming effect).\nIf you draw any other card, you may either put it in your hand or play it immediately.\n(2) Look For Trouble/Loot The Room: If you fought a monster in phase IL, skip this phase and go to phase Be If you did NOT draw a monster when you first opened the door, you have two choices: either Look For Trouble or Loot The Room.\nLook For Trouble: Play a monster from your hand and fight it, just as if you had found it when you kicked open the door. Don’t play a monster you can't handle, unless you're sure you can count on getting help (see p- 4)!\nLoot The Room: Draw a second card from the Door deck, face down, and place it in your hand.\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 4\nPASSAGE:\nInterfering With Combat\nYou can interfere with others’ combats in several ways, including: Use a one-shot card. You could help another player by using a one-shot to strengthen their side. Of course, you can “accidentally” strengthen the monster with it, instead. . .\nPlay a monster enhancer. These cards (usually) make a monster stronger .. . and give it more Treasure. You can play these either during your own combats or during someone else's combat.\nAdd a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule.\nBackstab a player in combat, if you're a Thief.\nCurse them, if you have a Curse card.\n\nREWARDS\nWhen you kill a monster, you get one level per monster, unless the monster card says something else, and you get all its Treasure! Each monster has a Treasure number on the bottom of its card. Draw that many Treasures, modified by any monster enhancers played on it. Draw face-down if you killed the mons ...
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 18:chain:chat-sampling] Entering Chain run with input:
# [inputs]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:404: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:404: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:404: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 18:chain:chat-sampling] [34.94s] Exiting Chain run with output:
# {
#   "output": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "Q: If a monster does not pursue me because my level is too low, can I still loot the room?\n\nStep 1: Understand the context\n\nThe passage is from a rulesheet for the card game \"Munchkin.\" In this game, players take on the role of adventurers who fight monsters to gain levels and treasure. The rules for combat and looting are outlined in the passage.\n\nStep 2: Analyze the question\n\nThe question asks if a player can still loot the room if a monster does not pursue them because their level is too low.\n\nStep 3: Summarize the rules\n\nAccording to the rules outlined in the passage, when a player opens the door to a room, they must either look for trouble or loot the room. If they choose to look for trouble, they must fight any monster they find. If they choose to loot the room, they must draw a second card from the deck and place it in their hand.\n\nStep 4: Determine the answer\n\nThe answer to the question is not clear based on the information provided in the passage. The passage does not specify whether a player can still loot the room if a monster does not pursue them because their level is too low. The rules for combat and looting only mention what a player must do when a monster is found, but do not address what happens if a monster does not pursue a player."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "This is a question about the rules of a game called Munchkin. It's not clear what the specific question is, but I can try to provide some general information about the game to help answer it.\n\nThe rules of Munchkin are designed to be flexible and easy to understand, with a focus on encouraging player creativity and strategic thinking. The game is played with cards, and each player starts with a certain level and a set of abilities. The goal of the game is to defeat all of the monsters and gain experience points, which allow players to level up and gain more abilities.\n\nThe rules of the game specify that certain cards, such as \"Wandering Monster\" and \"Curse,\" can be played during the game to add to the complexity and challenge of the game. These cards can also be used strategically by players to gain an advantage over their opponents.\n\nThere are also specific rules governing combat in the game, including how to determine the combat strength of each player and monster, and how to calculate damage and resolve combat outcomes. These rules are designed to be easy to understand and apply, with a focus on encouraging players to engage in strategic thinking and creative problem-solving.\n\nIn addition to the core rules of the game, there are also many different cards and expansions available that add new elements and challenges to the game. These cards can be used to create new strategies and approaches to gameplay, and to customize the game to suit the needs and preferences of individual players.\n\nOverall, the rules of Munchkin are designed to be flexible and easy to understand, with a focus on encouraging player creativity and strategic thinking. The game is played with cards, and each player starts with a certain level and a set of abilities. The goal of the game is to defeat all of the monsters and gain experience points, which allow players to level up and gain more abilities."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "Q: If a monster does not pursue me because my level is too low, can I still loot the room?\n\nContext:\n\n1. The question is about the rules of the Munchkin game.\n2. The rules are outlined in a rulesheet, but cards can add special rules that may conflict with the rulesheet.\n3. In general, players should follow their cards, but ignore any card effect that might contradict a rule listed in the rulesheet unless the card explicitly states it supersedes that rule.\n4. The rules state that a player can go up a level after combat only if they defeat a monster.\n5. The rules also state that a player cannot collect rewards for defeating a monster in the middle of a combat. They must finish the fight before gaining any rewards.\n6. The rules state that a player must kill a monster to reach Level 10, and they cannot force another player to help them do it.\n7. The rules also state that any other disputes should be settled by loud arguments, with the owner of the game having the last word.\n8. The rules also state that players can interfere with others' combats in several ways, including using a one-shot card, playing a monster enhancer, adding a monster from their hand to join the combat, backstabbing a player in combat, cursing them, or running away."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "The rules for Munchkin's combat and levels are as follows:\n\n1. No player can reduce another player's level below Level 1, although card effects might reduce a level.\n2. To go up a level after combat, a player must defeat a monster using their combat strength.\n3. A player cannot collect rewards for defeating a monster during combat. The player must finish the fight before gaining any rewards.\n4. To reach Level 10, a player must kill the monster.\n\nIf a monster does not pursue a player because their level is too low, the player can still loot the room. The rules do not specify that a player must defeat a monster to loot the room."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "The question is about looting the room if a monster does not pursue you because your level is too low.\n\n1. The turn phases in Munchkin are defined.\n2. Interfering with combat and rewards are explained.\n3. Running away from a monster is described.\n4. The rules for monsters and monster enhancers are given.\n5. Fighting multiple monsters is explained.\n6. The context of the question is set: a monster does not pursue you because your level is too low.\n7. The question is about whether you can still loot the room if this happens.\n8. The rules for looting the room are not specified in the provided passages, so it is unclear whether you can loot the room in this situation. It is recommended to read the Munchkin FAQ and errata pages at munchkin.game or start a discussion at forums.sjgames.com to clarify this rule."
#       }
#     }
#   ]
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 20:chain:<lambda>] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 20:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": true
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 22:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 23:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 24:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 25:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 26:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 22:chain:RunnableSequence > 23:chain:<lambda>] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 22:chain:RunnableSequence > 23:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "Q: If a monster does not pursue me because my level is too low, can I still loot the room?\n\nStep 1: Understand the context\n\nThe passage is from a rulesheet for the card game \"Munchkin.\" In this game, players take on the role of adventurers who fight monsters to gain levels and treasure. The rules for combat and looting are outlined in the passage.\n\nStep 2: Analyze the question\n\nThe question asks if a player can still loot the room if a monster does not pursue them because their level is too low.\n\nStep 3: Summarize the rules\n\nAccording to the rules outlined in the passage, when a player opens the door to a room, they must either look for trouble or loot the room. If they choose to look for trouble, they must fight any monster they find. If they choose to loot the room, they must draw a second card from the deck and place it in their hand.\n\nStep 4: Determine the answer\n\nThe answer to the question is not clear based on the information provided in the passage. The passage does not specify whether a player can still loot the room if a monster does not pursue them because their level is too low. The rules for combat and looting only mention what a player must do when a monster is found, but do not address what happens if a monster does not pursue a player.\n\nTherefore, the answer is"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 23:chain:RunnableSequence > 24:chain:<lambda>] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 23:chain:RunnableSequence > 24:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "This is a question about the rules of a game called Munchkin. It's not clear what the specific question is, but I can try to provide some general information about the game to help answer it.\n\nThe rules of Munchkin are designed to be flexible and easy to understand, with a focus on encouraging player creativity and strategic thinking. The game is played with cards, and each player starts with a certain level and a set of abilities. The goal of the game is to defeat all of the monsters and gain experience points, which allow players to level up and gain more abilities.\n\nThe rules of the game specify that certain cards, such as \"Wandering Monster\" and \"Curse,\" can be played during the game to add to the complexity and challenge of the game. These cards can also be used strategically by players to gain an advantage over their opponents.\n\nThere are also specific rules governing combat in the game, including how to determine the combat strength of each player and monster, and how to calculate damage and resolve combat outcomes. These rules are designed to be easy to understand and apply, with a focus on encouraging players to engage in strategic thinking and creative problem-solving.\n\nIn addition to the core rules of the game, there are also many different cards and expansions available that add new elements and challenges to the game. These cards can be used to create new strategies and approaches to gameplay, and to customize the game to suit the needs and preferences of individual players.\n\nOverall, the rules of Munchkin are designed to be flexible and easy to understand, with a focus on encouraging player creativity and strategic thinking. The game is played with cards, and each player starts with a certain level and a set of abilities. The goal of the game is to defeat all of the monsters and gain experience points, which allow players to level up and gain more abilities.\n\nTherefore, the answer is"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 24:chain:RunnableSequence > 25:chain:<lambda>] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 24:chain:RunnableSequence > 25:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "Q: If a monster does not pursue me because my level is too low, can I still loot the room?\n\nContext:\n\n1. The question is about the rules of the Munchkin game.\n2. The rules are outlined in a rulesheet, but cards can add special rules that may conflict with the rulesheet.\n3. In general, players should follow their cards, but ignore any card effect that might contradict a rule listed in the rulesheet unless the card explicitly states it supersedes that rule.\n4. The rules state that a player can go up a level after combat only if they defeat a monster.\n5. The rules also state that a player cannot collect rewards for defeating a monster in the middle of a combat. They must finish the fight before gaining any rewards.\n6. The rules state that a player must kill a monster to reach Level 10, and they cannot force another player to help them do it.\n7. The rules also state that any other disputes should be settled by loud arguments, with the owner of the game having the last word.\n8. The rules also state that players can interfere with others' combats in several ways, including using a one-shot card, playing a monster enhancer, adding a monster from their hand to join the combat, backstabbing a player in combat, cursing them, or running away.\n\nTherefore, the answer is"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 8:chain:RunnableParallel > 10:chain:thread-of-thought > 19:chain:RunnableBranch > 21:chain:RunnableEach > 25:chain:RunnableSequence > 26:chain:<lambda>] Entering Chain run with input:
# [inputs]
# ...
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The most consistent response is Response 2."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel > 45:chain:RunnableSequence > 48:parser:RegexParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel > 45:chain:RunnableSequence > 48:parser:RegexParser] s] Exiting Parser run with output:
# {
#   "response_selected_index": "2"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel > 45:chain:RunnableSequence > 49:chain:RunnableLambda] Entering Chain run with input:
# {
#   "response_selected_index": "2"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel > 45:chain:RunnableSequence > 49:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "2"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel > 45:chain:RunnableSequence > 50:chain:int] Entering Chain run with input:
# {
#   "input": "2"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel > 45:chain:RunnableSequence > 50:chain:int] s] Exiting Chain run with output:
# {
#   "output": 2
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel > 45:chain:RunnableSequence] s] Exiting Chain run with output:
# {
#   "output": 2
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign > 44:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "response_selected_index": 2
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 43:chain:RunnableAssign] s] Exiting Chain run with output:
# {
#   "question": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "responses": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "The answer is not clear based on the information provided in the passage."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "The rules of Munchkin are designed to be flexible and easy to understand, with a focus on encouraging player creativity and strategic thinking. The game is played with cards, and each player starts with a certain level and a set of abilities. The goal of the game is to defeat all of the monsters and gain experience points, which allow players to level up and gain more abilities."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "The player can loot the room even if they did not defeat the monster."
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "It is unclear whether you can loot the room if a monster does not pursue you because your level is too low. The rules for looting the room are not specified in the provided passages, so it is recommended to read the Munchkin FAQ and errata pages at munchkin.game or start a discussion at forums.sjgames.com to clarify this rule."
#       }
#     }
#   ],
#   "context": "Response 0\nThe answer is not clear based on the information provided in the passage.\n\nResponse 1\nThe rules of Munchkin are designed to be flexible and easy to understand, with a focus on encouraging player creativity and strategic thinking. The game is played with cards, and each player starts with a certain level and a set of abilities. The goal of the game is to defeat all of the monsters and gain experience points, which allow players to level up and gain more abilities.\n\nResponse 2\nNo, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room.\n\nResponse 3\nThe player can loot the room even if they did not defeat the monster.\n\nResponse 4\nIt is unclear whether you can loot the room if a monster does not pursue you because your level is too low. The rules for looting the room are not specified in the provided passages, so it is recommended to read the Munchkin FAQ and errata pages at munchkin.game or start a discussion at forums.sjgames.com to clarify this rule.",
#   "response_selected_index": 2
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 51:chain:<lambda>] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence > 51:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "messages",
#     "AIMessage"
#   ],
#   "kwargs": {
#     "content": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
#   }
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency > 30:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 29:chain:universal-consistency] s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 52:parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence > 52:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel > 4:chain:RunnableSequence] [50.97s] Exiting Chain run with output:
# {
#   "output": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign > 3:chain:RunnableParallel] [50.98s] Exiting Chain run with output:
# {
#   "result": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableAssign] [50.99s] Exiting Chain run with output:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room.",
#   "result": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
# }
# [chain/start] [1:chain:RunnableSequence > 53:chain:QAEvalChain] Entering Chain run with input:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room.",
#   "result": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room."
# }
# [llm/start] [1:chain:RunnableSequence > 53:chain:QAEvalChain > 54:llm:HuggingFaceChatModel] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: You are a teacher grading a quiz.\nYou are given a question, the student's answer, and the true answer, and are asked to score the student answer as either CORRECT or INCORRECT.\n\nExample Format:\nQUESTION: question here\nSTUDENT ANSWER: student's answer here\nTRUE ANSWER: true answer here\nGRADE: CORRECT or INCORRECT here\n\nGrade the student answers based ONLY on their factual accuracy. Ignore differences in punctuation and phrasing between the student answer and true answer. It is OK if the student answer contains more information than the true answer, as long as it does not contain any conflicting statements. Begin! \n\nQUESTION: If a monster does not pursue me because my level is too low, can I still loot the room?\nSTUDENT ANSWER: No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room.\nTRUE ANSWER: No, you cannot loot the room.\nGRADE:"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 53:chain:QAEvalChain > 54:llm:HuggingFaceChatModel] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "CORRECT.",
#         "generation_info": null,
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "CORRECT."
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:RunnableSequence > 53:chain:QAEvalChain] s] Exiting Chain run with output:
# {
#   "results": "CORRECT."
# }
# [chain/end] [1:chain:RunnableSequence] [51.29s] Exiting Chain run with output:
# {
#   "query": "If a monster does not pursue me because my level is too low, can I still loot the room?",
#   "answer": "No, you cannot loot the room.",
#   "result": "No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room.",
#   "results": "CORRECT."
# }
# {'query': 'If a monster does not pursue me because my level is too low, can I still loot the room?',
#  'answer': 'No, you cannot loot the room.',
#  'result': 'No, if a monster does not pursue me because my level is too low, I cannot loot the room. According to the rules, a player can only go up a level after defeating a monster in combat. If the monster does not pursue me, I cannot defeat it and therefore cannot go up a level. Additionally, the rules state that a player cannot collect rewards for defeating a monster in the middle of a combat. If I do not defeat the monster, I cannot collect any rewards. Therefore, I cannot loot the room.',
#  'results': 'CORRECT.'}

# %%
m = "As a content reviewer, I provide multiple retrieved passages about this question; you need to answer the question.\n\nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n\n----\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 2\nPASSAGE:\nWhen You May Take Actions\nYou may perform these actions at any time: & Discard a Class or Race.\n& Play a Go Up a Level or Hireling. Play a Curse.\nYou may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).\ny Change which Items you have equipped.\nPlay a card that you have just received (some cards may be played even during combat; see above).\nYou may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).\nwe Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).\n---\n\n\n---\nNAME: munchkin_rules/munchkin_rules-1.pdf\nPAGE: 1\nPASSAGE:\nConflicts Between Cards and Rules\nThis rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!\niL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.\n2. You go up a level after combat only if you Ail a monster.\n3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.\n4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.\nAny other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.\n\nSTEVE JACKSON GAMES\nYour Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).\nCards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.\n---\n\n----\n\nQ: Can I play a Go Up a Level card during combat?\nWalk me through this context in manageable parts step by step, summarizing and analyzing as we go.\n"
print(m)
print()
print()
print(chat_model.invoke(m).content)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# As a content reviewer, I provide multiple retrieved passages about this question; you need to answer the question.
#
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
#
# ----
#
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 2
# PASSAGE:
# When You May Take Actions
# You may perform these actions at any time: & Discard a Class or Race.
# & Play a Go Up a Level or Hireling. Play a Curse.
# You may perform these actions at any time, as long as you are not in combat: Trade an Item with another player (the other player may not be in combat, either).
# y Change which Items you have equipped.
# Play a card that you have just received (some cards may be played even during combat; see above).
# You may perform these actions on your own turn: 3 Play a new Class or Race card (at any time).
# we Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).
# ---
#
#
# ---
# NAME: munchkin_rules/munchkin_rules-1.pdf
# PAGE: 1
# PASSAGE:
# Conflicts Between Cards and Rules
# This rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!
# iL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.
# 2. You go up a level after combat only if you Ail a monster.
# 3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.
# 4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.
# Any other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.
#
# STEVE JACKSON GAMES
# Your Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).
# Cards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.
# ---
#
# ----
#
# Q: Can I play a Go Up a Level card during combat?
# Walk me through this context in manageable parts step by step, summarizing and analyzing as we go.
#
#
#
# The question is whether or not a player can play a Go Up a Level card during combat.
#
# The context starts with a rulesheet that gives general rules for Munchkin, a card game. The rules state that nothing can reduce a player below Level 1, but card effects might reduce a player's or a monster's combat strength below 1. A player goes up a level after combat only if they killed a monster, and they cannot collect rewards for defeating a monster in the middle of a combat. They must finish the fight before gaining any rewards.
#
# The next section is about conflicts between cards and rules. The general rule is that in most cases, when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed above, unless the card explicitly says it supersedes that rule!
#
# The rules also state that a player's hand contains cards that are not in play. They can't be taken away except by cards that specifically affect "your hand." At the end of a turn, a player may have no more than five cards in their hand. Cards in play may not be returned to a player's hand; they must be discarded or traded if a player wants to get rid of them.
#
# Finally, the question is whether or not a player can play a Go Up a Level card during combat. The rules do not specify whether or not a player can play this card during combat. Therefore, the answer is not known based on the provided context.

# %%
# # Using regular LLM interface
# from langchain.llms import VLLMOpenAI

# llm = VLLMOpenAI(
#     openai_api_key="EMPTY",
#     openai_api_base="http://localhost:8000/v1",
#     temperature=0.1,
#     # model_kwargs=dict(repetition_penalty=1.1),
#     max_tokens=2_000,
#     model_name=model_name,
#     frequency_penalty=0.2,
# )
# print(llm("[INST] Generate 10 names for a fantasy elf Paladin. [/INST] "))
# Out:
# 1. Galadriel
# 2. Elrond
# 3. Legolas
# 4. Arwen
# 5. Thranduil
# 6. Faramir
# 7. Eärendil
# 8. Lúthien
# 9. Glorfindel
# 10. Celebrindor

# %%
# To parse the PDFs, there are three strategies available: "fast", "hi_res", and
# "ocr_only". For the PDFs used here, "fast" retrieves a bunch of duplicate text
# in the wrong order. "hi_res" doesn't handle columns of text well and produces
# incoherent results. "ocr_only" seems to work reasonably well in this case.
rule_docs = []
for filename in data_path.glob("*.pdf"):
    print(f"Processing {filename}")
    loader = UnstructuredPDFLoader(filename, strategy="ocr_only")
    rule_docs.extend(loader.load())
# Out:
# Processing munchkin_rules/munchkin_rules-1.pdf
# Processing munchkin_rules/puppies-rules.pdf
# Processing munchkin_rules/princesses_rules.pdf
# Processing munchkin_rules/munch_4_rules_20thp.pdf

# %%
# Chunk text
text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
chunked_documents = text_splitter.split_documents(rule_docs)

# %%
# !nvidia-smi
# Out:
# Fri Dec  1 23:51:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:07:00.0 Off |                  N/A |
# |  0%   47C    P8    23W / 420W |    139MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# import faiss
# Load chunked documents into the FAISS index
db = FAISS.from_documents(
    chunked_documents, 
    embedding_model
)

# %%
# !nvidia-smi
# Out:
# Fri Dec  1 23:57:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:07:00.0 Off |                  N/A |
# |  0%   49C    P8    21W / 420W |  22475MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
prompt_template = """[INST] 
Instruction: You are an assitant to help answer questions about board game rules. Answer questions concisely and in one or two sentences. Rely upon the following passages from the rulebook when answering questions.

{context}

QUESTION:
{question} 
[/INST]"""

# text_generation_pipeline = transformers.pipeline(
#     model=model,
#     tokenizer=tokenizer,
#     task="text-generation",
#     # temperature=0.2,
#     # repetition_penalty=1.1,
#     # return_dict_in_generate=True,
#     # output_scores=True,
#     return_full_text=True,
#     max_new_tokens=1000,
# )
# text_generation_pipeline.model.config.pad_token_id = text_generation_pipeline.model.config.eos_token_id

# mistral_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# Create prompt from prompt template
prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template,
)

# Create llm chain 
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Create retriever
# retrieve_topk
retriever = db.as_retriever(search_kwargs={"k": 3})

def format_docs(docs):
    passages = []
    for i, doc in enumerate(docs):
        passages.append(f"Passage {i+1}: {doc.page_content}")
    return "\n\n".join(passages)

# Create rag chain
rag_chain = ( 
 {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | llm_chain
)

# %%
import langchain
langchain.debug = False

# %%
for i, test_case in enumerate(test_cases):
    # # Hack to avoid a warning about horribly inefficient our use of the GPU is
    # text_generation_pipeline.call_count = 0

    result = rag_chain.invoke(test_case["question"])

    print("input:", test_case["question"].strip())
    print("reference:", test_case["answer"].strip())
    print("prediction:", result["text"].strip())

    if i < len(test_cases) - 1:
        print()
        print()
# Out:
# input: If a monster does not pursue me because my level is too low, can I still loot the room?
# reference: No. If a monster does not pursue you, it means you automatically run away from it. However, you still count as having been in combat and cannot loot the room.
# prediction: No, if a monster does not pursue you because your level is too low, you cannot loot the room.
#
#
# input: Can I sell items from my hand to go up a level, assuming I can sell 1,000 gold pieces worth?
# reference: Yes. You can sell items from your hand to go up a level.
# prediction: No, you cannot sell items from your hand to go up a level. You can only sell items worth a total of at least 1,000 Gold Pieces and immediately go up one level.
#
#
# input: If a hireling is removed from play due to Bad Stuff, does the player retain any items the hireling was carrying?
# reference: No. When a hireling is removed from play due to bad stuff, any items the hireling was carrying are also removed from play.
# prediction: If a Hireling is removed from play due to Bad Stuff, the player loses any Items the Hireling was carrying.
#
#
# input: Can I have multiple steeds equipped at the same time?
# reference: No. You can only have one steed equipped at a time unless another card specifically says otherwise.
# prediction: No, a player can only have one Steed equipped at the same time, except by using a Cheat! card.
#
#
# input: Can I play a Go Up a Level card during combat on my turn?
# reference: Yes. You can play a Go Up a Level card at any time.
# prediction: No, you cannot play a Go Up a Level card during combat on your turn.
#
#
# input: How many players can join me in a combat?
# reference: Only one player can join you in combat.
# prediction: Passage 1 states that you can add a monster from your hand to join the combat, either with a Wandering Monster card or by using the special Undead rule. However, there is no limit on the number of players that can join a combat.
#
#
# input: Does a player retain their princess card in play if they die?
# reference: Yes. A player retains their princess card in play if they die.
# prediction: No, a player does not retain their Princess card in play if they die.
#
#
# input: Can I carry multiple big items so long as only one is equipped?
# reference: No. You can only carry one big item at a time.
# prediction: No, you can only carry one Big item at a time. You must either sell, trade, lose, or discard it to power a Class or Race ability.
#
#
# input: What is an item in play but not equipped called?
# reference: An item in play but not equipped is called a carried item.
# prediction: An item in play but not equipped is called "carried."

# %%
def ask(question):
    result = rag_chain.invoke(question)
    print("CONTEXT")
    print(result["context"])
    # for i, doc in enumerate(result["context"]):
    #     print(f"Document {i}:")
    #     print(f"{doc}")
    #     print("\n")
    print()
    print("ANSWER")
    print(result["text"].strip())

# %%
ask("Can I play a Go Up a Level card during combat on my turn?")
# Out:
# CONTEXT
# Passage 1: Hireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.
#
# COMBAT
#
# To fight a monster, compare its combat strength to yours. Combat strength is the total of Level plus all modifiers - positive or negative - given by Items and other cards. If the monster's combat strength is equal to yours, or greater, you lose the combat and must Run Away (see p. 5). If your combat strength totals more than the monster's — note that monsters win ties! — you kill it and goupa level (two levels for some big monsters). You'll also get the number of Treasures shown on its card.
#
# Sometimes a card will let you get rid of the monster without killing it. This is still “winning,” but you don't get a level. Unless the ability says otherwise, you don’t get the Treasures, either. If the last monster is removed from a combat, it ends instantly.
#
# Some monster cards have special powers that affect combat
#
# Passage 2: killing a monster, unless a card specifically allows you to win another way.
#
# When You May Take Actions
#
# You may perform these actions at any time: & Discard a Class or Race.
#
# & Play a Go Up a Level or Hireling. Play a Curse.
#
# You may perform these actions at any time, as long as you are not in combat:
#
# Trade an Item with another player (the other player may not be in combat, either).
#
# y Change which Items you have equipped.
#
# Play a card that you have just received (some cards may be
#
# played even during combat; see above).
#
# You may perform these actions on your own turn:
#
# 3 Play a new Class or Race card (at any time).
#
# we Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).
#
# TURN PHASES
#
# Your turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL
#
# (1) Kick Open The Door: Draw one card from the Door deck and turn it face up.
#
# Passage 3: Conflicts Between Cards and Rules
#
# This rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!
#
# iL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.
#
# 2. You go up a level after combat only if you Ail a monster.
#
# 3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.
#
# 4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.
#
# ANSWER
# No, you cannot play a Go Up a Level card during combat on your turn.

# %%
# Lets try thread of thought
prompt_template = """[INST] As a content reviewer, I provide multiple passages about this question; you need to answer the question.
Passage 1: 

Hireling may be played at any time, on any turn. You cannot give a Hireling an Item to carry while you are in combat, however.

COMBAT

To fight a monster, compare its combat strength to yours. Combat strength is the total of Level plus all modifiers - positive or negative - given by Items and other cards. If the monster's combat strength is equal to yours, or greater, you lose the combat and must Run Away (see p. 5). If your combat strength totals more than the monster's — note that monsters win ties! — you kill it and goupa level (two levels for some big monsters). You'll also get the number of Treasures shown on its card.

Sometimes a card will let you get rid of the monster without killing it. This is still “winning,” but you don't get a level. Unless the ability says otherwise, you don’t get the Treasures, either. If the last monster is removed from a combat, it ends instantly.

Some monster cards have special powers that affect combat

Passage 2: 

killing a monster, unless a card specifically allows you to win another way.

When You May Take Actions

You may perform these actions at any time: & Discard a Class or Race.

& Play a Go Up a Level or Hireling. Play a Curse.

You may perform these actions at any time, as long as you are not in combat:

Trade an Item with another player (the other player may not be in combat, either).

y Change which Items you have equipped.

Play a card that you have just received (some cards may be

played even during combat; see above).

You may perform these actions on your own turn:

3 Play a new Class or Race card (at any time).

we Sell Items for levels (except when you are in combat). Play an Item (most Items cannot be played during combat, but some one-shot Items can; see p- 3).

TURN PHASES

Your turn begins as soon as the previous player's turn ends. When your cards are arranged the way you want, go to phase iL

(1) Kick Open The Door: Draw one card from the Door deck and turn it face up.

Passage 3: 

Conflicts Between Cards and Rules

This rulesheet gives the general tules. Many cards add special rules, so in most cases when the rulesheet disagrees with a card, follow the card. However, ignore any card effect that might seem to contradict one of the rules listed below unless the card explicitly says it supersedes that rule!

iL Nothing can reduce a player below Level 1, although card effects might reduce a player's or a monster's combat strength (p. 3) below I.

2. You go up a level after combat only if you Ail a monster.

3. You cannot collect rewards for defeating a monster (eg., Treasure, levels) in the middle of a combat. You must finish the fight before gaining any rewards.

4. You must killa monster to reach Level 10, and you cannot force another player to help you do it.

Question: Can I play a Go Up a Level card during combat on my turn?
Walk me through this context in manageable parts step by step,
summarizing and analyzing as we go.
Answer:
"""

# Create prompt from prompt template
prompt = PromptTemplate(
    input_variables=[],
    template=prompt_template,
)

# Create llm chain 
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Create retriever
# retrieve_topk
retriever = db.as_retriever(search_kwargs={"k": 3})

def format_docs(docs):
    passages = []
    for i, doc in enumerate(docs):
        passages.append(f"Passage {i+1}: {doc.page_content}")
    return "\n\n".join(passages)

# Create rag chain
# rag_chain = ( 
#  {"context": retriever | format_docs, "question": RunnablePassthrough()}
#     | llm_chain
# )

# %%
thot_chain = llm_chain
print(thot_chain.invoke({})["text"])
# Out:
# Passage 1:
#
# * Hireling can be played at any time, on any turn.
# * Cannot give a Hireling an Item to carry while in combat.
#
# Passage 2:
#
# * You may perform these actions at any time: Discard a Class or Race, Play a Go Up a Level or Hireling, Play a Curse.
# * You may perform these actions on your own turn: Play a new Class or Race card, Sell Items for levels, Play an Item.
#
# Passage 3:
#
# * Conflicts Between Cards and Rules.
# * Nothing can reduce a player below Level 1.
# * You go up a level after combat only if you kill a monster.
# * You cannot collect rewards for defeating a monster in the middle of a combat.
# * You must kill a monster to reach Level 10 and cannot force another player to help you do it.
#
# Answer: No, you cannot play a Go Up a Level card during combat on your turn because the rules state that you can only go up a level after combat if you kill a monster. Additionally, the rules state that you cannot collect rewards for defeating a monster in the middle of a combat, so you would need to finish the fight before gaining any rewards.

# %%
ask("What is the card limit for how many cards can be in my hand?")
# Out:
# CONTEXT
# Any other disputes should be settled by loud arguments, with the owner of the game having the last word. You could also read the Munchkin FAQ and errata pages at munchkin.game, or start a discussion at forums.sjgames.com/, munchkin . . . unless it’s more fun to argue.
#
# STEVE JACKSON GAMES
#
# Your Hand: Cards in your hand are not in play. They don’t help you, but they can’t be taken away except by cards that specifically affect “your hand.” At the end of your turn, you may have no more than five cards in your hand (see Charity, p- 2).
#
# Cards in play may not be returned to your hand - they must be discarded or traded if you want to get rid of them.
#
# CHARACTER CREATION
#
# Everyone starts as a Level | human with no class. (Heh, heh.) Munchkin characters may be either male or female. Your character's sex is the same as your own at the start of the game, unless you declare otherwise.
#
# Anyone can carry any Item (except for extra Big items; see below), but you may equip only one Headgear, one suit of Armor, one pair of Footgear, and two “I Hand” Items (or one “2 Hands” Item) . . . unless you have a card that lets you ignore these limits, such as Hireling or Cheat!, or unless one of the cards says otherwise. If you are carrying two Headgear cards, for instance, you can equip only one of them at a time.
#
# Likewise, some Items have restrictions: for instance, the Mace of Sharpness can only be wielded by a Cleric. Its bonus only counts for someone who is, at the moment, a Cleric.
#
# You cannot discard Item cards “just because.” You may sell Items for a level, trade Items with other players, or give an Item to another player who wants it (see below). You may discard Items to power certain Class and Race abilities. And a Curse or a monster's Bad Stuff (see p. 5) may force you to get rid of something!
#
# When the next player begins their turn, your newly revived character appears and can help others in combat with your Level and Class or Race abilities . . . but you have no cards, unless you receive Charity or gifts from other players.
#
# On your next turn, start by drawing four face-down cards from each deck and playing any legal cards you want to, just as when you started the game. Then take your turn normally.
#
# CURSES
#
# If drawn face-up during the Kick Open The Door phase, Curse cards apply to the person who drew them. If acquired some other way, such as by Looting The Room, Curse cards go into your hand and may be played on any player at any time. Reducing someone's abilities just as they think they have killed a monster is a lot of fun.
#
# ANSWER
# The card limit for how many cards can be in your hand is five.
